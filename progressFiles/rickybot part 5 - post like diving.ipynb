# %%
# settings
posts_caturday = 2000
follows_caturday = 1100
posts_othercat = 100
follows_othercat = 100

# %%
pip install atproto
# Out:
# Requirement already satisfied: atproto in /usr/local/lib/python3.11/dist-packages (0.0.58)
# Requirement already satisfied: click<9,>=8.1.3 in /usr/local/lib/python3.11/dist-packages (from atproto) (8.1.8)
# Requirement already satisfied: cryptography<44,>=41.0.7 in /usr/local/lib/python3.11/dist-packages (from atproto) (43.0.3)
# Requirement already satisfied: dnspython<3,>=2.4.0 in /usr/local/lib/python3.11/dist-packages (from atproto) (2.7.0)
# Requirement already satisfied: httpx<0.28.0,>=0.25.0 in /usr/local/lib/python3.11/dist-packages (from atproto) (0.27.2)
# Requirement already satisfied: libipld<4,>=2.0.0 in /usr/local/lib/python3.11/dist-packages (from atproto) (3.0.0)
# Requirement already satisfied: pydantic<3,>=2.7 in /usr/local/lib/python3.11/dist-packages (from atproto) (2.10.6)
# Requirement already satisfied: typing-extensions<5,>=4.8.0 in /usr/local/lib/python3.11/dist-packages (from atproto) (4.12.2)
# Requirement already satisfied: websockets<14,>=12 in /usr/local/lib/python3.11/dist-packages (from atproto) (13.1)
# Requirement already satisfied: cffi>=1.12 in /usr/local/lib/python3.11/dist-packages (from cryptography<44,>=41.0.7->atproto) (1.17.1)
# Requirement already satisfied: anyio in /usr/local/lib/python3.11/dist-packages (from httpx<0.28.0,>=0.25.0->atproto) (3.7.1)
# Requirement already satisfied: certifi in /usr/local/lib/python3.11/dist-packages (from httpx<0.28.0,>=0.25.0->atproto) (2025.1.31)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.11/dist-packages (from httpx<0.28.0,>=0.25.0->atproto) (1.0.7)
# Requirement already satisfied: idna in /usr/local/lib/python3.11/dist-packages (from httpx<0.28.0,>=0.25.0->atproto) (3.10)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.11/dist-packages (from httpx<0.28.0,>=0.25.0->atproto) (1.3.1)
# Requirement already satisfied: h11<0.15,>=0.13 in /usr/local/lib/python3.11/dist-packages (from httpcore==1.*->httpx<0.28.0,>=0.25.0->atproto) (0.14.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.11/dist-packages (from pydantic<3,>=2.7->atproto) (0.7.0)
# Requirement already satisfied: pydantic-core==2.27.2 in /usr/local/lib/python3.11/dist-packages (from pydantic<3,>=2.7->atproto) (2.27.2)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.11/dist-packages (from cffi>=1.12->cryptography<44,>=41.0.7->atproto) (2.22)

# %%
# From the transformers package, import ViTImageProcessor and ViTForImageClassification
from transformers import ViTImageProcessor, ViTForImageClassification

# From the PIL package, import Image and Markdown
from PIL import Image

# import requests
import requests

# import torch
import torch

# import matplotlib
import matplotlib.pyplot as plt

# url getter for mpl
import urllib

import numpy as np

# import bluesky api
from atproto import Client

# import colab secrets to store login credentials
from google.colab import userdata

# datetime is necessary for caturday check and logging
import datetime
import zoneinfo

# these imports are to use github apis to do logging, base64 is to parse the json
# import requests # already imported for something else
import base64

# adding a hugginface login so that we can authenticate
from huggingface_hub import login

# %%
# input variables - x is target follows y is num of posts we want to look through, whichever end criteria we reach first
EMBEDDED_PIC = 'app.bsky.embed.images#view'
EMBEDDED_VID = 'app.bsky.embed.video#view'
# FEED_CATURDAY = 'at://did:plc:pmyqirafcp3jqdhrl7crpq7t/app.bsky.feed.generator/aaad4sb7tyvjw' # this one is old idk why it disappeared but it was still working?
FEED_CATURDAY = 'at://did:plc:tenurhgjptubkk5zf5qhi3og/app.bsky.feed.generator/#caturday'
FEED_SIAMESE = 'at://did:plc:jv3qdc5vxujp6taaa7nte35i/app.bsky.feed.generator/aaac6wmikqyhq'
FEED_CATPICS = 'at://did:plc:q6gjnaw2blty4crticxkmujt/app.bsky.feed.generator/cv:cat'
FEED_CATS = 'at://did:plc:jfhpnnst6flqway4eaeqzj2a/app.bsky.feed.generator/cats'
FEED_TUXEDOCATS = 'at://did:plc:eubjsqnf5edgvcc6zuoyixhw/app.bsky.feed.generator/tuxedo-cats'
FEED_NAME = {FEED_CATURDAY: "'Caturday'", FEED_SIAMESE: "'Siamese Cats'", FEED_CATPICS: "'Cat Pics'", FEED_CATS: "'Cats!'", FEED_TUXEDOCATS: "'Tuxedo Cats'"}
URL_BEGIN = 'https://bsky.app/profile/'
URL_POST = '/post/'
# my did to check against
MY_DID = 'did:plc:ktkc7jfakxzjpooj52ffc6ra'

# query creation constants
SCHEMA = '"bsky"'
TABLE_FOLLOWS = '"follows"'
COL_USERID = 'user_id'
COL_USERHANDLE = 'user_handle'
COL_FOLLOWURI = 'follow_uri'
COL_FOLLOWDATE = 'follow_date'
COL_FOLLOWSYOU = 'follows_you'
DATETIME_NOW = 'NOW()'
END_LINE = ','
END_QUERY = ';'
TABLE_POSTS = '"posts"'
COL_POSTCID = 'post_cid'
COL_SEENTIME = 'seen_time'

CATURDAY_DOW = 'Saturday'
USER_TIMEZONE = "US/Eastern" # you should fill this in with your own timezone here

LINE_BREAK = '\n'
END_LOGGING = '\n____________________\n'

# on colab you can set these userdata properties by clicking the key on the left bar, creating a secret, and giving the colab "notebook access"
BSKY_USERNAME = userdata.get('bsky_username')
BSKY_PASSWORD = userdata.get('bsky_password')
GITHUB_TOKEN = userdata.get('github_token')
GITHUB_REPO = userdata.get('github_user/repo') # this value should be <your github username>/<your repo name>
HUGGINGFACE_TOKEN = userdata.get('hugging_token')
FILE_PATH = "LOGGING_001.txt"  # Replace with the file path in your repo
BRANCH = "main"  # Replace with your branch name

# %%
# log in to huggingface to authenticate
login(HUGGINGFACE_TOKEN)

# %%
# vision transformer documentation - https://huggingface.co/docs/transformers/v4.13.0/en/model_doc/vit
# guide to using vision transformer from DataCamp - https://www.youtube.com/watch?v=WQMDZniQgj4

# Load the feature extractor for the vision transformer
feature_extractor = ViTImageProcessor.from_pretrained('google/vit-base-patch16-224')
# Load the pre-trained weights from vision transformer
model = ViTForImageClassification.from_pretrained('google/vit-base-patch16-224')

# %% [markdown]
# ### delete posts in the cache that are too old to matter
# ```
# DELETE FROM "bsky"."posts"
# WHERE seen_time < NOW() - INTERVAL '1 DAY'
# RETURNING *;
# ```
#
# ### get the remaining existing post entries from the database with this query
# ```
# SELECT post_cid FROM "bsky"."posts";
# ```
#
# ### copy the post ids into the code block below. Here is replacement text so you can ```ctrl+a del``` it when you're done
#
# ```
# # paste cached post ids here
# cached_posts = """
#
# """
# ```
#
# # ⭐⭐⭐⭐⭐⭐⭐⭐ this is what you are looking for

# %%
# paste cached post ids here
cached_posts = """

"""

# %%
# now we can split the raw output into lines and turn them into a hashset
cached_posts = set(cached_posts.strip().split('\n'))
seen_posts = set()

print(f'imported {len(cached_posts)} prior seen posts from "posts" table')
print(f'{len(seen_posts)} is the size of our seen posts set -- it should be 0')
# Out:
# imported 1 prior seen posts from "posts" table
# 0 is the size of our seen posts set -- it should be 0

# %%
# 281: 'tabby, tabby cat'
# 282: 'tiger cat', 283: 'Persian cat', 284: 'Siamese cat, Siamese', 285: 'Egyptian cat', 286: 'cougar, puma, catamount, mountain lion, painter, panther, Felis concolor', 287: 'lynx, catamount', 288: 'leopard, Panthera pardus', 289: 'snow leopard, ounce, Panthera uncia', 290: 'jaguar, panther, Panthera onca, Felis onca', 291: 'lion, king of beasts, Panthera leo', 292: 'tiger, Panthera tigris', 293: 'cheetah, chetah, Acinonyx jubatus',
# 281 to 293
cat_labels = set()
for i in range(281, 294):
  cat_labels.add(i)

# these labels are to remove drawings, memes/reposts, and images with a lot of text respectively
bad_labels = {
917 : 'comic book', 916 : 'web site, website, internet site, site', 921 : 'book jacket, dust cover, dust jacket, dust wrapper'}

def test_bsky_image(url):
  f = urllib.request.urlopen(url)
  image = plt.imread(f, format='jpeg')
  # plt.imshow(image)
  inputs = feature_extractor(images=image, return_tensor="pt")
  pixel_values = inputs["pixel_values"]
  pixel_values = np.array(pixel_values)
  pixel_values = torch.tensor(pixel_values)
  outputs = model(pixel_values)
  logits = outputs.logits
  predicted_class_idx = logits.argmax(-1).item()
  sorted_preds = torch.argsort(logits, descending=True)[0]
  top_predictions = [sorted_preds[i].item() for i in range(50)] # 50 is semi-arbitrary based on our findings from testing pics # could see tuning this down to 40 but can't tell if it would pick up more or less cats
  top_values = [logits[0][pred].item() for pred in top_predictions]
  # print('label predictions', top_predictions)
  # print('values of predictions', top_values)
  found_cat_label = -1
  found_bad_label = -1
  bad_labels_found = []
  cat_score = 0
  for i, pred in enumerate(top_predictions):
    predicted_class = model.config.id2label[pred]
    # print(predicted_class)
    if pred in cat_labels:
      if found_cat_label == -1:
        found_cat_label = i
      cat_score += top_values[i]
    if pred in bad_labels:
      if found_bad_label == -1:
        found_bad_label = i
      bad_labels_found.append(pred)
      bad_labels_found.append(bad_labels[pred])
      cat_score -= top_values[i]
  # print(' ')
  print('    found cat label:', found_cat_label)
  print('    found bad label:', found_bad_label, bad_labels_found)
  would_pass = found_cat_label >= 0 and found_bad_label < 0
  # print('AI cat score: ', cat_score)
  # print('    passed cat test:', would_pass)
  return would_pass

# %%
# LOG IN TO THE CLIENT
client = Client()
client.login(BSKY_USERNAME, BSKY_PASSWORD)
# Out:
# ProfileViewDetailed(did='did:plc:ktkc7jfakxzjpooj52ffc6ra', handle='tyrowo.com', associated=ProfileAssociated(chat=None, feedgens=0, labeler=False, lists=0, starter_packs=0, py_type='app.bsky.actor.defs#profileAssociated'), avatar='https://cdn.bsky.app/img/avatar/plain/did:plc:ktkc7jfakxzjpooj52ffc6ra/bafkreiepqgg5tlozvv4bw5ficwwixflfprionhnli26hngc3hjn6ygpamu@jpeg', banner='https://cdn.bsky.app/img/banner/plain/did:plc:ktkc7jfakxzjpooj52ffc6ra/bafkreierasgybimbz3pfobqfmay5ufxm7jlqnjeiumdx7dyof6mcss7a4m@jpeg', created_at='2023-08-28T14:18:41.780Z', description='Cat poster. Self-taught professional software developer, exF2P MTG Arena Challenger, ex wr holder speedrunning HotD2_100%, ex streamer, ex melee player. \nGrilling, coding, gaming, magic:tg, tcgs, and my kitty, Ricky 😻\nhe/him', display_name='Tyro, ft Ricky', followers_count=7562, follows_count=13487, indexed_at='2025-02-01T19:55:23.213Z', joined_via_starter_pack=None, labels=[], pinned_post=Main(cid='bafyreihszjgxkh5fmu5je5eldv6i27ubndfcyhwcbjsin4jsbfo2gu45ky', uri='at://did:plc:ktkc7jfakxzjpooj52ffc6ra/app.bsky.feed.post/3lcbntv5rmc2j', py_type='com.atproto.repo.strongRef'), posts_count=289, viewer=ViewerState(blocked_by=False, blocking=None, blocking_by_list=None, followed_by=None, following=None, known_followers=KnownFollowers(count=6766, followers=[ProfileViewBasic(did='did:plc:kivgunx5jnczrj2egcjuqrcr', handle='agirlcalledlina.bsky.social', associated=ProfileAssociated(chat=ProfileAssociatedChat(allow_incoming='following', py_type='app.bsky.actor.defs#profileAssociatedChat'), feedgens=None, labeler=None, lists=None, starter_packs=None, py_type='app.bsky.actor.defs#profileAssociated'), avatar='https://cdn.bsky.app/img/avatar/plain/did:plc:kivgunx5jnczrj2egcjuqrcr/bafkreic3xmutwzlqe5m52cua4aosucnkltmbnmyx2qa35gmahua4cpnene@jpeg', created_at='2023-04-27T20:51:47.311Z', display_name='✨ LINA• لينا ✨', labels=[], viewer=ViewerState(blocked_by=False, blocking=None, blocking_by_list=None, followed_by='at://did:plc:kivgunx5jnczrj2egcjuqrcr/app.bsky.graph.follow/3lhpejdntqu2b', following='at://did:plc:ktkc7jfakxzjpooj52ffc6ra/app.bsky.graph.follow/3lhpec5xb4423', known_followers=None, muted=False, muted_by_list=None, py_type='app.bsky.actor.defs#viewerState'), py_type='app.bsky.actor.defs#profileViewBasic'), ProfileViewBasic(did='did:plc:3awc6f2orurtpccg3l2ayr4v', handle='mitdasein.bsky.social', associated=ProfileAssociated(chat=ProfileAssociatedChat(allow_incoming='following', py_type='app.bsky.actor.defs#profileAssociatedChat'), feedgens=None, labeler=None, lists=None, starter_packs=None, py_type='app.bsky.actor.defs#profileAssociated'), avatar='https://cdn.bsky.app/img/avatar/plain/did:plc:3awc6f2orurtpccg3l2ayr4v/bafkreieqlxn7p6clfipkecxhl3tzu2d26unygknuqoprmaruzqrwhv3xna@jpeg', created_at='2023-06-21T22:05:28.914Z', display_name='Semiotic Stochastic wants a kidney 🇵🇸', labels=[], viewer=ViewerState(blocked_by=False, blocking=None, blocking_by_list=None, followed_by='at://did:plc:3awc6f2orurtpccg3l2ayr4v/app.bsky.graph.follow/3lhpqib2xay22', following='at://did:plc:ktkc7jfakxzjpooj52ffc6ra/app.bsky.graph.follow/3lhpq5etmoo25', known_followers=None, muted=False, muted_by_list=None, py_type='app.bsky.actor.defs#viewerState'), py_type='app.bsky.actor.defs#profileViewBasic'), ProfileViewBasic(did='did:plc:wpsxiky25uq2irj6lw6ognje', handle='vxo.bsky.social', associated=None, avatar='https://cdn.bsky.app/img/avatar/plain/did:plc:wpsxiky25uq2irj6lw6ognje/bafkreihvspncv4cric42v5a56sugcc5pk5vt3faa5ro3vpfwuven7mkbpa@jpeg', created_at='2023-06-10T02:50:07.671Z', display_name='vxo', labels=[], viewer=ViewerState(blocked_by=False, blocking=None, blocking_by_list=None, followed_by='at://did:plc:wpsxiky25uq2irj6lw6ognje/app.bsky.graph.follow/3lhafmsemj22e', following='at://did:plc:ktkc7jfakxzjpooj52ffc6ra/app.bsky.graph.follow/3lh5wqgtthb2d', known_followers=None, muted=False, muted_by_list=None, py_type='app.bsky.actor.defs#viewerState'), py_type='app.bsky.actor.defs#profileViewBasic ...

# %%
# initiate the string to add to our logger file
following = client.get_profile(actor=BSKY_USERNAME).follows_count
followers = client.get_profile(actor=BSKY_USERNAME).followers_count
cur_timestamp = datetime.datetime.now(zoneinfo.ZoneInfo(USER_TIMEZONE))
# print(cur_timestamp)
logging_text = LINE_BREAK + str(cur_timestamp) + LINE_BREAK + 'FINDING NEW FOLLOWERS' + LINE_BREAK + LINE_BREAK + 'prior follower count: ' + str(followers) + LINE_BREAK + 'previously following: ' + str(following) + LINE_BREAK + LINE_BREAK
print(logging_text)
# logging_stats = {}
# Out:
# 2025-02-12 14:54:44.892798-05:00
# FINDING NEW FOLLOWERS
#
# prior follower count: 7562
# previously following: 13487

# %%
def like_post_and_add_user(post):
  user_did = post.author.did
  followed_user = client.follow(user_did).uri
  post_cid = post.cid
  post_uri = post.uri
  liked_post = client.like(uri=post_uri, cid=post_cid).uri
  print(f'      ✓✓✓ ✅ Successfully liked post and followed user: {post.author.handle}')
  return followed_user

# %%
def get_post_follow_likers(post_uri, like_count, users_added_query_values, already_added_dids, max_new_followers):
  # need to try opening post, get the list of likers, iterate through following them, add each to the users added
  new_follows_count = 0
  likes_remaining = like_count
  try:
    while likes_remaining > 0:
      if (likes_remaining > 100):
        print(f'        Starting new page of likes. {likes_remaining} likes remaining to check on this post.')
      limit = min(likes_remaining, 100)
      likes_remaining -= limit
      next_page = ''
      response = client.get_likes(uri = post_uri, limit= limit, cursor= next_page)
      likes = response.likes
      next_page = response.cursor

      for like in likes:
        you_follow_them = like.actor.viewer.following
        you_are_followed_by = like.actor.viewer.followed_by
        user_did = like.actor.did
        user_handle = like.actor.handle
        if you_follow_them or you_are_followed_by or user_did == MY_DID or user_did in already_added_dids:
          print(f'        Already seen user. handle: {user_handle}')
          continue
        else:
          # like the user
          follow_uri = client.follow(user_did).uri
          date_added = DATETIME_NOW
          follows_you = 'FALSE'
          users_added_query_values.append(f"    ('{user_did}', '{user_handle}', '{follow_uri}', {date_added}, {follows_you}) ")
          print(f'        Followed post-liker. handle: {user_handle}')
          already_added_dids.add(user_did)
          new_follows_count += 1
          if new_follows_count >= max_new_followers:
            break
      # print(f'from {len(likes)} likes on this post you followed {new_followers_count}, saw {follow_them_count} users you already follow, and saw {followed_by_count} users that already follow you')
  except Exception as e:
    print(f'ERROR: THERE WAS AN ISSUE CHECKING THIS POST FOR LIKES. \n{e}')
  return new_follows_count

# %%
def createPostUrl(feed_post):
  url_handle = feed_post.post.author.handle
  url_ending_index = feed_post.post.uri.find('.feed.post/') + 11
  url_ending = feed_post.post.uri[url_ending_index : ]
  return URL_BEGIN + url_handle + URL_POST + url_ending

def follow_more_users(post_count, follows_count, feed):
  if post_count == 0 or follows_count == 0:
    return []
  posts_to_check = post_count
  successful_cat_post_like_count = 4
  max_errors_allowed = 5
  next_page = ''
  new_follow_count_from_posts = 0
  new_follow_count_from_likes = 0
  page_count = 0
  users_followed_query_values = []
  already_added_dids = set()

  logging_posts = 0
  logging_pics = 0
  logging_errors_count = 0
  logging_errors_description = []
  logging_notcat = 0
  logging_cat = 0
  logging_vid = 0
  logging_nomedia = 0
  logging_alreadyfollowed = 0
  logging_mutuals = 0
  logging_myposts = 0
  logging_seenpost = 0
  global logging_text
  logging_text = logging_text + f'Feed {FEED_NAME[feed]}:' + LINE_BREAK

  def log_results():
    global logging_text
    sum_new_follows = new_follow_count_from_posts + new_follow_count_from_likes
    sum_skipped_posts = logging_seenpost + logging_alreadyfollowed + logging_myposts
    sum_unprocessed = logging_nomedia + logging_vid
    print(f'followed {sum_new_follows} new users. {new_follow_count_from_posts} posters and {new_follow_count_from_likes} likers.')
    logging_text = logging_text + f'  Followed {sum_new_follows} new user{"s" if sum_new_follows != 1 else ""}{"!" if sum_new_follows > 0 else "."}' + LINE_BREAK
    logging_text = logging_text + f'    Of those follows, {new_follow_count_from_posts} were posters and {new_follow_count_from_likes} were from likes.' + LINE_BREAK
    logging_text = logging_text + f'  {logging_posts} posts in total were viewed during this run.' + LINE_BREAK
    logging_text = logging_text + f'  Skipped Posts: ({sum_skipped_posts}) - {logging_seenpost} posts were previously seen, {logging_alreadyfollowed} were from users already followed, {logging_myposts} were your posts.' + LINE_BREAK
    logging_text = logging_text + f'  Mutuals: {logging_mutuals} posts were from users that follow you, and these posts were liked.' + LINE_BREAK
    logging_text = logging_text + f'  Unprocessed: ({sum_unprocessed}) - {logging_nomedia} posts had no media attached, and {logging_vid} posts had videos attached.' + LINE_BREAK
    logging_text = logging_text + f'  Processed: {logging_pics} posts had pics attached: {logging_cat} were identified as cat pics and {logging_notcat} were not cats.' + LINE_BREAK
    logging_text = logging_text + f'  {"No errors were encountered while processing pics." if logging_errors_count == 0 else str(logging_errors_count) + " ERROR(S) ENCOUNTERED PROCESSING PICS FROM THIS FEED"} ' + LINE_BREAK
    if logging_errors_count > 0:
      logging_text = logging_text + ';; \n'.join(logging_errors_description) + LINE_BREAK
    logging_text = logging_text + LINE_BREAK # one last line break to get ready for the next entry


  while posts_to_check > 0:
    print(f'[checking page {page_count} of feed {FEED_NAME[feed]}, {posts_to_check} posts left to check, and have found {new_follow_count_from_posts + new_follow_count_from_likes} new users to follow]')
    page_count += 1
    limit = min(posts_to_check, 100)
    posts_to_check -= limit
    try:
      data = client.app.bsky.feed.get_feed({
          'feed': 'at://did:plc:jfhpnnst6flqway4eaeqzj2a/app.bsky.feed.generator/cats',
          'limit': limit,
          'cursor': next_page
      }, headers={})
      next_page = data.cursor

      for i, f in enumerate(data.feed):
        you_follow_them = f.post.author.viewer.following
        you_are_followed_by = f.post.author.viewer.followed_by
        did = f.post.author.did
        post_cid = f.post.cid

        logging_posts += 1
        if did == MY_DID:
          print(f'{i} - 😎 skipped. This was your own post.')
          logging_myposts += 1
          continue
        elif post_cid in cached_posts or post_cid in seen_posts:
          print(f'{i} - 👀 skipped. Post with cid {post_cid} has already been viewed. Found in {"db cache" if post_cid in cached_posts else "current set"}.')
          logging_seenpost += 1
          continue
        else:
          seen_posts.add(post_cid)
          # TODO: the way I have it if you are following them you never check the photo to see if it's a good one to get the likes from.
          if you_follow_them and you_are_followed_by:
            print(f'{i} 💕 user: {f.post.author.handle} is a mutual follower. Liking this post. {createPostUrl(f)}')
            # this can break if you get rate limited. So far hasn't broken when posts are deleted but should have been wrapped in one just in case
            try:
              liked_post = client.like(uri=f.post.uri, cid=f.post.cid).uri
            except Exception as e:
              logging_errors_count += 1
              print(f'    ✓✗ ‼️ liking post {i} caused an error. {logging_errors_count} errors seen this run.\n{e}')
              logging_errors_description.append(f'{i}. {e}')
              # got rate limited and know that if you hit like 100 errors or so you'll eventually get a timeout and the entire nootebook will be borked.
              if logging_errors_count >= max_errors_allowed:
                print(f'seen more errors ({logging_errors_count}) than the acceptable number of errors ({max_errors_allowed}). terminating run.')
                log_results()
                return users_followed_query_values

            logging_mutuals += 1
          elif did in already_added_dids:
            print(f'{i} ✗ 👀 user: {f.post.author.handle} was already followed in this batch.')
            logging_alreadyfollowed += 1
          elif you_follow_them or you_are_followed_by:
            print(f'{i} ✗ 👀 user: {f.post.author.handle} {"already follows you." if you_are_followed_by else ""}{"is already being followed." if you_follow_them else ""}')
            logging_alreadyfollowed += 1
          elif not f.post.embed or f.post.embed.py_type != EMBEDDED_PIC:
            if f.post.embed.py_type == EMBEDDED_VID:
              print(f'{i} ✗ 🎥 video post: {createPostUrl(f)}')
              logging_vid += 1
            else:
              print(f'{i} ✗ 🔲 no pic for post {i}')
              logging_nomedia += 1
          else:
            print(i, '✓', '📷', f.post.embed.images[0].fullsize)
            print(f'    post: {createPostUrl(f)}')
            logging_pics += 1
            try:
              handle = f.post.author.handle
              print(f'    user: {handle}')
              is_cat = test_bsky_image(f.post.embed.images[0].fullsize)
              if is_cat:
                print(f'    ✓✓ 😺 successfully found cat pic at post {i}. It has {f.post.like_count} likes.')
                new_follow_count_from_posts += 1
                logging_cat += 1
                follow_uri = like_post_and_add_user(f.post)
                date_added = DATETIME_NOW
                follows_you = 'FALSE'
                users_followed_query_values.append(f"    ('{did}', '{handle}', '{follow_uri}', {date_added}, {follows_you}) ")
                already_added_dids.add(did)
                # so we have a cat post. If it is a solid or particularly good cat post it should probably have a lot of likes, and we can go in and follow all those likers
                if f.post.like_count >= successful_cat_post_like_count:
                  print(f'      👍🏻 This cat post got {f.post.like_count}, and I would call it successful, so following its likers.')
                  likers_added = get_post_follow_likers(f.post.uri, f.post.like_count, users_followed_query_values, already_added_dids, follows_count - (new_follow_count_from_posts + new_follow_count_from_likes))
                  print(f'      {"✅" if likers_added > 0 else "0️⃣"} Added {likers_added} users that liked that post.')
                  new_follow_count_from_likes += likers_added
                if new_follow_count_from_posts + new_follow_count_from_likes >= follows_count:
                  print(f'Successfully followed the desired number of new users! breaking out of loop.')
                  break
              else:
                print(f'    ✓✗ ❌ post {i} was not a cat pic')
                logging_notcat += 1
            except Exception as e:
              logging_errors_count += 1
              print(f'    ✓✗ ❓ post {i} image caused an error. {logging_errors_count} errors seen this run.\n{e}')
              print(f'errors ({logging_errors_count}), acceptable number of errors ({max_errors_allowed}).')
              logging_errors_description.append(f'{i}. {e}')
              # got rate limited and know that if you hit like 100 errors or so you'll eventually get a timeout and the entire notebook will be borked.
              if logging_errors_count >= max_errors_allowed:
                print(f'seen more errors ({logging_errors_count}) than the acceptable number of errors ({max_errors_allowed}). terminating run.')
                log_results()
                return users_followed_query_values
    except Exception as e:
      print(f'error encountered from trying to get feed. terminating run.\n{repr(e)}: {e}')
      logging_errors_count += 1
      logging_errors_description.append('CRITICAL ERROR ENCOUNTERED WHILE GETTING FEED:')
      logging_errors_description.append(f'{repr(e)}: {e}')
      log_results()
      return users_followed_query_values
  log_results()
  return users_followed_query_values

    # print(data.feed[0].post.embed.images[0].fullsize)

# %%
# extracting a separate method
def generate_insert_query(rows_list):
  if not rows_list:
    print('NO CHANGES NECESSARY')
    return
  values = ', \n'.join(rows_list)
  print(f'INSERT INTO {SCHEMA}.{TABLE_FOLLOWS} ({COL_USERID}, {COL_USERHANDLE}, {COL_FOLLOWURI}, {COL_FOLLOWDATE}, {COL_FOLLOWSYOU}) ')
  print(f'VALUES ')
  print(values)
  print(f'RETURNING {COL_USERHANDLE}, {COL_FOLLOWDATE}{END_QUERY}')

# %%
# CATURDAY -- THIS IS THE BEGINNING OF THE RUNS
cur_timestamp = datetime.datetime.now(zoneinfo.ZoneInfo(USER_TIMEZONE))

dow = cur_timestamp.strftime("%A")
is_caturday = dow == CATURDAY_DOW
query_caturday = []

if is_caturday:
  print("IT'S CATURDAY! Checking the Caturday feed for new followers.")
  query_caturday = follow_more_users(posts_caturday, follows_caturday, FEED_CATURDAY)
else:
  print("Sorry, today's not Caturday.")
# Out:
# Sorry, today's not Caturday.

# %%
print(f'adding {len(query_caturday)} new follows from caturday.')
# Out:
# adding 0 new follows from caturday.

# %%
generate_insert_query(query_caturday)
# Out:
# NO CHANGES NECESSARY

# %%
query_siamese = []
if is_caturday:
  print("IT'S CATURDAY! Not running this feed as much")
  # query_siamese = follow_more_users(0, 100, FEED_SIAMESE)
else:
  print("Today's not Caturday. Doing the regular routine")
  query_siamese = follow_more_users(posts_othercat, follows_othercat, FEED_SIAMESE)
# Out:
# Today's not Caturday. Doing the regular routine
# [checking page 0 of feed 'Siamese Cats', 100 posts left to check, and have found 0 new users to follow]
# 0 ✓ 📷 https://cdn.bsky.app/img/feed_fullsize/plain/did:plc:5avcmy4dwd2c7fdarraucwa7/bafkreiclrl4sqdptegybggwyxu2f2saywpnvsiiybpe34mgzrl5h2rta4y@jpeg
#     post: https://bsky.app/profile/ashing87.bsky.social/post/3lhywupyjdk2a
#     user: ashing87.bsky.social
# /usr/local/lib/python3.11/dist-packages/transformers/image_processing_utils.py:41: UserWarning: The following named arguments are not valid for `ViTImageProcessor.preprocess` and were ignored: 'return_tensor'
#   return self.preprocess(images, **kwargs)
#     found cat label: 35
#     found bad label: -1 []
#     ✓✓ 😺 successfully found cat pic at post 0. It has 0 likes.
#       ✓✓✓ ✅ Successfully liked post and followed user: ashing87.bsky.social
# 1 ✓ 📷 https://cdn.bsky.app/img/feed_fullsize/plain/did:plc:kbfzsycsztgpwbz7xb7qe23k/bafkreiajcyyoddnkiupgowvefx5f7ynbogolknzfgzym6jbpvtfygy5e6y@jpeg
#     post: https://bsky.app/profile/bopterror.bsky.social/post/3lhywu563yk2p
#     user: bopterror.bsky.social
#     found cat label: 20
#     found bad label: -1 []
#     ✓✓ 😺 successfully found cat pic at post 1. It has 5 likes.
#       ✓✓✓ ✅ Successfully liked post and followed user: bopterror.bsky.social
#       👍🏻 This cat post got 5, and I would call it successful, so following its likers.
#         Followed post-liker. handle: missfoster.bsky.social
#         Followed post-liker. handle: clur.bsky.social
#         Already seen user. handle: broadbean.bsky.social
#         Followed post-liker. handle: paulst001.bsky.social
#         Followed post-liker. handle: stephupnorth.bsky.social
#       ✅ Added 4 users that liked that post.
# 2 ✓ 📷 https://cdn.bsky.app/img/feed_fullsize/plain/did:plc:4tixoizl4fy36fau4cwiz2ms/bafkreidus3yhpdlp5ztfvsfu6iw3bhrs56ovvdnqrbjscirk3xuuolmflu@jpeg
#     post: https://bsky.app/profile/jkmakes.bsky.social/post/3lhywtqntfk2c
#     user: jkmakes.bsky.social
#     found cat label: 46
#     found bad label: -1 []
#     ✓✓ 😺 successfully found cat pic at post 2. It has 0 likes.
#       ✓✓✓ ✅ Successfully liked post and followed user: jkmakes.bsky.social
# 3 ✓ 📷 https://cdn.bsky.app/img/feed_fullsize/plain/did:plc:paq7auao2b7iokmwdkjygvap/bafkreigq5563scww7lnbiawwztkur4jchrbjm2dkop6pyiclufx26mnxqm@jpeg
#     post: https://bsky.app/profile/jetmanjay.bsky.social/post/3lhywtnfbp22e
#     user: jetmanjay.bsky.social
#     found cat label: 0
#     found bad label: -1 []
#     ✓✓ 😺 successfully found cat pic at post 3. It has 2 likes.
#       ✓✓✓ ✅ Successfully liked post and followed user: jetmanjay.bsky.social
# 4 💕 user: attyepi.bsky.social is a mutual follower. Liking this post. https://bsky.app/profile/attyepi.bsky.social/post/3lhywt3gtuc25
# 5 ✓ 📷 https://cdn.bsky.app/img/feed_fullsize/plain/did:plc:wykuu2wbdxpbg5kzs2ru7pvw/bafkreieggqa3ga3eklqi4qpq6m7pg7cyzupwl4tf764gy42drw5qhfgx34@jpeg
#     post: https://bsky.app/profile/turbofrog.bsky.social/post/3lhywsd6nxs2c
#     user: turbofrog.bsky.social
#     found cat label: -1
#     found bad label: 15 [917, 'comic book']
#     ✓✗ ❌ post 5 was not a cat pic
# 6 ✓ 📷 https://cdn.bsky.app/img/feed_fullsize/plain/did:plc:ljmgs4t2u3j7ti56fdjqzwje/bafkreidztbtawmwjfchaiausl6itrutvio72lsxfrmgyeaseduyehx4fc4@jpeg
#     post: https://bsky.app/profile/antodim.bsky.social/post/3lhyws7kaf225
#     user: antodim.bsky.social
#     found cat label: 0
#     found bad label: -1 []
#     ✓✓ 😺 successfully found cat pic at post 6. It has 1 likes.
#       ✓✓✓ ✅ Successfully liked post and followed user: antodim.bsky.social
# 7 ✓ 📷 https://cdn.bsky.app/img/feed_fullsize/plain/did:plc:ob2mfczwcttmx572dwrk4qqi/bafkreih26hxyyhlclatwd2v24eldahz7ru5swtbxsww2qk7c5f4m4tcevi@jpeg
#     post: https://bsky.app/profile/dmciver54.bsky.social/post/3lhyws4f7xk22
#     user: dmciver54.bsky.social
#     found cat label: 2
#     found bad label: 47 [917, 'comic book']
#     ✓✗ ❌ post 7 was not a cat pic
# 8 ✓ 📷 https://cdn.bsky.app/img/feed_fullsize/plain/did:plc:6fjer5dsqkjdr6k2arp7agks/bafkreihkrfh6vybvgth3qb7vyupmtuntkj7yw2opfq23j4wc47b3aodmre@jpeg
#     post: https://bsky.app/profile/eliza-supriza.bsky.social/post/3lhyws33xnk2q
#     user: eliza-supriza.bsky.social
#     found cat label: -1
#     found bad label: 18 [916, 'web site, website, internet site, site']
#     ✓✗ ❌ post 8 was not a cat pic
# 9 ✓ 📷 https://cdn.bsky.app/img/feed_fullsize/plain/did:plc:4mgy2jtozv5w2vkgtygmavde/bafkreigeph3qb6mt3j5pfd23c4jb4vtsoywsms3usxaolzhcnfvsxaukle@jpeg
#     post: https://bsky.app/profile/s3062072.bsky.social/post/3lhywrdhask2w
#     user: s3062072.bsky.social
#     found cat label: 0
#     found bad label: -1 []
#     ✓✓ 😺 successfully found cat pic at post 9. It has 3 likes.
#       ✓✓✓ ✅ Successfully liked post and followed user: s3062072.bsky.social
# 10 ✓ 📷 https://cdn.bsky.app/img/feed_fullsize/plain/did:plc:tisuagfv7lb75rvk6stxugs7/bafkreigpzjhvpl6vh6bwey75m6odwt773g6ytuqrluhourz3ufqioqbjvq@jpeg
#     post: https://bsky.app/profile/mkebecky.bsky.social/post/3lhywr4zook2k
#     user: mkebecky.bsky.social
#     found cat label: 0
#     found bad label: -1 []
#     ✓✓ 😺 successfully found cat pic at post 10. It has 1 likes.
#       ✓✓✓ ✅ Successfully liked post and followed user: mkebecky.bsky.social
# 11 💕 user: lemonmeringuepi.bsky.social is a mutual follower. Liking this post. https://bsky.app/profile/lemonmeringuepi.bsky.social/post/3lhywqdafis2m
# 12 ✓ 📷 https://cdn.bsky.app/img/feed_fullsize/plain/did:plc:cvohvkqjrvovgnhyr62c3yuy/bafkreiehasmdqu2vrqrcfcxxyibh2pfwa3kalbb44izxwjuz5zdl6vk2wm@jpeg
#     post: https://bsky.app/profile/pushpullseattle.bsky.social/post/3lhywqcgjes24
#     user: pushpullseattle.bsky.social
#     found cat label: 0
#     found bad label: 32 [916, 'web site, website, internet site, site']
#     ✓✗ ❌ post 12 was not a cat pic
# 13 💕 user: poshoandtoast.bsky.social is a mutual follower. Liking this post. https://bsky.app/profile/poshoandtoast.bsky.social/post/3lhywpo2qwk2o
# 14 ✓ 📷 https://cdn.bsky.app/img/feed_fullsize/plain/did:plc:s3cgpkxt2vsy7k4wsvyfffhm/bafkreihvqnsihksrto5j2575otkfwgsct725nt54csyrcetf7fk6gpvyny@jpeg
#     post: https://bsky.app/profile/cryptidmarsz.bsky.social/post/3lhywpncens2i
#     user: cryptidmarsz.bsky.social
#     found cat label: 12
#     found bad label: 15 [916, 'web site, website, internet site, site', 917, 'comic book']
#     ✓✗ ❌ post 14 was not a cat pic
# 15 ✓ 📷 https://cdn.bsky.app/img/feed_fullsize/plain/did:plc:zlhs33h5d67c4u5vnmepfq2m/bafkreihzinp2ou5rzdvg6cxfyqzozqu3f2bohfrosol3d647lns7nx3c5e@jpeg
#     post: https://bsky.app/profile/elizahowdy.bsky.social/post/3lhywowvgbk22
#     user: elizahowdy.bsky.social
#     found cat label: -1
#     found bad label: 8 [921, 'book jacket, dust cover, dust jacket, dust wrapper', 917, 'comic book']
#     ✓✗ ❌ post 15 was not a cat pic
# 16 ✓ 📷 https://cdn.bsky.app/img/feed_fullsize/plain/did:plc:3k2fu5cereuj6mx4jnavvtyc/bafkreiak7dhs5lcuhemtn7ojr7n5vqcr5ci4vqjb7yzl4r6b2hnwki24va@jpeg
#     post: https://bsky.app/profile/crowlines.net/post/3lhywomnutc2d
#     user: crowlines.net
#     found cat label: -1
#     found bad label: -1 []
#     ✓✗ ❌ post 16 was not a cat pic
# 17 ✓ 📷 https://cdn.bsky.app/img/feed_fullsize/plain/did:plc:3jju2baoa5ggg6iul4oeh5ic/bafkreih4kih6ul6dqoxix7pjtutbw4h2jpfjhwfs7rjs4bzi6mxha34bii@jpeg
#     post: https://bsky.app/profile/ycatstacy.bsky.social/post/3lhywofsgek2k
#     user: ycatstacy.bsky.social
#     found cat label: 0
#     found bad label: -1 []
#     ✓✓ 😺 successfully found cat pic at post 17. It has 3 likes.
#       ✓✓✓ ✅ Successfully liked post and followed user: ycatstacy.bsky.social
# 18 ✓ 📷 https://cdn.bsky.app/img/feed_fullsize/plain/did:plc:opfhj7idx7f5s7kcc436ovcy/bafkreignfokn5ghb5k4hustlx7izenignz7odpndthdxeefrri3sn2sd74@jpeg
#     post: https://bsky.app/profile/seanrfrazier.com/post/3lhywoauzb22w
#     user: seanrfrazier.com
#     found cat label: 2
#     found bad label: -1 []
#     ✓✓ 😺 successfully found cat pic at post 18. It has 6 likes.
#       ✓✓✓ ✅ Successfully liked post and followed user: seanrfrazier.com
#       👍🏻 This cat post got 6, and I would call it successful, so following its likers.
#         Followed post-liker. handle: lotuscarroll.bsky.social
#         Already seen user. handle: piikotheartist.bsky.social
#         Followed post-liker. handle: sunflowerszsky.bsky.social
#         Followed post-liker. handle: theshaggyshepherd.bsky.social
#         Followed post-liker. handle: druidcat.bsky.social
#         Already seen user. handle: maladjustined.bsky.social
#       ✅ Added 4 users that liked that post.
# 19 ✓ 📷 https://cdn.bsky.app/img/feed_fullsize/plain/did:plc:xpy25dsjcfoycadlhog353pg/bafkreifkbzruu2drqwj5whu6adglrsimfnnchpwconihawlkxeckejfyfm@jpeg
#     post: https://bsky.app/profile/aunthagatha.bsky.social/post/3lhywo7xnsk2h
#     user: aunthagatha.bsky.social
#     found cat label: 0
#     found bad label: 9 [916, 'web site, website, internet site, site', 921, 'book jacket, dust cover, dust jacket, dust wrapper']
#     ✓✗ ❌ post 19 was not a cat pic
# 20 ✗ 🎥 video post: https://bsky.app/profile/meetcharliechap.bsky.social/post/3lhywo7ln222g
# 21 ✓ 📷 https://cdn.bsky.app/img/feed_fullsize/plain/did:plc:gztqch4f3zno5cmkt32hhzvg/bafkreicazitce5ywswrtvmgtzzte5rmbbdnaa6au5ht6xxxxseeiojqoce@jpeg
#     post: https://bsky.app/profile/satanistfather.bsky.social/post/3lhywnjbmfs2y
#     user: satanistfather.bsky.social
#     found cat label: -1
#     found bad label: 0 [916, 'web site, website, internet site, site', 921, 'book jacket, dust cover, dust jacket, dust wrapper']
#     ✓✗ ❌ post 21 was not a cat pic
# 22 ✗ 👀 user: ricericemommy.bsky.social is already being followed.
# 23 ✓ 📷 https://cdn.bsky.app/img/feed_fullsize/plain/did:plc
://cdn.bsky.app/img/feed_fullsize/plain/did:plc:mdhfktfdxxnz4mh3hv6sr4vw/bafkreifqhdhnc6hoapgzmqrgsaucuqaysbcimph3kvezfjodq6nomorg6u@jpeg
#     post: https://bsky.app/profile/slothandemma.bsky.social/post/3lhywlaesyk2d
#     user: slothandemma.bsky.social
#     found cat label: -1
#     found bad label: 0 [917, 'comic book', 921, 'book jacket, dust cover, dust jacket, dust wrapper', 916, 'web site, website, internet site, site']
#     ✓✗ ❌ post 31 was not a cat pic
# 32 ✗ 🎥 video post: https://bsky.app/profile/theonlytherapist.bsky.social/post/3lhywktkoxs2c
# 33 ✓ 📷 https://cdn.bsky.app/img/feed_fullsize/plain/did:plc:cj7injihakqpladrdouch7n3/bafkreibujs27enmuqvhvfalkxezaefrzkoo5fso7tbxnyf7pydgeoyju6e@jpeg
#     post: https://bsky.app/profile/zonisic.bsky.social/post/3lhywkoalmc22
#     user: zonisic.bsky.social
#     found cat label: -1
#     found bad label: 0 [917, 'comic book', 921, 'book jacket, dust cover, dust jacket, dust wrapper', 916, 'web site, website, internet site, site']
#     ✓✗ ❌ post 33 was not a cat pic
# 34 ✗ 🔲 no pic for post 34
# 35 ✓ 📷 https://cdn.bsky.app/img/feed_fullsize/plain/did:plc:3vhktcjk3l6g76m2iq74nbxu/bafkreih7xyud2ukabbjcskzkongnsaw2zxe53o52lgpbdj276cv4d2vr4q@jpeg
#     post: https://bsky.app/profile/tommymacyv.bsky.social/post/3lhywkcuiak2y
#     user: tommymacyv.bsky.social
#     found cat label: 7
#     found bad label: 0 [917, 'comic book', 916, 'web site, website, internet site, site', 921, 'book jacket, dust cover, dust jacket, dust wrapper']
#     ✓✗ ❌ post 35 was not a cat pic
# 36 ✓ 📷 https://cdn.bsky.app/img/feed_fullsize/plain/did:plc:pl7xs6bib3tecwpaborngsxr/bafkreid7gghdea5uybsopxraknww5ktasxmry67ycbtc4mr3vd7eynyijq@jpeg
#     post: https://bsky.app/profile/captaintrashi.bsky.social/post/3lhywkch5ic24
#     user: captaintrashi.bsky.social
#     found cat label: -1
#     found bad label: 1 [917, 'comic book']
#     ✓✗ ❌ post 36 was not a cat pic
# 37 ✗ 🔲 no pic for post 37
# 38 💕 user: joliehawk.bsky.social is a mutual follower. Liking this post. https://bsky.app/profile/joliehawk.bsky.social/post/3lhywittvr227
# 39 ✓ 📷 https://cdn.bsky.app/img/feed_fullsize/plain/did:plc:radu3psyqkqr564sn6wrixkl/bafkreid5l35s5wdzlalykck2lbfqvxhogrixr5fdmh4u5622vswl5e6bk4@jpeg
#     post: https://bsky.app/profile/diarilaveu.bsky.social/post/3lhywikomyk2p
#     user: diarilaveu.bsky.social
#     found cat label: -1
#     found bad label: 12 [916, 'web site, website, internet site, site']
#     ✓✗ ❌ post 39 was not a cat pic
# 40 💕 user: heshie.bsky.social is a mutual follower. Liking this post. https://bsky.app/profile/heshie.bsky.social/post/3lhywhxpkac2q
# 41 ✓ 📷 https://cdn.bsky.app/img/feed_fullsize/plain/did:plc:pqz2jjsqkcq2d7a74k4mmdf4/bafkreidjaoubaymcr6p44fqb5tfs7kwv5repig3ni7dkq4fdzphc3co37q@jpeg
#     post: https://bsky.app/profile/bibicosplays.bsky.social/post/3lhywh445ok2t
#     user: bibicosplays.bsky.social
#     found cat label: -1
#     found bad label: -1 []
#     ✓✗ ❌ post 41 was not a cat pic
# 42 💕 user: alexainparadise.bsky.social is a mutual follower. Liking this post. https://bsky.app/profile/alexainparadise.bsky.social/post/3lhywgifpu22w
# 43 ✓ 📷 https://cdn.bsky.app/img/feed_fullsize/plain/did:plc:yfrz67ub3laafrcwpbjaayw5/bafkreihtjybct37oqqxd4alswxmnhiebdsetabyqzxtqoyunrvayf5oyru@jpeg
#     post: https://bsky.app/profile/dgoddess2020.bsky.social/post/3lhywgcxins2j
#     user: dgoddess2020.bsky.social
#     found cat label: 0
#     found bad label: -1 []
#     ✓✓ 😺 successfully found cat pic at post 43. It has 1 likes.
#       ✓✓✓ ✅ Successfully liked post and followed user: dgoddess2020.bsky.social
# 44 ✓ 📷 https://cdn.bsky.app/img/feed_fullsize/plain/did:plc:ywm36bbc5kf5qamiwpo35qpq/bafkreibbohxa5uaeyknoazlisbw5g3yciflq6y2w3gdqbph4kwcdap2i5e@jpeg
#     post: https://bsky.app/profile/ohmydog.bsky.social/post/3lhywgasvds2i
#     user: ohmydog.bsky.social
#     found cat label: 0
#     found bad label: -1 []
#     ✓✓ 😺 successfully found cat pic at post 44. It has 2 likes.
#       ✓✓✓ ✅ Successfully liked post and followed user: ohmydog.bsky.social
# 45 ✗ 👀 user: princedrayko.bsky.social is already being followed.
# 46 ✓ 📷 https://cdn.bsky.app/img/feed_fullsize/plain/did:plc:hiuwyfo76as5g4w2wwqfyr4s/bafkreiepkg2yqt63tfbi4kmp3xxtkonygycgnvnrwax2y3npyvlb4arxgq@jpeg
#     post: https://bsky.app/profile/imaprettypeacock.bsky.social/post/3lhywg2qsfs2k
#     user: imaprettypeacock.bsky.social
#     found cat label: 0
#     found bad label: -1 []
#     ✓✓ 😺 successfully found cat pic at post 46. It has 1 likes.
#       ✓✓✓ ✅ Successfully liked post and followed user: imaprettypeacock.bsky.social
# 47 💕 user: betsycooley.bsky.social is a mutual follower. Liking this post. https://bsky.app/profile/betsycooley.bsky.social/post/3lhywfzzhdk2e
# 48 ✗ 🎥 video post: https://bsky.app/profile/chefbobbygregoire.bsky.social/post/3lhywfxpk422w
# 49 ✓ 📷 https://cdn.bsky.app/img/feed_fullsize/plain/did:plc:ygc2fbgsvaegqzhckekwnulc/bafkreiaphlbmg5xgtxui3ymkevnocdja7a2px6vgxhgg2vymvzvpgx52be@jpeg
#     post: https://bsky.app/profile/sonof8bits.com/post/3lhywfwv4fk2l
#     user: sonof8bits.com
#     found cat label: 2
#     found bad label: -1 []
#     ✓✓ 😺 successfully found cat pic at post 49. It has 4 likes.
#       ✓✓✓ ✅ Successfully liked post and followed user: sonof8bits.com
#       👍🏻 This cat post got 4, and I would call it successful, so following its likers.
#         Followed post-liker. handle: winniewormfriend.bsky.social
#         Followed post-liker. handle: roosmarijnr.bsky.social
#         Followed post-liker. handle: abbymachines.bsky.social
#         Followed post-liker. handle: fokkovdleest.bsky.social
#       ✅ Added 4 users that liked that post.
# 50 ✓ 📷 https://cdn.bsky.app/img/feed_fullsize/plain/did:plc
://cdn.bsky.app/img/feed_fullsize/plain/did:plc:paa35aohtvo3bvnspf7k4un5/bafkreib2434y62swmjk3lxb4bqowhjl3thdwtxqrt4venplrxmmfpwkorq@jpeg
#     post: https://bsky.app/profile/angeldeviloshi.bsky.social/post/3lhywcyy76c2q
#     user: angeldeviloshi.bsky.social
#     found cat label: -1
#     found bad label: 0 [916, 'web site, website, internet site, site']
#     ✓✗ ❌ post 56 was not a cat pic
# 57 ✓ 📷 https://cdn.bsky.app/img/feed_fullsize/plain/did:plc:idazfyzvckikm2ud77sqmdbl/bafkreiggpumde6ndfzjsh2xihfwatvkxpsmcncpjhan3u2364p6iuus3g4@jpeg
#     post: https://bsky.app/profile/cannamom13.bsky.social/post/3lhywcrmrxs2j
#     user: cannamom13.bsky.social
#     found cat label: -1
#     found bad label: 17 [921, 'book jacket, dust cover, dust jacket, dust wrapper', 916, 'web site, website, internet site, site']
#     ✓✗ ❌ post 57 was not a cat pic
# 58 ✓ 📷 https://cdn.bsky.app/img/feed_fullsize/plain/did:plc:l3q7n2jl2m3i62svn5qyzhne/bafkreigli6zg6ilvsaqjw5wrobefb32ac4bakwsy346nvqraouthxbxojq@jpeg
#     post: https://bsky.app/profile/corazondemadalena.bsky.social/post/3lhywcklhz22c
#     user: corazondemadalena.bsky.social
#     found cat label: 0
#     found bad label: -1 []
#     ✓✓ 😺 successfully found cat pic at post 58. It has 6 likes.
#       ✓✓✓ ✅ Successfully liked post and followed user: corazondemadalena.bsky.social
#       👍🏻 This cat post got 6, and I would call it successful, so following its likers.
#         Already seen user. handle: corazondemadalena.bsky.social
#         Followed post-liker. handle: javilor.bsky.social
#         Already seen user. handle: thewildimages.bsky.social
#         Already seen user. handle: adictoalacafeina.bsky.social
#         Already seen user. handle: virtualjapan.info
#         Already seen user. handle: lord-xander.bsky.social
#       ✅ Added 1 users that liked that post.
# 59 💕 user: klaravecernice.bsky.social is a mutual follower. Liking this post. https://bsky.app/profile/klaravecernice.bsky.social/post/3lhywcjje7k2r
# 60 ✗ 🎥 video post: https://bsky.app/profile/kobazco.bsky.social/post/3lhywci4wdk2g
# 61 ✓ 📷 https://cdn.bsky.app/img/feed_fullsize/plain/did:plc:wtshsbrz422rucbqxtvdgu7u/bafkreihjs6zsun7ho2id2klejii5akbkrq3k4dhrjzvadvghoqlzbgovne@jpeg
#     post: https://bsky.app/profile/catbrierwood.bsky.social/post/3lhywccixkc22
#     user: catbrierwood.bsky.social
#     found cat label: -1
#     found bad label: -1 []
#     ✓✗ ❌ post 61 was not a cat pic
# 62 ✓ 📷 https://cdn.bsky.app/img/feed_fullsize/plain/did:plc:7zseqxpsjuswjpaxwcnfuyf6/bafkreig6d3vqbzdrtjlxmmshnm7tf3pqwpfi7jlmfyj4nxjxwwr4bti3iq@jpeg
#     post: https://bsky.app/profile/krcwieka.bsky.social/post/3lhywcagils2h
#     user: krcwieka.bsky.social
#     found cat label: 3
#     found bad label: -1 []
#     ✓✓ 😺 successfully found cat pic at post 62. It has 3 likes.
#       ✓✓✓ ✅ Successfully liked post and followed user: krcwieka.bsky.social
# 63 ✓ 📷 https://cdn.bsky.app/img/feed_fullsize/plain/did:plc:ceizbietljjodoza7qwxo3ol/bafkreihmljy7rzjtiym6iqbbkopgccpdict6scgfpxxfjhz76y76qzawfa@jpeg
#     post: https://bsky.app/profile/ciemen.bsky.social/post/3lhywbulml224
#     user: ciemen.bsky.social
#     found cat label: -1
#     found bad label: 47 [916, 'web site, website, internet site, site']
#     ✓✗ ❌ post 63 was not a cat pic
# 64 ✓ 📷 https://cdn.bsky.app/img/feed_fullsize/plain/did:plc:scb4mr6rwsymo7wsklavbca7/bafkreihfz2lbkoan2f3ogta7cs7gxqx5w4tmge53vmpg6uhuip7lgt6jlu@jpeg
#     post: https://bsky.app/profile/catherinexjane.bsky.social/post/3lhywblywjs2g
#     user: catherinexjane.bsky.social
#     found cat label: 8
#     found bad label: -1 []
#     ✓✓ 😺 successfully found cat pic at post 64. It has 1 likes.
#       ✓✓✓ ✅ Successfully liked post and followed user: catherinexjane.bsky.social
# 65 ✓ 📷 https://cdn.bsky.app/img/feed_fullsize/plain/did:plc:hcxawl4wr63mamlqaopkq4sm/bafkreiay5uijs37etb7w34eaqhqot6rcgsfl4zp7ljksra3vg3j2u42xhy@jpeg
#     post: https://bsky.app/profile/lksws.bsky.social/post/3lhywai2abc2m
#     user: lksws.bsky.social
#     found cat label: 0
#     found bad label: 46 [921, 'book jacket, dust cover, dust jacket, dust wrapper']
#     ✓✗ ❌ post 65 was not a cat pic
# 66 ✓ 📷 https://cdn.bsky.app/img/feed_fullsize/plain/did:plc:llin4bdyjesllrstwwsaamov/bafkreictqrvkr3tagaie5fyvpff22m53w2kxlipgnsvchbg4sbqmxeoru4@jpeg
#     post: https://bsky.app/profile/grimvestige.bsky.social/post/3lhywa5vwga25
#     user: grimvestige.bsky.social
#     found cat label: -1
#     found bad label: 1 [917, 'comic book', 921, 'book jacket, dust cover, dust jacket, dust wrapper']
#     ✓✗ ❌ post 66 was not a cat pic
# 67 ✗ 👀 user: kenbuckley.bsky.social is already being followed.
# 68 ✓ 📷 https://cdn.bsky.app/img/feed_fullsize/plain/did:plc:wr42mzg3vc2kxx5picd55vbh/bafkreidfyj5t7u7e6vimqlev3oc2mzgta22mfvkwjzthteak4ndtqvk7t4@jpeg
#     post: https://bsky.app/profile/premisvinari.bsky.social/post/3lhyw7tavnb2w
#     user: premisvinari.bsky.social
#     found cat label: -1
#     found bad label: 0 [916, 'web site, website, internet site, site', 921, 'book jacket, dust cover, dust jacket, dust wrapper', 917, 'comic book']
#     ✓✗ ❌ post 68 was not a cat pic
# 69 ✓ 📷 https://cdn.bsky.app/img/feed_fullsize/plain/did:plc:5ehmuev2jrxezyfpp4j7wlhs/bafkreig63glblzpoekj7oau3jtkdtpnvp6m4elgzn376eeunnenw7tpbku@jpeg
#     post: https://bsky.app/profile/marofthebooks.bsky.social/post/3lhyw7omp7o2b
#     user: marofthebooks.bsky.social
#     found cat label: 44
#     found bad label: 12 [917, 'comic book', 921, 'book jacket, dust cover, dust jacket, dust wrapper']
#     ✓✗ ❌ post 69 was not a cat pic
# 70 ✓ 📷 https://cdn.bsky.app/img/feed_fullsize/plain/did:plc:gccvn3o7uvydlxzpxguzgfcv/bafkreibidjoagsj7jigoxgpfpcgjjtzqbegop7tfbspx2pdtuqp76aoiky@jpeg
#     post: https://bsky.app/profile/echoesandchimes.bsky.social/post/3lhyw6xr4vs2m
#     user: echoesandchimes.bsky.social
#     found cat label: 2
#     found bad label: -1 []
#     ✓✓ 😺 successfully found cat pic at post 70. It has 1 likes.
#       ✓✓✓ ✅ Successfully liked post and followed user: echoesandchimes.bsky.social
# 71 ✓ 📷 https://cdn.bsky.app/img/feed_fullsize/plain/did:plc:frnoi6xhdeosmb5w7b6ynfmi/bafkreiefhpdr3gxvh3jvgpzsphaohlktnk7dpknpcpyp23f4l566etqesa@jpeg
#     post: https://bsky.app/profile/mosiefar-27.bsky.social/post/3lhyw6rx2sk2p
#     user: mosiefar-27.bsky.social
#     found cat label: 0
#     found bad label: -1 []
#     ✓✓ 😺 successfully found cat pic at post 71. It has 3 likes.
#       ✓✓✓ ✅ Successfully liked post and followed user: mosiefar-27.bsky.social
# 72 ✓ 📷 https://cdn.bsky.app/img/feed_fullsize/plain/did:plc:z7yg3yziqbcyxdyvj5d4lipe/bafkreiffoyh2ifetxztzq6irtc7yg2tltzntj7o4enfliayr47milqg4b4@jpeg
#     post: https://bsky.app/profile/ambisocial.bsky.social/post/3lhyw6qtqwc2b
#     user: ambisocial.bsky.social
#     found cat label: -1
#     found bad label: 0 [917, 'comic book', 916, 'web site, website, internet site, site', 921, 'book jacket, dust cover, dust jacket, dust wrapper']
#     ✓✗ ❌ post 72 was not a cat pic
# 73 ✓ 📷 https://cdn.bsky.app/img/feed_fullsize/plain/did:plc:l34gzcydgnzzfdkrke24ojw2/bafkreicj5helzqgk22iymnzamsnicnwngmk4daqbsde42vxumgf5o2gd3m@jpeg
#     post: https://bsky.app/profile/5il0.bsky.social/post/3lhyw6ofvpk2c
#     user: 5il0.bsky.social
#     found cat label: -1
#     found bad label: 0 [916, 'web site, website, internet site, site', 921, 'book jacket, dust cover, dust jacket, dust wrapper', 917, 'comic book']
#     ✓✗ ❌ post 73 was not a cat pic
# 74 ✓ 📷 https://cdn.bsky.app/img/feed_fullsize/plain/did:plc:maydb63u4rzkjnoe2r3fwklj/bafkreigpgfkzakt6r3f6l7gqwprbjuguwopyavq3bjfqqkskclnzrgbu64@jpeg
#     post: https://bsky.app/profile/chrispco.bsky.social/post/3lhyw5honhk24
#     user: chrispco.bsky.social
#     found cat label: 2
#     found bad label: -1 []
#     ✓✓ 😺 successfully found cat pic at post 74. It has 5 likes.
#       ✓✓✓ ✅ Successfully liked post and followed user: chrispco.bsky.social
#       👍🏻 This cat post got 5, and I would call it successful, so following its likers.
#         Already seen user. handle: piikotheartist.bsky.social
#         Already seen user. handle: danlansdowne.bsky.social
#         Followed post-liker. handle: kookaburrasakura.co.nz
#         Followed post-liker. handle: burichu.bsky.social
#         Followed post-liker. handle: terrencemarks.com
#       ✅ Added 3 users that liked that post.
# 75 ✓ 📷 https://cdn.bsky.app/img/feed_fullsize/plain/did:plc:p35hwdhvr2aq3exjmnpvg43b/bafkreihq35puobzyilqnon3yd2hdcokileglfyqpfko56e4kpw4xutnhvu@jpeg
#     post: https://bsky.app/profile/psychojukebox.bsky.social/post/3lhyw5aqi3k2b
#     user: psychojukebox.bsky.social
#     found cat label: 1
#     found bad label: -1 []
#     ✓✓ 😺 successfully found cat pic at post 75. It has 1 likes.
#       ✓✓✓ ✅ Successfully liked post and followed user: psychojukebox.bsky.social
# 76 ✓ 📷 https://cdn.bsky.app/img/feed_fullsize/plain/did:plc:pyu2b24oc2q5nfjoypvaoqxc/bafkreifgnfeodn4gagq7cojhp2lan24kieft4ys44ektwxdfgu7cr5vec4@jpeg
#     post: https://bsky.app/profile/cincat3.bsky.social/post/3lhyw42iack2y
#     user: cincat3.bsky.social
#     found cat label: 3
#     found bad label: -1 []
#     ✓✓ 😺 successfully found cat pic at post 76. It has 1 likes.
#       ✓✓✓ ✅ Successfully liked post and followed user: cincat3.bsky.social
# 77 ✓ 📷 https://cdn.bsky.app/img/feed_fullsize/plain/did:plc:7ehxdsqd7tu357l2ytsjvenx/bafkreifxk45qqjglfzjxe5giqicspr5jkhftleypwszkarctpaef74fnea@jpeg
#     post: https://bsky.app/profile/eliskunk.bsky.social/post/3lhyw2y7im22y
#     user: eliskunk.bsky.social
#     found cat label: -1
#     found bad label: 0 [916, 'web site, website, internet site, site', 917, 'comic book', 921, 'book jacket, dust cover, dust jacket, dust wrapper']
#     ✓✗ ❌ post 77 was not a cat pic
# 78 ✓ 📷 https://cdn.bsky.app/img/feed_fullsize/plain/did:plc:bumgeuoa3r74zyfxhic4qlfi/bafkreic2b2m4snrbtn3qofld773k6findwhim44mxnanyhqi54qyqqbv2q@jpeg
#     post: https://bsky.app/profile/felinaria.bsky.social/post/3lhyw2pkzwc2p
#     user: felinaria.bsky.social
#     found cat label: 0
#     found bad label: -1 []
#     ✓✓ 😺 successfully found cat pic at post 78. It has 13 likes.
#       ✓✓✓ ✅ Successfully liked post and followed user: felinaria.bsky.social
#       👍🏻 This cat post got 13, and I would call it successful, so following its likers.
#         Followed post-liker. handle: fivefootmenace81.bsky.social
#         Followed post-liker. handle: lisamhearts.bsky.social
#         Already seen user. handle: sassybuns.no
#         Followed post-liker. handle: soverytired.bsky.social
#         Followed post-liker. handle: mysterymo.bsky.social
#         Already seen user. handle: emlyne.bsky.social
#         Already seen user. handle: iankali.bsky.social
#         Already seen user. handle: dadarchist.bsky.social
#         Already seen user. handle: gingerjanethebendy.bsky.social
#         Already seen user. handle: shizna.bsky.social
#         Followed post-liker. handle: katiewarczak.bsky.social
#         Already seen user. handle: louseslayer.bsky.social
#       ✅ Added 5 users that liked that post.
# 79 💕 user: imarebel.bsky.social is a mutual follower. Liking this post. https://bsky.app/profile/imarebel.bsky.social/post/3lhyw2nndcs2e
# 80 ✓ 📷 https://cdn.bsky.app/img/feed_fullsize/plain/did:plc:dm6kj7smfqep4thiulnu7quk/bafkreifhv34si6xjcsqbujxir4vnszuqplz3657tyzrsfwdgaex5a6mpo4@jpeg
#     post: https://bsky.app/profile/theladyhemlock.bsky.social/post/3lhyw2ggy7s2c
#     user: theladyhemlock.bsky.social
#     found cat label: 1
#     found bad label: 45 [917, 'comic book']
#     ✓✗ ❌ post 80 was not a cat pic
# 81 ✗ 👀 user: catdogsky.bsky.social is already being followed.
# 82 💕 user: alygory.bsky.social is a mutual follower. Liking this post. https://bsky.app/profile/alygory.bsky.social/post/3lhyw2d6z322n
# 83 ✓ 📷 https://cdn.bsky.app/img/feed_fullsize/plain/did:plc
://cdn.bsky.app/img/feed_fullsize/plain/did:plc:yhr7puqihe2rhebzus4uu5dv/bafkreiax5myrds4xwy2k64fmx6vmzgzkq4ml2gssbvtsxl2wu56yc5hsqy@jpeg
#     post: https://bsky.app/profile/krsjn.bsky.social/post/3lhyvycdwq222
#     user: krsjn.bsky.social
#     found cat label: 0
#     found bad label: -1 []
#     ✓✓ 😺 successfully found cat pic at post 91. It has 1 likes.
#       ✓✓✓ ✅ Successfully liked post and followed user: krsjn.bsky.social
# 92 ✓ 📷 https://cdn.bsky.app/img/feed_fullsize/plain/did:plc:bcasispas3xzhqfkcua7mst3/bafkreih4vr2cgkouahmfczexepck7sn2nvi23adzss5y6nfgh7d6tihfqa@jpeg
#     post: https://bsky.app/profile/jamesabellart.bsky.social/post/3lhyvxyrzo223
#     user: jamesabellart.bsky.social
#     found cat label: -1
#     found bad label: 25 [921, 'book jacket, dust cover, dust jacket, dust wrapper']
#     ✓✗ ❌ post 92 was not a cat pic
# 93 ✓ 📷 https://cdn.bsky.app/img/feed_fullsize/plain/did:plc:htrla5mqdbxtrtwdubp7ym66/bafkreib3tkynqxnplipuy7adrjseocgqb7j5jmo2a3xc6h2v3pt2rh7gau@jpeg
#     post: https://bsky.app/profile/velvie.bsky.social/post/3lhyvxv3pjs2u
#     user: velvie.bsky.social
#     found cat label: -1
#     found bad label: 1 [917, 'comic book', 921, 'book jacket, dust cover, dust jacket, dust wrapper', 916, 'web site, website, internet site, site']
#     ✓✗ ❌ post 93 was not a cat pic
# 94 ✓ 📷 https://cdn.bsky.app/img/feed_fullsize/plain/did:plc:din5h5tx5u3ioltr5ekfxuug/bafkreickvw2bmiarkgbuqffsxs4vf4m2ylqzhpdrobnc6rdgzu2amfm7ie@jpeg
#     post: https://bsky.app/profile/crystalalumina.bsky.social/post/3lhyvxkqivk24
#     user: crystalalumina.bsky.social
#     found cat label: -1
#     found bad label: 0 [917, 'comic book', 921, 'book jacket, dust cover, dust jacket, dust wrapper']
#     ✓✗ ❌ post 94 was not a cat pic
# 95 ✓ 📷 https://cdn.bsky.app/img/feed_fullsize/plain/did:plc:yqkprducybquntu5vn3d6iix/bafkreifnscd5rx4kjmb2rosgmmmclgg7m76hys4jqalvlqa7zb4dvft7nu@jpeg
#     post: https://bsky.app/profile/gnomieshobbycorner.bsky.social/post/3lhyvxgtjus2x
#     user: gnomieshobbycorner.bsky.social
#     found cat label: 0
#     found bad label: -1 []
#     ✓✓ 😺 successfully found cat pic at post 95. It has 3 likes.
#       ✓✓✓ ✅ Successfully liked post and followed user: gnomieshobbycorner.bsky.social
# 96 ✓ 📷 https://cdn.bsky.app/img/feed_fullsize/plain/did:plc:iwvsg6d62a6hwrrp67ysaskg/bafkreic3fax4pf75jlzg4hkjkbqvxkvt65nexb3fp6ksx2pxvn7afp2sxu@jpeg
#     post: https://bsky.app/profile/jstevenyork.mastodon.social.ap.brid.gy/post/3lhyvyijuxfp2
#     user: jstevenyork.mastodon.social.ap.brid.gy
#     found cat label: 0
#     found bad label: -1 []
#     ✓✓ 😺 successfully found cat pic at post 96. It has 0 likes.
#       ✓✓✓ ✅ Successfully liked post and followed user: jstevenyork.mastodon.social.ap.brid.gy
# followed 67 new users. 32 posters and 35 likers.

# %%
print(f'adding {len(query_siamese)} new follows from siamese cats.')
# Out:
# adding 67 new follows from siamese cats.

# %%
generate_insert_query(query_siamese)
# Out:
# INSERT INTO "bsky"."follows" (user_id, user_handle, follow_uri, follow_date, follows_you)
# VALUES
#     ('did:plc:5avcmy4dwd2c7fdarraucwa7', 'ashing87.bsky.social', 'at://did:plc:ktkc7jfakxzjpooj52ffc6ra/app.bsky.graph.follow/3lhyxc7or6t2z', NOW(), FALSE) ,
#     ('did:plc:kbfzsycsztgpwbz7xb7qe23k', 'bopterror.bsky.social', 'at://did:plc:ktkc7jfakxzjpooj52ffc6ra/app.bsky.graph.follow/3lhyxcbljip2g', NOW(), FALSE) ,
#     ('did:plc:uarlx3o2qsak7kenjzaaxp34', 'missfoster.bsky.social', 'at://did:plc:ktkc7jfakxzjpooj52ffc6ra/app.bsky.graph.follow/3lhyxcbp3pz26', NOW(), FALSE) ,
#     ('did:plc:c432zrciyugbcfzn36uviowc', 'clur.bsky.social', 'at://did:plc:ktkc7jfakxzjpooj52ffc6ra/app.bsky.graph.follow/3lhyxcbq5uh2o', NOW(), FALSE) ,
#     ('did:plc:sefj3flbz6bvu6l7ufbpvm3f', 'paulst001.bsky.social', 'at://did:plc:ktkc7jfakxzjpooj52ffc6ra/app.bsky.graph.follow/3lhyxcbr65x2g', NOW(), FALSE) ,
#     ('did:plc:yszji3g3lavse7fr7dzgoo43', 'stephupnorth.bsky.social', 'at://did:plc:ktkc7jfakxzjpooj52ffc6ra/app.bsky.graph.follow/3lhyxcbrzgp25', NOW(), FALSE) ,
#     ('did:plc:4tixoizl4fy36fau4cwiz2ms', 'jkmakes.bsky.social', 'at://did:plc:ktkc7jfakxzjpooj52ffc6ra/app.bsky.graph.follow/3lhyxcfc3jk2j', NOW(), FALSE) ,
#     ('did:plc:paq7auao2b7iokmwdkjygvap', 'jetmanjay.bsky.social', 'at://did:plc:ktkc7jfakxzjpooj52ffc6ra/app.bsky.graph.follow/3lhyxcgyzdk2j', NOW(), FALSE) ,
#     ('did:plc:ljmgs4t2u3j7ti56fdjqzwje', 'antodim.bsky.social', 'at://did:plc:ktkc7jfakxzjpooj52ffc6ra/app.bsky.graph.follow/3lhyxckfsme2p', NOW(), FALSE) ,
#     ('did:plc:4mgy2jtozv5w2vkgtygmavde', 's3062072.bsky.social', 'at://did:plc:ktkc7jfakxzjpooj52ffc6ra/app.bsky.graph.follow/3lhyxcsaqxx2g', NOW(), FALSE) ,
#     ('did:plc:tisuagfv7lb75rvk6stxugs7', 'mkebecky.bsky.social', 'at://did:plc:ktkc7jfakxzjpooj52ffc6ra/app.bsky.graph.follow/3lhyxctjuic2j', NOW(), FALSE) ,
#     ('did:plc:3jju2baoa5ggg6iul4oeh5ic', 'ycatstacy.bsky.social', 'at://did:plc:ktkc7jfakxzjpooj52ffc6ra/app.bsky.graph.follow/3lhyxczszsj2s', NOW(), FALSE) ,
#     ('did:plc:iwvsg6d62a6hwrrp67ysaskg', 'jstevenyork.mastodon.social.ap.brid.gy', 'at://did:plc:ktkc7jfakxzjpooj52ffc6ra/app.bsky.graph.follow/3lhyxf5mvha2g', NOW(), FALSE)
# RETURNING user_handle, follow_date;

# %%
# going through tuxedo and cats after doing siamese has been proving to be nearly completely unnecessary. So we'll skip these for a while
query_cats = []
# follow_more_users(1000, 300, FEED_CATS)

# %%
generate_insert_query(query_cats)
# Out:
# NO CHANGES NECESSARY

# %%
# going through tuxedo and cats after doing siamese has been proving to be nearly completely unnecessary. So we'll skip these for a while
query_tuxedo = []
# follow_more_users(1000, 300, FEED_TUXEDOCATS)

# %%
for line in query_tuxedo:
  print(line)

# %%
print(f'posts seen during this batch: {len(seen_posts)}')
# Out:
# posts seen during this batch: 97

# %%
# create an insert query for the posts cache, updating the db with our newly seen posts
posts_values = [f"  ('{post}', NOW())" for post in seen_posts]
posts_values = ', \n'.join(posts_values)
print(f'INSERT INTO {SCHEMA}.{TABLE_POSTS} ({COL_POSTCID}, {COL_SEENTIME}) ')
print('VALUES')
print(posts_values)
print(f'RETURNING {COL_POSTCID}, {COL_SEENTIME}' + END_QUERY)
# Out:
# INSERT INTO "bsky"."posts" (post_cid, seen_time)
# VALUES
#   ('bafyreichnshyz4q4xtpaxnyf6wozjwyrqv6jev37zzdnyhyc3ijnmgw4hu', NOW()),
#   ('bafyreiardjawdgf22hz4n5gt2uvorl2muh7udj5netzmtst33ynxyogzy4', NOW()),
#   ('bafyreibisrfp6hoq5hdamvjtrkwo4r6af6crupsqrhu2yfalzjha2c6c5q', NOW()),
#   ('bafyreiavvhpsfymxxmvp4mn4mtglcub4b63kbw5tjbozehfhp7jgy2puya', NOW()),
#   ('bafyreif7pzo4jj6fjvxdvtpf7l5qfxarkhd3jy72wpaawlze47ydg422b4', NOW()),
#   ('bafyreifc4ejlh4pfh7lngq55m2vhuiwbpusw3kl2tx2vdkhxtz7bvrvwxi', NOW()),
#   ('bafyreigrfkuveh4nhlpntegmjyvegcvkbf4qxj6f7dykeppihjgsf34hcy', NOW()),
#   ('bafyreiax7inw6evgx4az6k4myi54bkdbwu6xnh5qngevvcro7rwfp5pimy', NOW()),
#   ('bafyreibsg3xf273w7joxfclrrumstmsfri2nweufe56z6u4twsgjmmt6cy', NOW()),
#   ('bafyreifdha5cadpqwsyjkqsesvwuxttwaanzzlv5zdkpuoxuclu5kzsjri', NOW()),
#   ('bafyreifplrk2rozyii4x6pfdr4ocrzkr2abiwd2enpqjawy6hx6rmiwiam', NOW()),
#   ('bafyreihrvtd6e4lrd2oi3y56g7fcgqynzeh2jnc67lk4olgwjxswwrn5ra', NOW()),
#   ('bafyreif3ddwpyblq46olnmylpxftrhud53q7wuj4pthvcxqjwyb6dbrqru', NOW()),
#   ('bafyreidpze2v44dvrmnjv2yj5gfp2exia2gjyb5bwi6ay5wljeilqce77m', NOW()),
#   ('bafyreih3tliepifuguh5qz542r4mcfj6e5u6zo32kqzzcte4v7ehcbr24u', NOW()),
#   ('bafyreidzikzbvz44d6usq5waoqylwkhxbdzet6kjoull6otbwm4vezowcu', NOW()),
#   ('bafyreiezyue5dqxb7heibzpfdl5bwkpqsvo2ceyewvxl5e6ocqdjfoszmm', NOW()),
#   ('bafyreia5udrjvdjifuoptd7k7o225qoxdqcho6fdd5xhnfhu7opc42anku', NOW())
# RETURNING post_cid, seen_time;

# %%
end_timestamp = datetime.datetime.now(zoneinfo.ZoneInfo(USER_TIMEZONE))
time_diff = end_timestamp - cur_timestamp
logging_text = logging_text + LINE_BREAK + f'completed at: {str(end_timestamp)}' + LINE_BREAK + f'time diff: {str(time_diff)}' + LINE_BREAK
print(f'end timestamp: {end_timestamp}\ntime diff (runtime): {time_diff}')
# print(logging_text)
# Out:
# end timestamp: 2025-02-12 14:56:27.207845-05:00
# time diff (runtime): 0:01:42.063989

# %%
following = client.get_profile(actor=BSKY_USERNAME).follows_count
followers = client.get_profile(actor=BSKY_USERNAME).followers_count

logging_text = logging_text + LINE_BREAK + 'cur followers: ' + str(followers) + LINE_BREAK + 'now following: ' + str(following) + LINE_BREAK
# print(logging_text)

# %%
# LOGGING ALL THE CHANGES TO OUR LOGGING FILE IN GITHUB
commit_message = "Logging for follower additions on " + str(cur_timestamp)

# Step 1: Get the file's current content and SHA
url = f"https://api.github.com/repos/{GITHUB_REPO}/contents/{FILE_PATH}"
headers = {"Authorization": f"token {GITHUB_TOKEN}"}
response = requests.get(url, headers=headers)
response_json = response.json()

# Decode the content of the file
file_sha = response_json["sha"]
content = base64.b64decode(response_json["content"]).decode("utf-8")

# Step 2: Modify the file content
new_content = content + LINE_BREAK + logging_text + END_LOGGING
encoded_content = base64.b64encode(new_content.encode("utf-8")).decode("utf-8")

# Step 3: Push the updated content
data = {
    "message": commit_message,
    "content": encoded_content,
    "sha": file_sha,
    "branch": BRANCH,
}
update_response = requests.put(url, headers=headers, json=data)

if update_response.status_code == 200:
    print("Logging file updated successfully! Here's what was added to the logs:\n")
    print(logging_text + END_LOGGING)
else:
    print(f"Error: {update_response.json()}")
# Out:
# Logging file updated successfully! Here's what was added to the logs:
#
#
# 2025-02-12 14:54:44.892798-05:00
# FINDING NEW FOLLOWERS
#
# prior follower count: 7562
# previously following: 13487
#
# Feed 'Siamese Cats':
#   Followed 67 new users!
#     Of those follows, 32 were posters and 35 were from likes.
#   97 posts in total were viewed during this run.
#   Skipped Posts: (5) - 0 posts were previously seen, 5 were from users already followed, 0 were your posts.
#   Mutuals: 11 posts were from users that follow you, and these posts were liked.
#   Unprocessed: (8) - 3 posts had no media attached, and 5 posts had videos attached.
#   Processed: 73 posts had pics attached: 32 were identified as cat pics and 41 were not cats.
#   No errors were encountered while processing pics.
#
#
# completed at: 2025-02-12 14:56:27.207845-05:00
# time diff: 0:01:42.063989
#
# cur followers: 7563
# now following: 13554
#
# ____________________
