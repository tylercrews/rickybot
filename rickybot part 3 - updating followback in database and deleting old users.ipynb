# %%
pip install atproto
# Out:
# Collecting atproto
#   Downloading atproto-0.0.58-py3-none-any.whl.metadata (14 kB)
# Requirement already satisfied: click<9,>=8.1.3 in /usr/local/lib/python3.11/dist-packages (from atproto) (8.1.8)
# Requirement already satisfied: cryptography<44,>=41.0.7 in /usr/local/lib/python3.11/dist-packages (from atproto) (43.0.3)
# Collecting dnspython<3,>=2.4.0 (from atproto)
#   Downloading dnspython-2.7.0-py3-none-any.whl.metadata (5.8 kB)
# Collecting httpx<0.28.0,>=0.25.0 (from atproto)
#   Downloading httpx-0.27.2-py3-none-any.whl.metadata (7.1 kB)
# Collecting libipld<4,>=2.0.0 (from atproto)
#   Downloading libipld-3.0.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (3.6 kB)
# Requirement already satisfied: pydantic<3,>=2.7 in /usr/local/lib/python3.11/dist-packages (from atproto) (2.10.6)
# Requirement already satisfied: typing-extensions<5,>=4.8.0 in /usr/local/lib/python3.11/dist-packages (from atproto) (4.12.2)
# Collecting websockets<14,>=12 (from atproto)
#   Downloading websockets-13.1-cp311-cp311-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.8 kB)
# Requirement already satisfied: cffi>=1.12 in /usr/local/lib/python3.11/dist-packages (from cryptography<44,>=41.0.7->atproto) (1.17.1)
# Requirement already satisfied: anyio in /usr/local/lib/python3.11/dist-packages (from httpx<0.28.0,>=0.25.0->atproto) (3.7.1)
# Requirement already satisfied: certifi in /usr/local/lib/python3.11/dist-packages (from httpx<0.28.0,>=0.25.0->atproto) (2024.12.14)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.11/dist-packages (from httpx<0.28.0,>=0.25.0->atproto) (1.0.7)
# Requirement already satisfied: idna in /usr/local/lib/python3.11/dist-packages (from httpx<0.28.0,>=0.25.0->atproto) (3.10)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.11/dist-packages (from httpx<0.28.0,>=0.25.0->atproto) (1.3.1)
# Requirement already satisfied: h11<0.15,>=0.13 in /usr/local/lib/python3.11/dist-packages (from httpcore==1.*->httpx<0.28.0,>=0.25.0->atproto) (0.14.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.11/dist-packages (from pydantic<3,>=2.7->atproto) (0.7.0)
# Requirement already satisfied: pydantic-core==2.27.2 in /usr/local/lib/python3.11/dist-packages (from pydantic<3,>=2.7->atproto) (2.27.2)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.11/dist-packages (from cffi>=1.12->cryptography<44,>=41.0.7->atproto) (2.22)
# Downloading atproto-0.0.58-py3-none-any.whl (351 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 351.1/351.1 kB 4.9 MB/s eta 0:00:00
# Downloading dnspython-2.7.0-py3-none-any.whl (313 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 313.6/313.6 kB 9.7 MB/s eta 0:00:00
# Downloading httpx-0.27.2-py3-none-any.whl (76 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 76.4/76.4 kB 3.2 MB/s eta 0:00:00
# Downloading libipld-3.0.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (671 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 671.7/671.7 kB 16.6 MB/s eta 0:00:00
# Downloading websockets-13.1-cp311-cp311-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (164 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 164.8/164.8 kB 8.1 MB/s eta 0:00:00
# Installing collected packages: websockets, libipld, dnspython, httpx, atproto
#   Attempting uninstall: websockets
#     Found existing installation: websockets 14.2
#     Uninstalling websockets-14.2:
#       Successfully uninstalled websockets-14.2
#   Attempting uninstall: httpx
#     Found existing installation: httpx 0.28.1
#     Uninstalling httpx-0.28.1:
#       Successfully uninstalled httpx-0.28.1
# Successfully installed atproto-0.0.58 dnspython-2.7.0 httpx-0.27.2 libipld-3.0.0 websockets-13.1

# %%
from atproto import Client
from google.colab import userdata

BSKY_USERNAME = userdata.get('bsky_username')
BSKY_PASSWORD = userdata.get('bsky_password')

client = Client()
client.login(BSKY_USERNAME, BSKY_PASSWORD)
# Out:
# ProfileViewDetailed(did='did:plc:ktkc7jfakxzjpooj52ffc6ra', handle='tyrowo.com', associated=ProfileAssociated(chat=None, feedgens=0, labeler=False, lists=0, starter_packs=0, py_type='app.bsky.actor.defs#profileAssociated'), avatar='https://cdn.bsky.app/img/avatar/plain/did:plc:ktkc7jfakxzjpooj52ffc6ra/bafkreiepqgg5tlozvv4bw5ficwwixflfprionhnli26hngc3hjn6ygpamu@jpeg', banner='https://cdn.bsky.app/img/banner/plain/did:plc:ktkc7jfakxzjpooj52ffc6ra/bafkreierasgybimbz3pfobqfmay5ufxm7jlqnjeiumdx7dyof6mcss7a4m@jpeg', created_at='2023-08-28T14:18:41.780Z', description='Cat poster. Self-taught professional software developer, exF2P MTG Arena Challenger, ex wr holder speedrunning HotD2_100%, ex streamer, ex melee player. \nGrilling, coding, gaming, magic:tg, tcgs, and my kitty, Ricky 😻\nNO POLITICS\nhe/him', display_name='Tyro, ft Ricky', followers_count=2665, follows_count=6329, indexed_at='2025-01-31T21:22:03.213Z', joined_via_starter_pack=None, labels=[], pinned_post=Main(cid='bafyreihszjgxkh5fmu5je5eldv6i27ubndfcyhwcbjsin4jsbfo2gu45ky', uri='at://did:plc:ktkc7jfakxzjpooj52ffc6ra/app.bsky.feed.post/3lcbntv5rmc2j', py_type='com.atproto.repo.strongRef'), posts_count=200, viewer=ViewerState(blocked_by=False, blocking=None, blocking_by_list=None, followed_by=None, following=None, known_followers=KnownFollowers(count=2211, followers=[ProfileViewBasic(did='did:plc:isliyiq3gjuxpwysdpdgj5t3', handle='chateauminette.com', associated=ProfileAssociated(chat=ProfileAssociatedChat(allow_incoming='following', py_type='app.bsky.actor.defs#profileAssociatedChat'), feedgens=None, labeler=None, lists=None, starter_packs=None, py_type='app.bsky.actor.defs#profileAssociated'), avatar='https://cdn.bsky.app/img/avatar/plain/did:plc:isliyiq3gjuxpwysdpdgj5t3/bafkreibdrunuo63uix5ex4e35nqaiya3rtt3v6suongv2ozavvyeu2u4ei@jpeg', created_at='2023-04-30T14:38:48.713Z', display_name='Chateau Minette', labels=[], viewer=ViewerState(blocked_by=False, blocking=None, blocking_by_list=None, followed_by='at://did:plc:isliyiq3gjuxpwysdpdgj5t3/app.bsky.graph.follow/3lg2cp2jeb32r', following='at://did:plc:ktkc7jfakxzjpooj52ffc6ra/app.bsky.graph.follow/3lfux5yfjiq2c', known_followers=None, muted=False, muted_by_list=None, py_type='app.bsky.actor.defs#viewerState'), py_type='app.bsky.actor.defs#profileViewBasic'), ProfileViewBasic(did='did:plc:5p6dvkv2oewtrk4tg6kjxvfz', handle='manelcamacho.bsky.social', associated=ProfileAssociated(chat=ProfileAssociatedChat(allow_incoming='none', py_type='app.bsky.actor.defs#profileAssociatedChat'), feedgens=None, labeler=None, lists=None, starter_packs=None, py_type='app.bsky.actor.defs#profileAssociated'), avatar='https://cdn.bsky.app/img/avatar/plain/did:plc:5p6dvkv2oewtrk4tg6kjxvfz/bafkreidn5ebplo6xlomimqqpfdi6yquankw4r3ukdfeelxu7fl2xgvfclq@jpeg', created_at='2023-07-29T05:24:24.944Z', display_name='Manu  🌊🐳🐦\u200d⬛🏔️🌎', labels=[Label(cts='1970-01-01T00:00:00.000Z', src='did:plc:5p6dvkv2oewtrk4tg6kjxvfz', uri='at://did:plc:5p6dvkv2oewtrk4tg6kjxvfz/app.bsky.actor.profile/self', val='!no-unauthenticated', cid='bafyreigi6ud7e6i5pvkfw7ufs6sr747brere7azlt3y4aimzghdd7wj7ga', exp=None, neg=None, sig=None, ver=None, py_type='com.atproto.label.defs#label')], viewer=ViewerState(blocked_by=False, blocking=None, blocking_by_list=None, followed_by='at://did:plc:5p6dvkv2oewtrk4tg6kjxvfz/app.bsky.graph.follow/3lggkroicc32p', following='at://did:plc:ktkc7jfakxzjpooj52ffc6ra/app.bsky.graph.follow/3lggkndelsx2d', known_followers=None, muted=False, muted_by_list=None, py_type='app.bsky.actor.defs#viewerState'), py_type='app.bsky.actor.defs#profileViewBasic'), ProfileViewBasic(did='did:plc:uth2m47jh7mgtz6pa7nmexv4', handle='y-sr2024.bsky.social', associated=ProfileAssociated(chat=ProfileAssociatedChat(allow_incoming='following', py_type='app.bsky.actor.defs#profileAssociatedChat'), feedgens=None, labeler=None, lists=None, starter_packs=None, py_type='app.bsky.actor.defs#profileAssociated'), avatar='https://cdn.bsky.app/img/avatar/plain/did:plc:uth2m47jh7mg ...

# %%
data = client.app.bsky.feed.get_feed({
    'feed': 'at://did:plc:jfhpnnst6flqway4eaeqzj2a/app.bsky.feed.generator/cats',
    'limit': 30,
}, headers={})

feed = data.feed
next_page = data.cursor

# %%
# anatomy of a feed post
print(data.feed[0].post)
# Out:
# author=ProfileViewBasic(did='did:plc:zdsfrnukjpuyiy2w35bei7ay', handle='lsepper.bsky.social', associated=ProfileAssociated(chat=ProfileAssociatedChat(allow_incoming='following', py_type='app.bsky.actor.defs#profileAssociatedChat'), feedgens=None, labeler=None, lists=None, starter_packs=None, py_type='app.bsky.actor.defs#profileAssociated'), avatar='https://cdn.bsky.app/img/avatar/plain/did:plc:zdsfrnukjpuyiy2w35bei7ay/bafkreieopwr4u7xg2yc2e3edqxbqrp5zhtikqgbf6t3bsvyuhk46doalze@jpeg', created_at='2023-05-12T22:37:49.047Z', display_name='Liz Sepper', labels=[Label(cts='1970-01-01T00:00:00.000Z', src='did:plc:zdsfrnukjpuyiy2w35bei7ay', uri='at://did:plc:zdsfrnukjpuyiy2w35bei7ay/app.bsky.actor.profile/self', val='!no-unauthenticated', cid='bafyreigedanxwuaag6u3sdmzu6xzxr7xscxvyrntq4yps4rfhg5d52xgaa', exp=None, neg=None, sig=None, ver=None, py_type='com.atproto.label.defs#label')], viewer=ViewerState(blocked_by=False, blocking=None, blocking_by_list=None, followed_by=None, following=None, known_followers=None, muted=False, muted_by_list=None, py_type='app.bsky.actor.defs#viewerState'), py_type='app.bsky.actor.defs#profileViewBasic') cid='bafyreihvc4k3nzmalmyi3yfnmf7zd2ypw2ppuo6vkwoyv6na2cez7oxypm' indexed_at='2025-02-01T01:59:30.628Z' record=Record(created_at='2025-02-01T01:59:28.358Z', text='Not at all impressed by humans this week', embed=Main(images=[Image(alt='A calico cat, all white in the front, standing tall and looking very unimpressed', image=BlobRef(mime_type='image/jpeg', size=789194, ref=IpldLink(link='bafkreicanndqc6obelneaxkvn2svufuscbgobfvafh36g7xozobma2xh6y'), py_type='blob'), aspect_ratio=AspectRatio(height=1954, width=1822, py_type='app.bsky.embed.defs#aspectRatio'), py_type='app.bsky.embed.images#image')], py_type='app.bsky.embed.images'), entities=None, facets=None, labels=None, langs=['en'], reply=None, tags=None, py_type='app.bsky.feed.post') uri='at://did:plc:zdsfrnukjpuyiy2w35bei7ay/app.bsky.feed.post/3lh3g3ah22k2o' embed=View(images=[ViewImage(alt='A calico cat, all white in the front, standing tall and looking very unimpressed', fullsize='https://cdn.bsky.app/img/feed_fullsize/plain/did:plc:zdsfrnukjpuyiy2w35bei7ay/bafkreicanndqc6obelneaxkvn2svufuscbgobfvafh36g7xozobma2xh6y@jpeg', thumb='https://cdn.bsky.app/img/feed_thumbnail/plain/did:plc:zdsfrnukjpuyiy2w35bei7ay/bafkreicanndqc6obelneaxkvn2svufuscbgobfvafh36g7xozobma2xh6y@jpeg', aspect_ratio=AspectRatio(height=1954, width=1822, py_type='app.bsky.embed.defs#aspectRatio'), py_type='app.bsky.embed.images#viewImage')], py_type='app.bsky.embed.images#view') labels=[] like_count=14 quote_count=1 reply_count=2 repost_count=0 threadgate=None viewer=ViewerState(embedding_disabled=False, like=None, pinned=None, reply_disabled=None, repost=None, thread_muted=False, py_type='app.bsky.feed.defs#viewerState') py_type='app.bsky.feed.defs#postView'

# %%
print(data.feed[0].post.like_count)
# Out:
# 14

# %%
post_uri = data.feed[0].post.uri
print(post_uri)
# Out:
# at://did:plc:zdsfrnukjpuyiy2w35bei7ay/app.bsky.feed.post/3lh3g3ah22k2o

# %%
post_cid = data.feed[0].post.cid
print(post_cid)
# Out:
# bafyreihvc4k3nzmalmyi3yfnmf7zd2ypw2ppuo6vkwoyv6na2cez7oxypm

# %%
# A thread refers to a post, its replies (descendants), and its parents (ancestors). Fetching a thread is done with the getPostThread method, which accepts the following parameters:
res = client.get_post_thread(uri=post_uri)
thread = res.thread
print(res)
# Out:
# thread=ThreadViewPost(post=PostView(author=ProfileViewBasic(did='did:plc:zdsfrnukjpuyiy2w35bei7ay', handle='lsepper.bsky.social', associated=ProfileAssociated(chat=ProfileAssociatedChat(allow_incoming='following', py_type='app.bsky.actor.defs#profileAssociatedChat'), feedgens=None, labeler=None, lists=None, starter_packs=None, py_type='app.bsky.actor.defs#profileAssociated'), avatar='https://cdn.bsky.app/img/avatar/plain/did:plc:zdsfrnukjpuyiy2w35bei7ay/bafkreieopwr4u7xg2yc2e3edqxbqrp5zhtikqgbf6t3bsvyuhk46doalze@jpeg', created_at='2023-05-12T22:37:49.047Z', display_name='Liz Sepper', labels=[Label(cts='1970-01-01T00:00:00.000Z', src='did:plc:zdsfrnukjpuyiy2w35bei7ay', uri='at://did:plc:zdsfrnukjpuyiy2w35bei7ay/app.bsky.actor.profile/self', val='!no-unauthenticated', cid='bafyreigedanxwuaag6u3sdmzu6xzxr7xscxvyrntq4yps4rfhg5d52xgaa', exp=None, neg=None, sig=None, ver=None, py_type='com.atproto.label.defs#label')], viewer=ViewerState(blocked_by=False, blocking=None, blocking_by_list=None, followed_by=None, following=None, known_followers=None, muted=False, muted_by_list=None, py_type='app.bsky.actor.defs#viewerState'), py_type='app.bsky.actor.defs#profileViewBasic'), cid='bafyreihvc4k3nzmalmyi3yfnmf7zd2ypw2ppuo6vkwoyv6na2cez7oxypm', indexed_at='2025-02-01T01:59:30.628Z', record=Record(created_at='2025-02-01T01:59:28.358Z', text='Not at all impressed by humans this week', embed=Main(images=[Image(alt='A calico cat, all white in the front, standing tall and looking very unimpressed', image=BlobRef(mime_type='image/jpeg', size=789194, ref=IpldLink(link='bafkreicanndqc6obelneaxkvn2svufuscbgobfvafh36g7xozobma2xh6y'), py_type='blob'), aspect_ratio=AspectRatio(height=1954, width=1822, py_type='app.bsky.embed.defs#aspectRatio'), py_type='app.bsky.embed.images#image')], py_type='app.bsky.embed.images'), entities=None, facets=None, labels=None, langs=['en'], reply=None, tags=None, py_type='app.bsky.feed.post'), uri='at://did:plc:zdsfrnukjpuyiy2w35bei7ay/app.bsky.feed.post/3lh3g3ah22k2o', embed=View(images=[ViewImage(alt='A calico cat, all white in the front, standing tall and looking very unimpressed', fullsize='https://cdn.bsky.app/img/feed_fullsize/plain/did:plc:zdsfrnukjpuyiy2w35bei7ay/bafkreicanndqc6obelneaxkvn2svufuscbgobfvafh36g7xozobma2xh6y@jpeg', thumb='https://cdn.bsky.app/img/feed_thumbnail/plain/did:plc:zdsfrnukjpuyiy2w35bei7ay/bafkreicanndqc6obelneaxkvn2svufuscbgobfvafh36g7xozobma2xh6y@jpeg', aspect_ratio=AspectRatio(height=1954, width=1822, py_type='app.bsky.embed.defs#aspectRatio'), py_type='app.bsky.embed.images#viewImage')], py_type='app.bsky.embed.images#view'), labels=[], like_count=25, quote_count=1, reply_count=2, repost_count=1, threadgate=None, viewer=ViewerState(embedding_disabled=False, like=None, pinned=None, reply_disabled=None, repost=None, thread_muted=False, py_type='app.bsky.feed.defs#viewerState'), py_type='app.bsky.feed.defs#postView'), parent=None, replies=[ThreadViewPost(post=PostView(author=ProfileViewBasic(did='did:plc:cmdqzehaqbrxkhnxsolmk6w2', handle='rickweinmeyer.bsky.social', associated=ProfileAssociated(chat=ProfileAssociatedChat(allow_incoming='all', py_type='app.bsky.actor.defs#profileAssociatedChat'), feedgens=None, labeler=None, lists=None, starter_packs=None, py_type='app.bsky.actor.defs#profileAssociated'), avatar='https://cdn.bsky.app/img/avatar/plain/did:plc:cmdqzehaqbrxkhnxsolmk6w2/bafkreifthiuy352ffsnv25qaqb7p56gpvcudexrwxlpqkreorhgams6wn4@jpeg', created_at='2023-07-01T20:46:41.612Z', display_name='Rick Weinmeyer', labels=[], viewer=ViewerState(blocked_by=False, blocking=None, blocking_by_list=None, followed_by=None, following=None, known_followers=None, muted=False, muted_by_list=None, py_type='app.bsky.actor.defs#viewerState'), py_type='app.bsky.actor.defs#profileViewBasic'), cid='bafyreicvafohint7fbux2qt2u6fb2iqoniggadjqabmsm3ofyfmmtmuukq', indexed_at='2025-02-01T02:01:31.621Z', record=Record(created_at='2025-02-01T02:01:30.970Z', text='More pictures of Brisket!', embed=None, entities= ...

# %%
print(thread)
# Out:
# post=PostView(author=ProfileViewBasic(did='did:plc:zdsfrnukjpuyiy2w35bei7ay', handle='lsepper.bsky.social', associated=ProfileAssociated(chat=ProfileAssociatedChat(allow_incoming='following', py_type='app.bsky.actor.defs#profileAssociatedChat'), feedgens=None, labeler=None, lists=None, starter_packs=None, py_type='app.bsky.actor.defs#profileAssociated'), avatar='https://cdn.bsky.app/img/avatar/plain/did:plc:zdsfrnukjpuyiy2w35bei7ay/bafkreieopwr4u7xg2yc2e3edqxbqrp5zhtikqgbf6t3bsvyuhk46doalze@jpeg', created_at='2023-05-12T22:37:49.047Z', display_name='Liz Sepper', labels=[Label(cts='1970-01-01T00:00:00.000Z', src='did:plc:zdsfrnukjpuyiy2w35bei7ay', uri='at://did:plc:zdsfrnukjpuyiy2w35bei7ay/app.bsky.actor.profile/self', val='!no-unauthenticated', cid='bafyreigedanxwuaag6u3sdmzu6xzxr7xscxvyrntq4yps4rfhg5d52xgaa', exp=None, neg=None, sig=None, ver=None, py_type='com.atproto.label.defs#label')], viewer=ViewerState(blocked_by=False, blocking=None, blocking_by_list=None, followed_by=None, following=None, known_followers=None, muted=False, muted_by_list=None, py_type='app.bsky.actor.defs#viewerState'), py_type='app.bsky.actor.defs#profileViewBasic'), cid='bafyreihvc4k3nzmalmyi3yfnmf7zd2ypw2ppuo6vkwoyv6na2cez7oxypm', indexed_at='2025-02-01T01:59:30.628Z', record=Record(created_at='2025-02-01T01:59:28.358Z', text='Not at all impressed by humans this week', embed=Main(images=[Image(alt='A calico cat, all white in the front, standing tall and looking very unimpressed', image=BlobRef(mime_type='image/jpeg', size=789194, ref=IpldLink(link='bafkreicanndqc6obelneaxkvn2svufuscbgobfvafh36g7xozobma2xh6y'), py_type='blob'), aspect_ratio=AspectRatio(height=1954, width=1822, py_type='app.bsky.embed.defs#aspectRatio'), py_type='app.bsky.embed.images#image')], py_type='app.bsky.embed.images'), entities=None, facets=None, labels=None, langs=['en'], reply=None, tags=None, py_type='app.bsky.feed.post'), uri='at://did:plc:zdsfrnukjpuyiy2w35bei7ay/app.bsky.feed.post/3lh3g3ah22k2o', embed=View(images=[ViewImage(alt='A calico cat, all white in the front, standing tall and looking very unimpressed', fullsize='https://cdn.bsky.app/img/feed_fullsize/plain/did:plc:zdsfrnukjpuyiy2w35bei7ay/bafkreicanndqc6obelneaxkvn2svufuscbgobfvafh36g7xozobma2xh6y@jpeg', thumb='https://cdn.bsky.app/img/feed_thumbnail/plain/did:plc:zdsfrnukjpuyiy2w35bei7ay/bafkreicanndqc6obelneaxkvn2svufuscbgobfvafh36g7xozobma2xh6y@jpeg', aspect_ratio=AspectRatio(height=1954, width=1822, py_type='app.bsky.embed.defs#aspectRatio'), py_type='app.bsky.embed.images#viewImage')], py_type='app.bsky.embed.images#view'), labels=[], like_count=25, quote_count=1, reply_count=2, repost_count=1, threadgate=None, viewer=ViewerState(embedding_disabled=False, like=None, pinned=None, reply_disabled=None, repost=None, thread_muted=False, py_type='app.bsky.feed.defs#viewerState'), py_type='app.bsky.feed.defs#postView') parent=None replies=[ThreadViewPost(post=PostView(author=ProfileViewBasic(did='did:plc:cmdqzehaqbrxkhnxsolmk6w2', handle='rickweinmeyer.bsky.social', associated=ProfileAssociated(chat=ProfileAssociatedChat(allow_incoming='all', py_type='app.bsky.actor.defs#profileAssociatedChat'), feedgens=None, labeler=None, lists=None, starter_packs=None, py_type='app.bsky.actor.defs#profileAssociated'), avatar='https://cdn.bsky.app/img/avatar/plain/did:plc:cmdqzehaqbrxkhnxsolmk6w2/bafkreifthiuy352ffsnv25qaqb7p56gpvcudexrwxlpqkreorhgams6wn4@jpeg', created_at='2023-07-01T20:46:41.612Z', display_name='Rick Weinmeyer', labels=[], viewer=ViewerState(blocked_by=False, blocking=None, blocking_by_list=None, followed_by=None, following=None, known_followers=None, muted=False, muted_by_list=None, py_type='app.bsky.actor.defs#viewerState'), py_type='app.bsky.actor.defs#profileViewBasic'), cid='bafyreicvafohint7fbux2qt2u6fb2iqoniggadjqabmsm3ofyfmmtmuukq', indexed_at='2025-02-01T02:01:31.621Z', record=Record(created_at='2025-02-01T02:01:30.970Z', text='More pictures of Brisket!', embed=None, entities=None, facets=None, label ...

# %%
likes = client.get_likes(post_uri).likes
print(likes)
# Out:
# [Like(actor=ProfileView(did='did:plc:52y4vre3rlxjk3267qwyffus', handle='iamaholly.bsky.social', associated=None, avatar='https://cdn.bsky.app/img/avatar/plain/did:plc:52y4vre3rlxjk3267qwyffus/bafkreibusyihwe73b3asliilra7s3u6nybur36mmkhfj7tpexp7f7xj3me@jpeg', created_at='2023-09-20T12:36:55.380Z', description='Sociologist at Ohio U. Narrative criminology, green criminology, and gender-based violence. Chelsea Green Bean.', display_name='Holly Ningard', indexed_at='2024-12-15T04:06:13.813Z', labels=[], viewer=ViewerState(blocked_by=False, blocking=None, blocking_by_list=None, followed_by=None, following=None, known_followers=None, muted=False, muted_by_list=None, py_type='app.bsky.actor.defs#viewerState'), py_type='app.bsky.actor.defs#profileView'), created_at='2025-02-01T02:22:17.135Z', indexed_at='2025-02-01T02:22:16.723Z', py_type='app.bsky.feed.getLikes#like'), Like(actor=ProfileView(did='did:plc:bqwcgjaecinvqxetjnjuygel', handle='morfaleji.bsky.social', associated=None, avatar='https://cdn.bsky.app/img/avatar/plain/did:plc:bqwcgjaecinvqxetjnjuygel/bafkreidqvpuhxcmd5j3v5rrsedxfaisuuza6g6xg6sjiprl7ds7z7qg5ce@jpeg', created_at='2024-02-18T20:11:48.096Z', description='Husband. Flack. Principal Consultant, Morphology Media Relations LLC. Pirkei Avot 2:21. #unionmember. DC via Cincinnati. @morfaleji most places', display_name='Doug Pennington ', indexed_at='2024-11-08T22:30:59.316Z', labels=[], viewer=ViewerState(blocked_by=False, blocking=None, blocking_by_list=None, followed_by=None, following=None, known_followers=None, muted=False, muted_by_list=None, py_type='app.bsky.actor.defs#viewerState'), py_type='app.bsky.actor.defs#profileView'), created_at='2025-02-01T02:21:31.022Z', indexed_at='2025-02-01T02:21:31.022Z', py_type='app.bsky.feed.getLikes#like'), Like(actor=ProfileView(did='did:plc:zdexiybfgfsfklx6grrb26au', handle='offwhitewarden.bsky.social', associated=ProfileAssociated(chat=ProfileAssociatedChat(allow_incoming='following', py_type='app.bsky.actor.defs#profileAssociatedChat'), feedgens=None, labeler=None, lists=None, starter_packs=None, py_type='app.bsky.actor.defs#profileAssociated'), avatar='https://cdn.bsky.app/img/avatar/plain/did:plc:zdexiybfgfsfklx6grrb26au/bafkreiftsfqltdbiauv5szccbcwzzkdrxcfypxbtreyhiofptvst4vug3e@jpeg', created_at='2024-01-26T05:25:13.291Z', description='Just some guy sitting at a desk', display_name='Offwhitewarden', indexed_at='2024-07-27T23:12:08.106Z', labels=[], viewer=ViewerState(blocked_by=False, blocking=None, blocking_by_list=None, followed_by=None, following=None, known_followers=None, muted=False, muted_by_list=None, py_type='app.bsky.actor.defs#viewerState'), py_type='app.bsky.actor.defs#profileView'), created_at='2025-02-01T02:20:08.733Z', indexed_at='2025-02-01T02:20:08.327Z', py_type='app.bsky.feed.getLikes#like'), Like(actor=ProfileView(did='did:plc:jup7asx2z4nggibntgibc75l', handle='adudofmilk.bsky.social', associated=None, avatar='https://cdn.bsky.app/img/avatar/plain/did:plc:jup7asx2z4nggibntgibc75l/bafkreigmhzi4n57mir6mybtwo6ttxfq6p2v3re6ldtdqxqctvl45aqxjsq@jpeg', created_at='2024-11-17T09:11:48.467Z', description='He/him\n\nDefinitely not 3 cats in a trenchcoat', display_name='Human worm baby', indexed_at='2024-11-22T05:34:17.415Z', labels=[], viewer=ViewerState(blocked_by=False, blocking=None, blocking_by_list=None, followed_by='at://did:plc:jup7asx2z4nggibntgibc75l/app.bsky.graph.follow/3lghii7baji2e', following='at://did:plc:ktkc7jfakxzjpooj52ffc6ra/app.bsky.graph.follow/3lghfg24hji2o', known_followers=None, muted=False, muted_by_list=None, py_type='app.bsky.actor.defs#viewerState'), py_type='app.bsky.actor.defs#profileView'), created_at='2025-02-01T02:20:03.765Z', indexed_at='2025-02-01T02:20:03.765Z', py_type='app.bsky.feed.getLikes#like'), Like(actor=ProfileView(did='did:plc:o7tq4bhg2o7bpeaonphpan3i', handle='nolo93.bsky.social', associated=None, avatar='https://cdn.bsky.app/img/avatar/plain/did:plc:o7tq4bhg2o7bpeaonphpan3i/bafkreibxfpe2srxa4ang4p4fc6wu5w35xdajwmng ...

# %%
print(len(likes))
for like in likes:
  print(like)
# Out:
# 27
# actor=ProfileView(did='did:plc:52y4vre3rlxjk3267qwyffus', handle='iamaholly.bsky.social', associated=None, avatar='https://cdn.bsky.app/img/avatar/plain/did:plc:52y4vre3rlxjk3267qwyffus/bafkreibusyihwe73b3asliilra7s3u6nybur36mmkhfj7tpexp7f7xj3me@jpeg', created_at='2023-09-20T12:36:55.380Z', description='Sociologist at Ohio U. Narrative criminology, green criminology, and gender-based violence. Chelsea Green Bean.', display_name='Holly Ningard', indexed_at='2024-12-15T04:06:13.813Z', labels=[], viewer=ViewerState(blocked_by=False, blocking=None, blocking_by_list=None, followed_by=None, following=None, known_followers=None, muted=False, muted_by_list=None, py_type='app.bsky.actor.defs#viewerState'), py_type='app.bsky.actor.defs#profileView') created_at='2025-02-01T02:22:17.135Z' indexed_at='2025-02-01T02:22:16.723Z' py_type='app.bsky.feed.getLikes#like'
# actor=ProfileView(did='did:plc:bqwcgjaecinvqxetjnjuygel', handle='morfaleji.bsky.social', associated=None, avatar='https://cdn.bsky.app/img/avatar/plain/did:plc:bqwcgjaecinvqxetjnjuygel/bafkreidqvpuhxcmd5j3v5rrsedxfaisuuza6g6xg6sjiprl7ds7z7qg5ce@jpeg', created_at='2024-02-18T20:11:48.096Z', description='Husband. Flack. Principal Consultant, Morphology Media Relations LLC. Pirkei Avot 2:21. #unionmember. DC via Cincinnati. @morfaleji most places', display_name='Doug Pennington ', indexed_at='2024-11-08T22:30:59.316Z', labels=[], viewer=ViewerState(blocked_by=False, blocking=None, blocking_by_list=None, followed_by=None, following=None, known_followers=None, muted=False, muted_by_list=None, py_type='app.bsky.actor.defs#viewerState'), py_type='app.bsky.actor.defs#profileView') created_at='2025-02-01T02:21:31.022Z' indexed_at='2025-02-01T02:21:31.022Z' py_type='app.bsky.feed.getLikes#like'
# actor=ProfileView(did='did:plc:zdexiybfgfsfklx6grrb26au', handle='offwhitewarden.bsky.social', associated=ProfileAssociated(chat=ProfileAssociatedChat(allow_incoming='following', py_type='app.bsky.actor.defs#profileAssociatedChat'), feedgens=None, labeler=None, lists=None, starter_packs=None, py_type='app.bsky.actor.defs#profileAssociated'), avatar='https://cdn.bsky.app/img/avatar/plain/did:plc:zdexiybfgfsfklx6grrb26au/bafkreiftsfqltdbiauv5szccbcwzzkdrxcfypxbtreyhiofptvst4vug3e@jpeg', created_at='2024-01-26T05:25:13.291Z', description='Just some guy sitting at a desk', display_name='Offwhitewarden', indexed_at='2024-07-27T23:12:08.106Z', labels=[], viewer=ViewerState(blocked_by=False, blocking=None, blocking_by_list=None, followed_by=None, following=None, known_followers=None, muted=False, muted_by_list=None, py_type='app.bsky.actor.defs#viewerState'), py_type='app.bsky.actor.defs#profileView') created_at='2025-02-01T02:20:08.733Z' indexed_at='2025-02-01T02:20:08.327Z' py_type='app.bsky.feed.getLikes#like'
# actor=ProfileView(did='did:plc:jup7asx2z4nggibntgibc75l', handle='adudofmilk.bsky.social', associated=None, avatar='https://cdn.bsky.app/img/avatar/plain/did:plc:jup7asx2z4nggibntgibc75l/bafkreigmhzi4n57mir6mybtwo6ttxfq6p2v3re6ldtdqxqctvl45aqxjsq@jpeg', created_at='2024-11-17T09:11:48.467Z', description='He/him\n\nDefinitely not 3 cats in a trenchcoat', display_name='Human worm baby', indexed_at='2024-11-22T05:34:17.415Z', labels=[], viewer=ViewerState(blocked_by=False, blocking=None, blocking_by_list=None, followed_by='at://did:plc:jup7asx2z4nggibntgibc75l/app.bsky.graph.follow/3lghii7baji2e', following='at://did:plc:ktkc7jfakxzjpooj52ffc6ra/app.bsky.graph.follow/3lghfg24hji2o', known_followers=None, muted=False, muted_by_list=None, py_type='app.bsky.actor.defs#viewerState'), py_type='app.bsky.actor.defs#profileView') created_at='2025-02-01T02:20:03.765Z' indexed_at='2025-02-01T02:20:03.765Z' py_type='app.bsky.feed.getLikes#like'
# actor=ProfileView(did='did:plc:o7tq4bhg2o7bpeaonphpan3i', handle='nolo93.bsky.social', associated=None, avatar='https://cdn.bsky.app/img/avatar/plain/did:plc:o7tq4bhg2o7bpeaonphpan3i/bafkreibxfpe2srxa4ang4p4fc6wu5w35xdajwmnghq4utucsv5maocnzfy@jpeg', created_at='2023-08-15T12:39:01.152Z', description='Twitter escapee.  Cat harborer, lawyer, exhausted mostly.', display_name='Brenda Johnson', indexed_at='2024-01-26T00:46:56.784Z', labels=[], viewer=ViewerState(blocked_by=False, blocking=None, blocking_by_list=None, followed_by=None, following=None, known_followers=None, muted=False, muted_by_list=None, py_type='app.bsky.actor.defs#viewerState'), py_type='app.bsky.actor.defs#profileView') created_at='2025-02-01T02:17:58.950Z' indexed_at='2025-02-01T02:17:58.621Z' py_type='app.bsky.feed.getLikes#like'
# actor=ProfileView(did='did:plc:j5uumgjgi2zhchzj2w3kgn3r', handle='norbizness.bsky.social', associated=ProfileAssociated(chat=ProfileAssociatedChat(allow_incoming='none', py_type='app.bsky.actor.defs#profileAssociatedChat'), feedgens=None, labeler=None, lists=None, starter_packs=None, py_type='app.bsky.actor.defs#profileAssociated'), avatar='https://cdn.bsky.app/img/avatar/plain/did:plc:j5uumgjgi2zhchzj2w3kgn3r/bafkreihdttmt22ciu36jc5uq72i4murdtwdt3rdhzrfjvftbpsawgsmwxa@jpeg', created_at='2023-11-16T04:31:09.347Z', description='Appearing again with the tedious inevitability of an unloved season.', display_name='norbizness', indexed_at='2025-01-27T21:04:46.912Z', labels=[Label(cts='1970-01-01T00:00:00.000Z', src='did:plc:j5uumgjgi2zhchzj2w3kgn3r', uri='at://did:plc:j5uumgjgi2zhchzj2w3kgn3r/app.bsky.actor.profile/self', val='!no-unauthenticated', cid='bafyreibicypdptmii35y53otzrslckk5pvyejy7mxmphvfld6pax4yqhtm', exp=None, neg=None, sig=None, ver=None, py_type='com.atproto.label.defs#label')], viewer=ViewerState(blocked_by=False, blocking=None, blocking_by_list=None, followed_by=None, following=None, known_followers=None, muted=False, muted_by_list=None, py_type='app.bsky.actor.defs#viewerState'), py_type='app.bsky.actor.defs#profileView') created_at='2025-02-01T02:16:37.707Z' indexed_at='2025-02-01T02:16:37.024Z' py_type='app.bsky.feed.getLikes#like'
# actor=ProfileView(did='did:plc:4vdtvgrdk5qwpwosmg4x6r5i', handle='janetll69.bsky.social', associated=ProfileAssociated(chat=ProfileAssociatedChat(allow_incoming='following', py_type='app.bsky.actor.defs#profileAssociatedChat'), feedgens=None, labeler=None, lists=None, starter_packs=None, py_type='app.bsky.actor.defs#profileAssociated'), avatar='https://cdn.bsky.app/img/avatar/plain/did:plc:4vdtvgrdk5qwpwosmg4x6r5i/bafkreih6qassiqs4i3vqgr7gkfy5twpkonq4e36po7wbghwxpswfy2kzlu@jpeg', created_at='2023-07-30T23:24:30.079Z', description="I'm a Witch, die-hard Longhorn, cat lover, Metallica lover, book lover, roller skater, proud Ravenclaw and much more. Engaged to @raggedrabbit.bsky.social.", display_name='Janet L ♌🤘🧙\u200d♀️🧹🛼', indexed_at='2024-06-26T03:38:45.512Z', labels=[Label(cts='1970-01-01T00:00:00.000Z', src='did:plc:4vdtvgrdk5qwpwosmg4x6r5i', uri='at://did:plc:4vdtvgrdk5qwpwosmg4x6r5i/app.bsky.actor.profile/self', val='!no-unauthenticated', cid='bafyreia5h6jhv5dkq2intqr5lkzuufhrplv7pf5rxb5jy6sgcb6efmnmdu', exp=None, neg=None, sig=None, ver=None, py_type='com.atproto.label.defs#label')], viewer=ViewerState(blocked_by=False, blocking=None, blocking_by_list=None, followed_by=None, following=None, known_followers=None, muted=False, muted_by_list=None, py_type='app.bsky.actor.defs#viewerState'), py_type='app.bsky.actor.defs#profileView') created_at='2025-02-01T02:14:54.960Z' indexed_at='2025-02-01T02:14:54.960Z' py_type='app.bsky.feed.getLikes#like'
# actor=ProfileView(did='did:plc:7eseqpztvmtdxfk6hdop5jqd', handle='mykelascott.bsky.social', associated=None, avatar='https://cdn.bsky.app/img/avatar/plain/did:plc:7eseqpztvmtdxfk6hdop5jqd/bafkreigzco4z7wk6qrcpcocxglhb6hpvyxxmds22slb7cpc2bxy3qicd2i@jpeg', created_at='2025-01-08T00:00:09.213Z', description=None, display_name='', indexed_at='2025-01-08T00:00:09.213Z', labels=[], viewer=ViewerState(blocked_by=False, blocking=None, blocking_by_list=None, followed_by=None, following=None, known_followers=None, muted=False, muted_by_list=None, py_type='app.bsky.actor.defs#viewerState'), py_type='app.bsky.actor.defs#profileView') created_at='2025-02-01T02:14:30.768Z' indexed_at='2025-02-01T02:14:30.768Z' py_type='app.bsky.feed.getLikes#like'
# actor=ProfileView(did='did:plc:zlqszxzd4uutn6k3d7leoytd', handle='worstnitemare.bsky.social', associated=None, avatar='https://cdn.bsky.app/img/avatar/plain/did:plc:zlqszxzd4uutn6k3d7leoytd/bafkreia5ib42dzilmzlhw3rwy2vo4jhvozxalcbkbpyteifkvnt4we5gpi@jpeg', created_at='2024-11-12T00:08:19.936Z', description='Democracy- #norepukes- animal rescue- fighting animal rescue charity fraud- Blue dot in a red sea is sickening- love my giant breed dogs 💙', display_name='Saphira12', indexed_at='2024-11-19T22:14:33.996Z', labels=[], viewer=ViewerState(blocked_by=False, blocking=None, blocking_by_list=None, followed_by=None, following=None, known_followers=None, muted=False, muted_by_list=None, py_type='app.bsky.actor.defs#viewerState'), py_type='app.bsky.actor.defs#profileView') created_at='2025-02-01T02:21:01.422Z' indexed_at='2025-02-01T02:14:00.618Z' py_type='app.bsky.feed.getLikes#like'
# actor=ProfileView(did='did:plc:5yxpwiis743o473oogype4x2', handle='ilovechcats.bsky.social', associated=None, avatar='https://cdn.bsky.app/img/avatar/plain/did:plc:5yxpwiis743o473oogype4x2/bafkreiexmraspst6s3cfrclyw4p27mhljw2kafvrrncpgouokvkcakc57q@jpeg', created_at='2024-12-30T08:59:39.814Z', description='A couple of wobbly kittens living their best little lives💕', display_name='Lucky & Sweetie', indexed_at='2025-01-29T04:41:28.213Z', labels=[], viewer=ViewerState(blocked_by=False, blocking=None, blocking_by_list=None, followed_by=None, following=None, known_followers=None, muted=False, muted_by_list=None, py_type='app.bsky.actor.defs#viewerState'), py_type='app.bsky.actor.defs#profileView') created_at='2025-02-01T02:13:21.816Z' indexed_at='2025-02-01T02:13:21.816Z' py_type='app.bsky.feed.getLikes#like'
# actor=ProfileView(did='did:plc:ckxyjenj3iuf5d4zkqhyrseo', handle='roobooshmoo.bsky.social', associated=None, avatar='https://cdn.bsky.app/img/avatar/plain/did:plc:ckxyjenj3iuf5d4zkqhyrseo/bafkreigmcstakzj6bkqplwz5g2pzjenfmt5lziqhsru7vayme3vxibwiui@jpeg', created_at='2024-11-09T05:13:51.415Z', description=None, display_name='RooBooShmoo', indexed_at='2024-11-09T05:17:04.516Z', labels=[], viewer=ViewerState(blocked_by=False, blocking=None, blocking_by_list=None, followed_by=None, following=None, known_followers=None, muted=False, muted_by_list=None, py_type='app.bsky.actor.defs#viewerState'), py_type='app.bsky.actor.defs#profileView') created_at='2025-02-01T02:13:12.753Z' indexed_at='2025-02-01T02:13:12.753Z' py_type='app.bsky.feed.getLikes#like'
# actor=ProfileView(did='did:plc:ecqzmcvqhh3vunvstjefh6h5', handle='andyorban.bsky.social', associated=None, avatar='https://cdn.bsky.app/img/avatar/plain/did:plc:ecqzmcvqhh3vunvstjefh6h5/bafkreigc3t2o2tllkuzajt5okfa7y7f4gtljaccfpltsbuutffjpapzbh4@jpeg', created_at='2024-11-04T15:42:44.618Z', description='Architect, husband & dad, lives in Charlottesville. Bikes for fun and for transport.', display_name='Andy Orban', indexed_at='2024-12-01T05:20:32.407Z', labels=[], viewer=ViewerState(blocked_by=False, blocking=None, blocking_by_list=None, followed_by=None, following=None, known_followers=None, muted=False, muted_by_list=None, py_type='app.bsky.actor.defs#viewerState'), py_type='app.bsky.actor.defs#profileView') created_at='2025-02-01T02:11:00.798Z' indexed_at='2025-02-01T02:11:00.798Z' py_type='app.bsky.feed.getLikes#like'
# actor=ProfileView(did='did:plc:vbhs3yecd74cmoaht2khocza', handle='yuvrajjoshi.bsky.social', associated=ProfileAssociated(chat=ProfileAssociatedChat(allow_incoming='following', py_type='app.bsky.actor.defs#profileAssociatedChat'), feedgens=None, labeler=None, lists=None, starter_packs=None, py_type='app.bsky.actor.defs#profileAssociated'), avatar='https://cdn.bsky.app/img/avatar/plain/did:plc:vbhs3yecd74cmoaht2khocza/bafkreiaan34saaxivddlt6mnj3pdayess2qxtjr5zbiawvtrusuydf24qi@jpeg', created_at='2023-08-09T16:51:03.522Z', description='Law professor. Constitutional Law, Racial Justice, Human Rights. He/him 🏳️\u200d🌈.', display_name='Yuvraj Joshi', indexed_at='2025-01-20T18:51:47.214Z', labels=[], viewer=ViewerState(blocked_by=False, blocking=None, blocking_by_list=None, followed_by=None, following=None, known_followers=None, muted=False, muted_by_list=None, py_type='app.bsky.actor.defs#viewerState'), py_type='app.bsky.actor.defs#profileView') created_at='2025-02-01T02:10:18.484Z' indexed_at='2025-02-01T02:10:18.484Z' py_type='app.bsky.feed.getLikes#like'
# actor=ProfileView(did='did:plc:lm4bqisi3rztdxieymib55di', handle='baphyduck.bsky.social', associated=None, avatar='https://cdn.bsky.app/img/avatar/plain/did:plc:lm4bqisi3rztdxieymib55di/bafkreidqxntpzlb5cgh57v64jrfic4vpxi2hxunw7egbqlmydrpfibrxim@jpeg', created_at='2024-11-15T01:57:46.393Z', description='         “It’s too bad stupidity isn’t painful.” -ASL \n\n 𖤐 18↑ Only! • she/her • living life to the fullest. 𖤐\n                             pfp by: cozydalia', display_name='Benny 𖤐', indexed_at='2025-02-01T00:26:24.513Z', labels=[Label(cts='2024-11-15T01:57:38.472Z', src='did:plc:lm4bqisi3rztdxieymib55di', uri='at://did:plc:lm4bqisi3rztdxieymib55di/app.bsky.actor.profile/self', val='!no-unauthenticated', cid='bafyreifxcuiogddwbvtpp3i4jo6s6ipz42bz5au76q3zdgbwt2kawtrove', exp=None, neg=None, sig=None, ver=None, py_type='com.atproto.label.defs#label')], viewer=ViewerState(blocked_by=False, blocking=None, blocking_by_list=None, followed_by=None, following='at://did:plc:ktkc7jfakxzjpooj52ffc6ra/app.bsky.graph.follow/3lglyr4obp52p', known_followers=None, muted=False, muted_by_list=None, py_type='app.bsky.actor.defs#viewerState'), py_type='app.bsky.actor.defs#profileView') created_at='2025-02-01T02:09:03.031Z' indexed_at='2025-02-01T02:09:03.031Z' py_type='app.bsky.feed.getLikes#like'
# actor=ProfileView(did='did:plc:svihkbezxwxdtnyyfkm5eb3s', handle='lawprofblawg.bsky.social', associated=ProfileAssociated(chat=ProfileAssociatedChat(allow_incoming='following', py_type='app.bsky.actor.defs#profileAssociatedChat'), feedgens=None, labeler=None, lists=None, starter_packs=None, py_type='app.bsky.actor.defs#profileAssociated'), avatar='https://cdn.bsky.app/img/avatar/plain/did:plc:svihkbezxwxdtnyyfkm5eb3s/bafkreib77fcjsx6zkra65r2mfzuxgbpfqluxni4bor6ibi3jkkfemaebuu@jpeg', created_at='2023-06-04T18:17:08.777Z', description='Law Professor. Economist. \n\nCo-Author of a law review article and author of a few blog posts.  \n\nhttps://papers.ssrn.com/sol3/papers.cfm?abstract_id=3339527\n\nMastodon:  @lawprofblawg@mstdn.social.  \nTwitter: @lawprofblawg', display_name='Lawprofblawg', indexed_at='2024-11-12T07:14:40.437Z', labels=[], viewer=ViewerState(blocked_by=False, blocking=None, blocking_by_list=None, followed_by=None, following=None, known_followers=None, muted=False, muted_by_list=None, py_type='app.bsky.actor.defs#viewerState'), py_type='app.bsky.actor.defs#profileView') created_at='2025-02-01T02:08:11.851Z' indexed_at='2025-02-01T02:08:11.851Z' py_type='app.bsky.feed.getLikes#like'
# actor=ProfileView(did='did:plc:aql7pqvjg6lmm6ixftpnzhqo', handle='deborahahrens.bsky.social', associated=None, avatar='https://cdn.bsky.app/img/avatar/plain/did:plc:aql7pqvjg6lmm6ixftpnzhqo/bafkreibvivandbukr5biuc33x66amgie6f6v6aqfbncidjzgemmde7bpby@jpeg', created_at='2023-08-07T00:21:29.787Z', description='Crimprof, evidence curmudgeon, former public defender, Seattle University School of Law professor, true crime enthusiast, parent of many, fan of bitter food.', display_name='Deborah Ahrens', indexed_at='2024-01-26T00:48:18.122Z', labels=[], viewer=ViewerState(blocked_by=False, blocking=None, blocking_by_list=None, followed_by=None, following=None, known_followers=None, muted=False, muted_by_list=None, py_type='app.bsky.actor.defs#viewerState'), py_type='app.bsky.actor.defs#profileView') created_at='2025-02-01T02:06:39.353Z' indexed_at='2025-02-01T02:06:39.353Z' py_type='app.bsky.feed.getLikes#like'
# actor=ProfileView(did='did:plc:vmndlcbq5scfce35ethtoq5j', handle='clairemyfanwy.bsky.social', associated=None, avatar='https://cdn.bsky.app/img/avatar/plain/did:plc:vmndlcbq5scfce35ethtoq5j/bafkreie7ahcsb5ufukdnorz3lqlicdvefctkh3wijgisv5l54u64kmjdfq@jpeg', created_at='2024-08-06T15:30:44.907Z', description='Chronically ill Doctor: #MECFS #POTS #MCAS\nSupport freedom & democracy everywhere:\n🇬🇧🏴\U000e0067\U000e0062\U000e0077\U000e006c\U000e0073\U000e007f🇪🇺🇺🇦🇺🇲 #fella\nKnowledge sponge. Overthinker.\nShare/Like/Follow ≠ endorsement', display_name="It's Not All About ME", indexed_at='2024-11-12T07:09:46.436Z', labels=[Label(cts='2024-08-06T15:30:42.886Z', src='did:plc:vmndlcbq5scfce35ethtoq5j', uri='at://did:plc:vmndlcbq5scfce35ethtoq5j/app.bsky.actor.profile/self', val='!no-unauthenticated', cid='bafyreici2vko564s3nt3lrh4fsznpjmlrgm6hfe37h2kd5tl4rhmjvffmq', exp=None, neg=None, sig=None, ver=None, py_type='com.atproto.label.defs#label')], viewer=ViewerState(blocked_by=False, blocking=None, blocking_by_list=None, followed_by=None, following=None, known_followers=None, muted=False, muted_by_list=None, py_type='app.bsky.actor.defs#viewerState'), py_type='app.bsky.actor.defs#profileView') created_at='2025-02-01T02:06:21.300Z' indexed_at='2025-02-01T02:06:18.417Z' py_type='app.bsky.feed.getLikes#like'
# actor=ProfileView(did='did:plc:yn4gpjoryeb4pgfw5e2y7dqv', handle='attyepi.bsky.social', associated=None, avatar='https://cdn.bsky.app/img/avatar/plain/did:plc:yn4gpjoryeb4pgfw5e2y7dqv/bafkreig2wmzo7m7ptnsturivl5eg4fdn55dygcyrdjumqzmnrzj2b3t2x4@jpeg', created_at='2024-11-17T22:07:18.920Z', description='they/them\nAutistic/ADHD\n99% of my posts will be my cats 😺😺😺\nEveryone deserves food, housing, and healthcare\n✅️ comment/respond\n🚫 DM ... I will just ignore and/or block', display_name='Atty Epi', indexed_at='2024-12-19T21:05:21.812Z', labels=[], viewer=ViewerState(blocked_by=False, blocking=None, blocking_by_list=None, followed_by='at://did:plc:yn4gpjoryeb4pgfw5e2y7dqv/app.bsky.graph.follow/3lgchl5a5h623', following='at://did:plc:ktkc7jfakxzjpooj52ffc6ra/app.bsky.graph.follow/3lgcgpezh7m2l', known_followers=None, muted=False, muted_by_list=None, py_type='app.bsky.actor.defs#viewerState'), py_type='app.bsky.actor.defs#profileView') created_at='2025-02-01T02:05:56.780Z' indexed_at='2025-02-01T02:05:56.780Z' py_type='app.bsky.feed.getLikes#like'
# actor=ProfileView(did='did:plc:uzh5c3leyul6hdvfd3grcp6r', handle='saffronsfloof.bsky.social', associated=ProfileAssociated(chat=ProfileAssociatedChat(allow_incoming='following', py_type='app.bsky.actor.defs#profileAssociatedChat'), feedgens=None, labeler=None, lists=None, starter_packs=None, py_type='app.bsky.actor.defs#profileAssociated'), avatar='https://cdn.bsky.app/img/avatar/plain/did:plc:uzh5c3leyul6hdvfd3grcp6r/bafkreihiywratvgx5u27tybdkt2ecfvusc6nqx7iae3bfuo2ly7vbreut4@jpeg', created_at='2024-10-09T20:13:25.442Z', description='🐈\u200d⬛ + 💁🏻\u200d♀️. Daily cat adventures. Love 🌅, walks, and 🪶 Proud owner of world’s cutest meow and fluffiest tail. Bonded sis to Spice & aspiring friend to Zeo.\n\nPosts are a lil’ bit of everything, with a dose of mama’s 📸, responses, humor, & whimsy.', display_name='Saffron & Her Majestic Floof', indexed_at='2025-01-09T11:01:04.812Z', labels=[Label(cts='2024-10-09T20:13:23.915Z', src='did:plc:uzh5c3leyul6hdvfd3grcp6r', uri='at://did:plc:uzh5c3leyul6hdvfd3grcp6r/app.bsky.actor.profile/self', val='!no-unauthenticated', cid='bafyreibo6kj2nmkgrebutwwnt4gaacf7b5e4k7e52gpjjqdqdag66unauq', exp=None, neg=None, sig=None, ver=None, py_type='com.atproto.label.defs#label')], viewer=ViewerState(blocked_by=False, blocking=None, blocking_by_list=None, followed_by=None, following=None, known_followers=None, muted=False, muted_by_list=None, py_type='app.bsky.actor.defs#viewerState'), py_type='app.bsky.actor.defs#profileView') created_at='2025-02-01T02:03:51.964Z' indexed_at='2025-02-01T02:03:51.964Z' py_type='app.bsky.feed.getLikes#like'
# actor=ProfileView(did='did:plc:jrefz3ve4vy5ayn7s7ge57ub', handle='emeldaalonzo.bsky.social', associated=None, avatar='https://cdn.bsky.app/img/avatar/plain/did:plc:jrefz3ve4vy5ayn7s7ge57ub/bafkreibvyqa5fq5to24s6he6gzvm4cgvukjdlrziilqbfmd3t6agpzuije@jpeg', created_at='2023-06-22T18:36:06.094Z', description="Austin budget manager by day, news junkie 24/7. It's a gift. Glad my journalism degrees have come in handy. Here for the animal content. Scritches for all. #HookEm", display_name='Emelda Alonzo', indexed_at='2024-11-12T02:55:55.743Z', labels=[Label(cts='1970-01-01T00:00:00.000Z', src='did:plc:jrefz3ve4vy5ayn7s7ge57ub', uri='at://did:plc:jrefz3ve4vy5ayn7s7ge57ub/app.bsky.actor.profile/self', val='!no-unauthenticated', cid='bafyreih4gddl5atygtvbtjb55ag37qwbsmro6ofv5lgl2hpbponux53b6q', exp=None, neg=None, sig=None, ver=None, py_type='com.atproto.label.defs#label')], viewer=ViewerState(blocked_by=False, blocking=None, blocking_by_list=None, followed_by=None, following=None, known_followers=None, muted=False, muted_by_list=None, py_type='app.bsky.actor.defs#viewerState'), py_type='app.bsky.actor.defs#profileView') created_at='2025-02-01T02:03:18.219Z' indexed_at='2025-02-01T02:03:18.219Z' py_type='app.bsky.feed.getLikes#like'
# actor=ProfileView(did='did:plc:742dyttpas2bg5rirnfgjzvw', handle='chrisdaae3.bsky.social', associated=None, avatar='https://cdn.bsky.app/img/avatar/plain/did:plc:742dyttpas2bg5rirnfgjzvw/bafkreibhtnjo3bx3homkkz2qv7nvoc6stdgms3bi6ntbj462kbdpho6z3q@jpeg', created_at='2024-11-09T15:22:34.413Z', description=None, display_name='', indexed_at='2024-11-09T15:22:34.413Z', labels=[], viewer=ViewerState(blocked_by=False, blocking=None, blocking_by_list=None, followed_by=None, following=None, known_followers=None, muted=False, muted_by_list=None, py_type='app.bsky.actor.defs#viewerState'), py_type='app.bsky.actor.defs#profileView') created_at='2025-02-01T02:02:55.567Z' indexed_at='2025-02-01T02:02:55.567Z' py_type='app.bsky.feed.getLikes#like'
# actor=ProfileView(did='did:plc:sq65ibx5i2vhrjkvhkfdw2it', handle='kkmortier.bsky.social', associated=ProfileAssociated(chat=ProfileAssociatedChat(allow_incoming='following', py_type='app.bsky.actor.defs#profileAssociatedChat'), feedgens=None, labeler=None, lists=None, starter_packs=None, py_type='app.bsky.actor.defs#profileAssociated'), avatar='https://cdn.bsky.app/img/avatar/plain/did:plc:sq65ibx5i2vhrjkvhkfdw2it/bafkreidjmtgmony5q2pyz5mdt7u54t2plv4eifocr7xwbjlnn3og3syd5y@jpeg', created_at='2023-12-18T01:03:09.462Z', description='Air Force brat. Mom to grown ass kids, an ornery cat, and a stubborn dog. Hockey and college football are the best sports. It was so quiet before you all got here.', display_name='kkmortier', indexed_at='2024-11-21T12:09:10.433Z', labels=[Label(cts='1970-01-01T00:00:00.000Z', src='did:plc:sq65ibx5i2vhrjkvhkfdw2it', uri='at://did:plc:sq65ibx5i2vhrjkvhkfdw2it/app.bsky.actor.profile/self', val='!no-unauthenticated', cid='bafyreifvdsrznkskklt3z276udf4lsl27bktsrulagwdiu47nk5cqiucgq', exp=None, neg=None, sig=None, ver=None, py_type='com.atproto.label.defs#label')], viewer=ViewerState(blocked_by=False, blocking=None, blocking_by_list=None, followed_by=None, following=None, known_followers=None, muted=False, muted_by_list=None, py_type='app.bsky.actor.defs#viewerState'), py_type='app.bsky.actor.defs#profileView') created_at='2025-02-01T02:02:44.029Z' indexed_at='2025-02-01T02:02:44.029Z' py_type='app.bsky.feed.getLikes#like'
# actor=ProfileView(did='did:plc:f4d76fjna5nxqsy2fu6cgmp3', handle='evanbernick.bsky.social', associated=ProfileAssociated(chat=ProfileAssociatedChat(allow_incoming='following', py_type='app.bsky.actor.defs#profileAssociatedChat'), feedgens=None, labeler=None, lists=None, starter_packs=None, py_type='app.bsky.actor.defs#profileAssociated'), avatar='https://cdn.bsky.app/img/avatar/plain/did:plc:f4d76fjna5nxqsy2fu6cgmp3/bafkreiaatyy4gkl4vjhww7uq4tlb4tgmo3p7igmsvqtmzewt2j7cqvsb7y@jpeg', created_at='2023-07-03T11:49:21.823Z', description='Associate Prof at Northern Illinois University College of Law. Constitutional law, criminal law, abolition, philosophy, hoops, puppies (esp. Argo the Floof): He/him.', display_name='Evan Bernick, a finite mode with a resolute floof', indexed_at='2025-01-02T21:56:13.113Z', labels=[], viewer=ViewerState(blocked_by=False, blocking=None, blocking_by_list=None, followed_by=None, following=None, known_followers=None, muted=False, muted_by_list=None, py_type='app.bsky.actor.defs#viewerState'), py_type='app.bsky.actor.defs#profileView') created_at='2025-02-01T02:01:19.181Z' indexed_at='2025-02-01T02:01:19.181Z' py_type='app.bsky.feed.getLikes#like'
# actor=ProfileView(did='did:plc:u2agmbq3fjdugd2s3nlatqwx', handle='tlbjames.bsky.social', associated=ProfileAssociated(chat=ProfileAssociatedChat(allow_incoming='following', py_type='app.bsky.actor.defs#profileAssociatedChat'), feedgens=None, labeler=None, lists=None, starter_packs=None, py_type='app.bsky.actor.defs#profileAssociated'), avatar='https://cdn.bsky.app/img/avatar/plain/did:plc:u2agmbq3fjdugd2s3nlatqwx/bafkreifrfzhwwyzrbv5kjct2zgn44yladbzr3zgyg7rnerpe6ju2qkvnpq@jpeg', created_at='2023-06-22T00:16:27.166Z', description="🌈 Science-literate gay Gen-X misanthrope married to @TLBTim.bsky.social. Grizzled copy editor, proud dogfather, rude grammarian, self-pub'd queer SFF/horror author, podcaster since 8/10/06 (@TrashSprinkles.bsky.social), and pragmatic nihilist. He/Him", display_name='James', indexed_at='2025-01-18T20:59:30.813Z', labels=[Label(cts='1970-01-01T00:00:00.000Z', src='did:plc:u2agmbq3fjdugd2s3nlatqwx', uri='at://did:plc:u2agmbq3fjdugd2s3nlatqwx/app.bsky.actor.profile/self', val='!no-unauthenticated', cid='bafyreif72hmkvu6n5xhyw7tmuikrvw7vcit5l3ikui6c6nbjhr5uokzwy4', exp=None, neg=None, sig=None, ver=None, py_type='com.atproto.label.defs#label')], viewer=ViewerState(blocked_by=False, blocking=None, blocking_by_list=None, followed_by=None, following=None, known_followers=None, muted=False, muted_by_list=None, py_type='app.bsky.actor.defs#viewerState'), py_type='app.bsky.actor.defs#profileView') created_at='2025-02-01T02:01:18.858Z' indexed_at='2025-02-01T02:01:18.858Z' py_type='app.bsky.feed.getLikes#like'
# actor=ProfileView(did='did:plc:gnijwzcpldzgr3h6njwut6mp', handle='jaymiemoore.bsky.social', associated=ProfileAssociated(chat=ProfileAssociatedChat(allow_incoming='following', py_type='app.bsky.actor.defs#profileAssociatedChat'), feedgens=None, labeler=None, lists=None, starter_packs=None, py_type='app.bsky.actor.defs#profileAssociated'), avatar='https://cdn.bsky.app/img/avatar/plain/did:plc:gnijwzcpldzgr3h6njwut6mp/bafkreifb7qx5vvlgpipz2r7n3ahctphbcr5yx2vt5svu4aiy4vwc2xaua4@jpeg', created_at='2023-12-01T14:28:50.566Z', description='Formerly with Human Engineering Life Laboratories, now a researcher with Occult Research Center (if you get the refences, Rao protect you), trans, she/her they/them', display_name='Jaymie Moore', indexed_at='2024-11-17T17:25:50.163Z', labels=[], viewer=ViewerState(blocked_by=False, blocking=None, blocking_by_list=None, followed_by=None, following=None, known_followers=None, muted=False, muted_by_list=None, py_type='app.bsky.actor.defs#viewerState'), py_type='app.bsky.actor.defs#profileView') created_at='2025-02-01T02:01:11.298Z' indexed_at='2025-02-01T02:01:11.298Z' py_type='app.bsky.feed.getLikes#like'
# actor=ProfileView(did='did:plc:cmdqzehaqbrxkhnxsolmk6w2', handle='rickweinmeyer.bsky.social', associated=ProfileAssociated(chat=ProfileAssociatedChat(allow_incoming='all', py_type='app.bsky.actor.defs#profileAssociatedChat'), feedgens=None, labeler=None, lists=None, starter_packs=None, py_type='app.bsky.actor.defs#profileAssociated'), avatar='https://cdn.bsky.app/img/avatar/plain/did:plc:cmdqzehaqbrxkhnxsolmk6w2/bafkreifthiuy352ffsnv25qaqb7p56gpvcudexrwxlpqkreorhgams6wn4@jpeg', created_at='2023-07-01T20:46:41.612Z', description='Assistant Professor - Loyola University Chicago Law • PhD - Northwestern, JD - Minnesota • I study 🚽s, sanitation, public health law, health policy • Forever UW Dawg & Cantab • Like, super gay 🏳️\u200d🌈', display_name='Rick Weinmeyer', indexed_at='2025-02-01T00:05:30.913Z', labels=[], viewer=ViewerState(blocked_by=False, blocking=None, blocking_by_list=None, followed_by=None, following=None, known_followers=None, muted=False, muted_by_list=None, py_type='app.bsky.actor.defs#viewerState'), py_type='app.bsky.actor.defs#profileView') created_at='2025-02-01T02:01:05.956Z' indexed_at='2025-02-01T02:01:05.956Z' py_type='app.bsky.feed.getLikes#like'
# actor=ProfileView(did='did:plc:3maysedii4tlyvoknevwam4v', handle='rexvrex.bsky.social', associated=ProfileAssociated(chat=ProfileAssociatedChat(allow_incoming='following', py_type='app.bsky.actor.defs#profileAssociatedChat'), feedgens=None, labeler=None, lists=None, starter_packs=None, py_type='app.bsky.actor.defs#profileAssociated'), avatar='https://cdn.bsky.app/img/avatar/plain/did:plc:3maysedii4tlyvoknevwam4v/bafkreicyrfwkcmtnh25mbr5jx2sio76acxqgc77w3sictgvkxll4ffnc5u@jpeg', created_at='2023-08-11T14:55:23.032Z', description='Friendly-ish HTX neighborhood lawyer & doomscroller extraordinaire', display_name='rexvrex ', indexed_at='2024-08-20T00:21:45.019Z', labels=[Label(cts='1970-01-01T00:00:00.000Z', src='did:plc:3maysedii4tlyvoknevwam4v', uri='at://did:plc:3maysedii4tlyvoknevwam4v/app.bsky.actor.profile/self', val='!no-unauthenticated', cid='bafyreie7vchrypwl67xdhfroi65cymizwsilkovduturk42n7xzzuvy5ey', exp=None, neg=None, sig=None, ver=None, py_type='com.atproto.label.defs#label')], viewer=ViewerState(blocked_by=False, blocking=None, blocking_by_list=None, followed_by=None, following=None, known_followers=None, muted=False, muted_by_list=None, py_type='app.bsky.actor.defs#viewerState'), py_type='app.bsky.actor.defs#profileView') created_at='2025-02-01T02:00:15.711Z' indexed_at='2025-02-01T02:00:15.711Z' py_type='app.bsky.feed.getLikes#like'

# %%
likes = client.get_likes(post_uri, cid=post_cid).likes
print(likes)
print(len(likes))
# Out:
# [Like(actor=ProfileView(did='did:plc:z3bbabbmwysumlmj67tof2b3', handle='millyp.bsky.social', associated=None, avatar='https://cdn.bsky.app/img/avatar/plain/did:plc:z3bbabbmwysumlmj67tof2b3/bafkreiejghtnikjfupajfoe3jcs6uyti2nahgjqwa64fpsnnlwcb4rzeky@jpeg', created_at='2023-07-08T02:42:55.487Z', description=None, display_name='Milton', indexed_at='2025-01-22T01:16:49.613Z', labels=[], viewer=ViewerState(blocked_by=False, blocking=None, blocking_by_list=None, followed_by=None, following=None, known_followers=None, muted=False, muted_by_list=None, py_type='app.bsky.actor.defs#viewerState'), py_type='app.bsky.actor.defs#profileView'), created_at='2025-02-01T02:31:32.656Z', indexed_at='2025-02-01T02:31:32.656Z', py_type='app.bsky.feed.getLikes#like'), Like(actor=ProfileView(did='did:plc:dgkyncbh6kcchafzi55rqltt', handle='smmarotta.bsky.social', associated=None, avatar='https://cdn.bsky.app/img/avatar/plain/did:plc:dgkyncbh6kcchafzi55rqltt/bafkreig2poupnpkulju2mhoo7cgiyd23mbmqjgd2rh6rdlbofhvttuky7u@jpeg', created_at='2023-05-23T03:32:46.024Z', description="Partner with Hogan Lovells's Appellate and Supreme Court and Administrative Litigation groups.  #AppellateSky member.  Skeets mine.  Banner image by Art Lien.", display_name='Sean Marotta', indexed_at='2024-12-11T21:48:02.913Z', labels=[], viewer=ViewerState(blocked_by=False, blocking=None, blocking_by_list=None, followed_by=None, following=None, known_followers=None, muted=False, muted_by_list=None, py_type='app.bsky.actor.defs#viewerState'), py_type='app.bsky.actor.defs#profileView'), created_at='2025-02-01T02:30:48.213Z', indexed_at='2025-02-01T02:30:48.213Z', py_type='app.bsky.feed.getLikes#like'), Like(actor=ProfileView(did='did:plc:ztoagmcugarp5ue37yeonb5f', handle='andyve.bsky.social', associated=ProfileAssociated(chat=ProfileAssociatedChat(allow_incoming='following', py_type='app.bsky.actor.defs#profileAssociatedChat'), feedgens=None, labeler=None, lists=None, starter_packs=None, py_type='app.bsky.actor.defs#profileAssociated'), avatar='https://cdn.bsky.app/img/avatar/plain/did:plc:ztoagmcugarp5ue37yeonb5f/bafkreifi4z4dovcdlcqxz763u3rslr7z5h3zt67lq6n753d2wncl3qqp2y@jpeg', created_at='2024-03-27T23:12:48.343Z', description=None, display_name='Andy Van Epps', indexed_at='2024-08-06T15:13:31.106Z', labels=[], viewer=ViewerState(blocked_by=False, blocking=None, blocking_by_list=None, followed_by=None, following=None, known_followers=None, muted=False, muted_by_list=None, py_type='app.bsky.actor.defs#viewerState'), py_type='app.bsky.actor.defs#profileView'), created_at='2025-02-01T02:28:58.966Z', indexed_at='2025-02-01T02:28:58.966Z', py_type='app.bsky.feed.getLikes#like'), Like(actor=ProfileView(did='did:plc:52y4vre3rlxjk3267qwyffus', handle='iamaholly.bsky.social', associated=None, avatar='https://cdn.bsky.app/img/avatar/plain/did:plc:52y4vre3rlxjk3267qwyffus/bafkreibusyihwe73b3asliilra7s3u6nybur36mmkhfj7tpexp7f7xj3me@jpeg', created_at='2023-09-20T12:36:55.380Z', description='Sociologist at Ohio U. Narrative criminology, green criminology, and gender-based violence. Chelsea Green Bean.', display_name='Holly Ningard', indexed_at='2024-12-15T04:06:13.813Z', labels=[], viewer=ViewerState(blocked_by=False, blocking=None, blocking_by_list=None, followed_by=None, following=None, known_followers=None, muted=False, muted_by_list=None, py_type='app.bsky.actor.defs#viewerState'), py_type='app.bsky.actor.defs#profileView'), created_at='2025-02-01T02:22:17.135Z', indexed_at='2025-02-01T02:22:16.723Z', py_type='app.bsky.feed.getLikes#like'), Like(actor=ProfileView(did='did:plc:bqwcgjaecinvqxetjnjuygel', handle='morfaleji.bsky.social', associated=None, avatar='https://cdn.bsky.app/img/avatar/plain/did:plc:bqwcgjaecinvqxetjnjuygel/bafkreidqvpuhxcmd5j3v5rrsedxfaisuuza6g6xg6sjiprl7ds7z7qg5ce@jpeg', created_at='2024-02-18T20:11:48.096Z', description='Husband. Flack. Principal Consultant, Morphology Media Relations LLC. Pirkei Avot 2:21. #unionmember. DC via Cincinnati. @morfaleji most places',  ...
# 30

# %%
EMBEDDED_PIC = 'app.bsky.embed.images#view'

for i, f in enumerate(data.feed):
  if not f.post.embed or f.post.embed.py_type != EMBEDDED_PIC:
    print('no pic for post at', i)
  else:
    print(i, f.post.embed.images[0].fullsize)

# print(data.feed[0].post.embed.images[0].fullsize)
# Out:
# 0 https://cdn.bsky.app/img/feed_fullsize/plain/did:plc:uqnyrpls22pqbicmdkwnlvli/bafkreibd2hmxklohejn6imqo7uxtlep5y5gwmdvztxxdek2wtqksdfht5m@jpeg
# no pic for post at 1
# 2 https://cdn.bsky.app/img/feed_fullsize/plain/did:plc:me25ptvza6pvbhldxmslfski/bafkreibp66miin4cb4zgwsuzbozpqfvgsxykheypddcmm6y3xf3jdrlc24@jpeg
# 3 https://cdn.bsky.app/img/feed_fullsize/plain/did:plc:edznrxcch4eoquz6szpthe6r/bafkreido47kwsfbnin663vxekuuzhr7ubmyq7zqkv53lnr65u7flam3q7y@jpeg
# 4 https://cdn.bsky.app/img/feed_fullsize/plain/did:plc:2gvkp6lxy6i7dugkza6q6tvh/bafkreiapf4hbaraoswd7mlplo642n2ftp4ddqov4aryejcypnjgxfcnfn4@jpeg
# 5 https://cdn.bsky.app/img/feed_fullsize/plain/did:plc:mda5p64chnynpei53huhdv4g/bafkreiea4he5ch6mtpxanhgnz7rsy34a6d6nujtdnutm2rahyfww2sjpma@jpeg
# 6 https://cdn.bsky.app/img/feed_fullsize/plain/did:plc:kuaday3keoocnfw5utp4w6la/bafkreifyi5ai23g4id5sswfvdj7lx2l7uywplho7l67xv3uqqlrs45j254@jpeg
# 7 https://cdn.bsky.app/img/feed_fullsize/plain/did:plc:muyvftnlabmtsskktmohqsls/bafkreias3bblu7rp3jcc3qzipyeivkjappeghuatsenocbyqz3noin252e@jpeg
# 8 https://cdn.bsky.app/img/feed_fullsize/plain/did:plc:4eyrjmujfx3uc3c55afb4zm4/bafkreiga4xuqniu5hakfav23oilogwaxyk7q3kcoc7klqjwm5xgcujjk7q@jpeg
# 9 https://cdn.bsky.app/img/feed_fullsize/plain/did:plc:dqmtm36rzpocwpcsenc7wh2o/bafkreicf4nrxxczsdmtvoaflzhrxg6qlw2myyd57jmavixwei445jto6aa@jpeg
# 10 https://cdn.bsky.app/img/feed_fullsize/plain/did:plc:7ni6ktnv7pnp3pk6eosdznrg/bafkreifuhvfp7beu3lda5wxabdnuo3bb6bg25a5v77eits5q5nt5vghiom@jpeg
# 11 https://cdn.bsky.app/img/feed_fullsize/plain/did:plc:vvs5hxfxe7qufvmwyuixopl5/bafkreif7szejawhkzcia7ocndnvtbmzwvqjzryxnkxygu2kgc2neeevgem@jpeg
# 12 https://cdn.bsky.app/img/feed_fullsize/plain/did:plc:5l43mhwno3poaz76xhm3xftg/bafkreigl3yb7ufg5t7xksiiaxiscnxgmawzchkluep5bdsqhhmptwa57jy@jpeg
# 13 https://cdn.bsky.app/img/feed_fullsize/plain/did:plc:vseant7txzthd77i4kjhxm54/bafkreib2y2hlzxtwke2nw7cukamcnxic3ipqw245e3k5zdrt3ftkj2bqyy@jpeg
# 14 https://cdn.bsky.app/img/feed_fullsize/plain/did:plc:ncjnyxonoz56loxqf4yfndrg/bafkreie5kuqcwmr23ueg4ifmy4a2rbyjwvldw7gxgtetugywkf5zod3mfe@jpeg
# 15 https://cdn.bsky.app/img/feed_fullsize/plain/did:plc:36ojg56skq364ud54uhrurdb/bafkreifajy2jddw4iu5t42uesfycgi5wuwvwnwsq7jqw5rd2662utseely@jpeg
# 16 https://cdn.bsky.app/img/feed_fullsize/plain/did:plc:zgp7z3cshf5wqv2jifj4mij2/bafkreid3mzfrmpursszemfst6jy3nggrcpjczaeiqe6djqlwxuubchgrly@jpeg
# 17 https://cdn.bsky.app/img/feed_fullsize/plain/did:plc:ia2vcw2y3sbkuiif4vqcgo5n/bafkreievt3ad45gfduwcjpvsvnffctw6iaxrm4ikw7crtewixgfoizh7my@jpeg
# no pic for post at 18
# 19 https://cdn.bsky.app/img/feed_fullsize/plain/did:plc:uikhh4ytkn7hivripzltye7z/bafkreifkbpmallcmty2vp5uv27yk7fvgq2vcrvytv4brpxjt545og4tewm@jpeg
# 20 https://cdn.bsky.app/img/feed_fullsize/plain/did:plc:muyvftnlabmtsskktmohqsls/bafkreifgkox2hehrwt5g7phzrdibq7ywrhbywn542cdd2ybl523ggy4z64@jpeg
# 21 https://cdn.bsky.app/img/feed_fullsize/plain/did:plc:gprnt72k5ediqv4phk635ih3/bafkreiccguusxlqhij3gxanariavnzqkk3zxm4f5iuyyn73i4qjyfm4lse@jpeg
# 22 https://cdn.bsky.app/img/feed_fullsize/plain/did:plc:35swtcy4cgxavdub6x7ziune/bafkreifhcqeqb6oiep5kb7gxrzc2j76s52dxoywwxs26v3izxq7qhxmoem@jpeg
# no pic for post at 23
# 24 https://cdn.bsky.app/img/feed_fullsize/plain/did:plc:eaczcs2hvxyol5uk3wdwsmue/bafkreidrqzo6s4saeyacc37d72jb6fipfwloouf5bvszcq5rvzanqwr6lm@jpeg
# 25 https://cdn.bsky.app/img/feed_fullsize/plain/did:plc:nlmhlsy3f7jspfvfwkxaon3e/bafkreifh6iaxbzjltvc3pxpusbavcwb6dsurro2i56nlzcs4n5pcpsdtdu@jpeg
# no pic for post at 26
# 27 https://cdn.bsky.app/img/feed_fullsize/plain/did:plc:pjnm3nfjp6noqcs77qrfhwj6/bafkreibwllyeklpi3ddwhtrf7wmbe4gtge6rrvsyaxouu6t2byqo67u6v4@jpeg
# 28 https://cdn.bsky.app/img/feed_fullsize/plain/did:plc:h3hk2cmxuf7ymqyyx3jhkyni/bafkreiewnzrok7oou7qvfmfbyoxjcv3lwv7en5h65z7v56sct6e7zqgcky@jpeg
# 29 https://cdn.bsky.app/img/feed_fullsize/plain/did:plc:qjid6tlunbmxdplja6rckhmb/bafkreidlvthbbiq7rgnyv5kfmuj3v6e7mixn4cgaaqwlvgto4x3lk3czuu@jpeg

# %%
print(data.feed[0].post.embed)
# will return None if there are no images
# will return images=[...]
# Out:
# images=[ViewImage(alt='Desperado, an orange cat, sleeps curled in an awkward position on top of a gray and black patterned blanket', fullsize='https://cdn.bsky.app/img/feed_fullsize/plain/did:plc:xeoa6zhnvmrnwb2jajkzgdew/bafkreiguwoio63ksukkjkwgudgzxjq7yxxogxk2xbiusnhbwpprjvyzpgu@jpeg', thumb='https://cdn.bsky.app/img/feed_thumbnail/plain/did:plc:xeoa6zhnvmrnwb2jajkzgdew/bafkreiguwoio63ksukkjkwgudgzxjq7yxxogxk2xbiusnhbwpprjvyzpgu@jpeg', aspect_ratio=AspectRatio(height=2000, width=1500, py_type='app.bsky.embed.defs#aspectRatio'), py_type='app.bsky.embed.images#viewImage')] py_type='app.bsky.embed.images#view'

# %%
# so if that didn't return None you can use
data.feed[0].post.embed.images[0]
# to get the first image
# the url is found at
data.feed[0].post.embed.images[0].fullsize

# so that url we can use to either download and analyze or just analyze directly, gotta figure out how we can plug it into the classification model
# Out:
# 'https://cdn.bsky.app/img/feed_fullsize/plain/did:plc:xeoa6zhnvmrnwb2jajkzgdew/bafkreiguwoio63ksukkjkwgudgzxjq7yxxogxk2xbiusnhbwpprjvyzpgu@jpeg'

# %%
print('poster: ', data.feed[0].post.author.handle)
print('am I following this poster: ', data.feed[0].post.author.viewer.following)
print('does this poster follow me: ', data.feed[0].post.author.viewer.followed_by)
# Out:
# poster:  slothy666.bsky.social
# am I following this poster:  at://did:plc:ktkc7jfakxzjpooj52ffc6ra/app.bsky.graph.follow/3lc4ehpqbzg2i
# does this poster follow me:  None

# %%
did = data.feed[5].post.author.did
print(did)
# Out:
# did:plc:s3qvgdyeohv5evkb3orpidq5

# %%
uri = client.follow(did).uri

# %%
print(uri)
# you're gonna want to save this uri in the database so it's easy to unfollow if necessary
# Out:
# at://did:plc:ktkc7jfakxzjpooj52ffc6ra/app.bsky.graph.follow/3lfvjrq6nwk2f

# %%
cid = data.feed[5].post.cid
uri = data.feed[5].post.uri

# after it has passed assessment we can grab these two properties so that we can like the post
# by getting the cid and uri from the post after it has passed assess

# %%
# using the variables saved for the post this command will like the post
post_uri = client.like(uri=uri, cid=cid).uri

# %%
client.get_follows
# Out:
# <bound method Client.get_follows of <atproto_client.client.client.Client object at 0x7857881018d0>>

# %%
client.get_followers
# Out:
# <bound method Client.get_followers of <atproto_client.client.client.Client object at 0x7857881018d0>>

# %%
client.get_follows('tyrowo.bsky.social')
# Out:
# Response(follows=[ProfileView(did='did:plc:ykkkrah7gq23zkjyi4b66437', handle='tricialockwood.bsky.social', associated=ProfileAssociated(chat=ProfileAssociatedChat(allow_incoming='all', py_type='app.bsky.actor.defs#profileAssociatedChat'), feedgens=None, labeler=None, lists=None, starter_packs=None, py_type='app.bsky.actor.defs#profileAssociated'), avatar='https://cdn.bsky.app/img/avatar/plain/did:plc:ykkkrah7gq23zkjyi4b66437/bafkreierxqwfqnltdij3ih2tcm6oknofgspvdwkh5ojpgqpu3ytbewtsie@jpeg', created_at='2023-05-31T21:17:04.574Z', description=None, display_name='Tricia Lockwood', indexed_at='2024-05-30T19:27:07.088Z', labels=[], viewer=ViewerState(blocked_by=False, blocking=None, blocking_by_list=None, followed_by=None, following='at://did:plc:ktkc7jfakxzjpooj52ffc6ra/app.bsky.graph.follow/3lfre5cmmj32o', known_followers=None, muted=False, muted_by_list=None, py_type='app.bsky.actor.defs#viewerState'), py_type='app.bsky.actor.defs#profileView'), ProfileView(did='did:plc:4ahux7ekdxhn5o2u5yfjdpjx', handle='shiitake74.bsky.social', associated=ProfileAssociated(chat=ProfileAssociatedChat(allow_incoming='all', py_type='app.bsky.actor.defs#profileAssociatedChat'), feedgens=None, labeler=None, lists=None, starter_packs=None, py_type='app.bsky.actor.defs#profileAssociated'), avatar='https://cdn.bsky.app/img/avatar/plain/did:plc:4ahux7ekdxhn5o2u5yfjdpjx/bafkreiacbo22e7yh5cpucop7sc6htgpeahtjc5cnql2hvq3du74zggqsd4@jpeg', created_at='2023-09-17T17:02:34.825Z', description="Topics I'm following and thinking about: US and German politics, food and cooking, renewable energy, romance authors, random Bluesky craziness.  She/her.  #fuckAfD, 🏳️\u200d⚧️rights", display_name='Erin', indexed_at='2024-09-27T14:43:28.043Z', labels=[], viewer=ViewerState(blocked_by=False, blocking=None, blocking_by_list=None, followed_by=None, following='at://did:plc:ktkc7jfakxzjpooj52ffc6ra/app.bsky.graph.follow/3lfr4mrnyjz2c', known_followers=None, muted=False, muted_by_list=None, py_type='app.bsky.actor.defs#viewerState'), py_type='app.bsky.actor.defs#profileView'), ProfileView(did='did:plc:askzkdmixmo2b2oxns3kiwhn', handle='thebadness.bsky.social', associated=None, avatar='https://cdn.bsky.app/img/avatar/plain/did:plc:askzkdmixmo2b2oxns3kiwhn/bafkreihz3wtzdvpilkam2xp5lvg2ctbq4daacwshgsaddt66sxthwo22pa@jpeg', created_at='2024-11-15T12:26:42.658Z', description='Comment me décris-je? Réparé, mais pas vendable.', display_name='The Badness', indexed_at='2025-01-12T04:15:24.713Z', labels=[Label(cts='2024-11-15T12:26:41.699Z', src='did:plc:askzkdmixmo2b2oxns3kiwhn', uri='at://did:plc:askzkdmixmo2b2oxns3kiwhn/app.bsky.actor.profile/self', val='!no-unauthenticated', cid='bafyreibyu7siwbldnynz3nbbr67sn6lephznccztz4f2kn7lugqaefunvu', exp=None, neg=None, sig=None, ver=None, py_type='com.atproto.label.defs#label')], viewer=ViewerState(blocked_by=False, blocking=None, blocking_by_list=None, followed_by=None, following='at://did:plc:ktkc7jfakxzjpooj52ffc6ra/app.bsky.graph.follow/3lfr4mioakz26', known_followers=None, muted=False, muted_by_list=None, py_type='app.bsky.actor.defs#viewerState'), py_type='app.bsky.actor.defs#profileView'), ProfileView(did='did:plc:5nxmbmsl6ssrengg5savltjj', handle='theprof3ssorr.bsky.social', associated=None, avatar='https://cdn.bsky.app/img/avatar/plain/did:plc:5nxmbmsl6ssrengg5savltjj/bafkreih5tylpopanggn47o7zb2jb55l3vvhsltk3pnschd7yfrghb4khru@jpeg', created_at='2023-07-30T15:22:52.920Z', description='A history nerd that plays video games. \n\nhttps://www.twitch.tv/theprof3ssorr', display_name='theprof3ssorr', indexed_at='2024-01-26T00:52:09.904Z', labels=[], viewer=ViewerState(blocked_by=False, blocking=None, blocking_by_list=None, followed_by=None, following='at://did:plc:ktkc7jfakxzjpooj52ffc6ra/app.bsky.graph.follow/3lfr4ma5mkb23', known_followers=None, muted=False, muted_by_list=None, py_type='app.bsky.actor.defs#viewerState'), py_type='app.bsky.actor.defs#profileView'), ProfileView(did='did:plc:s64kwggya2gz6kfg2xnaax7y', handle='literarygadd.co ...

# %%
client.get_followers('tyrowo.bsky.social')
# Out:
# Response(followers=[ProfileView(did='did:plc:da5vy5gmpx6ktv2de6t4ipdd', handle='michellerh.bsky.social', associated=None, avatar='https://cdn.bsky.app/img/avatar/plain/did:plc:da5vy5gmpx6ktv2de6t4ipdd/bafkreiblnwjsjw3y5xmscudaalopjcvg6dmheu6z3mtwtanzosp4moip2u@jpeg', created_at='2024-11-20T00:59:32.302Z', description='Animal and Nature lover, kayak obsessed and overall concerned citizen.  Supporting my LGBTQ+ and neurodivergent friends and hoping to keep throwing the starfish back. NO DM🚫👎from strangers, NO Porn🚫👎, NO bit coin or other investme t 🚫👎.', display_name='Michelle 😼🌳🛶☮️', indexed_at='2025-01-09T21:16:46.914Z', labels=[], viewer=ViewerState(blocked_by=False, blocking=None, blocking_by_list=None, followed_by='at://did:plc:da5vy5gmpx6ktv2de6t4ipdd/app.bsky.graph.follow/3lfr6tzk4342l', following='at://did:plc:ktkc7jfakxzjpooj52ffc6ra/app.bsky.graph.follow/3lfr4lmta3o2a', known_followers=None, muted=False, muted_by_list=None, py_type='app.bsky.actor.defs#viewerState'), py_type='app.bsky.actor.defs#profileView'), ProfileView(did='did:plc:v467i5bgokox3d4v2ydnbecn', handle='gormangee.bsky.social', associated=ProfileAssociated(chat=ProfileAssociatedChat(allow_incoming='none', py_type='app.bsky.actor.defs#profileAssociatedChat'), feedgens=None, labeler=None, lists=None, starter_packs=None, py_type='app.bsky.actor.defs#profileAssociated'), avatar='https://cdn.bsky.app/img/avatar/plain/did:plc:v467i5bgokox3d4v2ydnbecn/bafkreiekk4g3tfgmefarfuwgki5oaaaoyct5vhlktbnha2yx4l7rugoyzu@jpeg', created_at='2023-08-03T07:53:08.166Z', description="The only reason that I came was so that I could go! 🥸\nhttps://gormangee.wordpress.com\nNo one's going to take my soul away. Living like Jim Morrison.\nHeading towards a fucked up holiday!\nhttps://youtu.be/PIVkYAiAVAI", display_name='Sir Crus†abread✝️🥖👨\u200d🏭🗡️🛡️🎸💜⚡🔫👾🍾🎆🌹', indexed_at='2025-01-04T00:10:48.613Z', labels=[], viewer=ViewerState(blocked_by=False, blocking=None, blocking_by_list=None, followed_by='at://did:plc:v467i5bgokox3d4v2ydnbecn/app.bsky.graph.follow/3lfr4ozwmit2z', following='at://did:plc:ktkc7jfakxzjpooj52ffc6ra/app.bsky.graph.follow/3lfr4lemvak2d', known_followers=None, muted=False, muted_by_list=None, py_type='app.bsky.actor.defs#viewerState'), py_type='app.bsky.actor.defs#profileView'), ProfileView(did='did:plc:dzgxws3mn3f5su62udrfxbsy', handle='freywild.bsky.social', associated=None, avatar='https://cdn.bsky.app/img/avatar/plain/did:plc:dzgxws3mn3f5su62udrfxbsy/bafkreigjuuc7fnchhp4x2i355wv6ygi3n5ujnhtif6o4zhhichqgbplzou@jpeg', created_at='2024-11-15T03:06:15.969Z', description=None, display_name='', indexed_at='2024-11-19T08:09:15.138Z', labels=[], viewer=ViewerState(blocked_by=False, blocking=None, blocking_by_list=None, followed_by='at://did:plc:dzgxws3mn3f5su62udrfxbsy/app.bsky.graph.follow/3lfqs7vwodq25', following='at://did:plc:ktkc7jfakxzjpooj52ffc6ra/app.bsky.graph.follow/3lfqn7vvrmp23', known_followers=None, muted=False, muted_by_list=None, py_type='app.bsky.actor.defs#viewerState'), py_type='app.bsky.actor.defs#profileView'), ProfileView(did='did:plc:pvin2oiqvkbkzaun63qqf5nm', handle='thechubbychickpea.bsky.social', associated=None, avatar='https://cdn.bsky.app/img/avatar/plain/did:plc:pvin2oiqvkbkzaun63qqf5nm/bafkreidowdvzepnkkot5jxspusv6c466hvzz3z2e67mzxfkvdzqi2ritmq@jpeg', created_at='2025-01-09T22:01:45.713Z', description='Coffee. Cats. Family. Trek. Nerd. Social Worker. LGBTQ+ ally. She/Her', display_name='', indexed_at='2025-01-12T04:09:25.213Z', labels=[], viewer=ViewerState(blocked_by=False, blocking=None, blocking_by_list=None, followed_by='at://did:plc:pvin2oiqvkbkzaun63qqf5nm/app.bsky.graph.follow/3lfqmz6irba2k', following='at://did:plc:ktkc7jfakxzjpooj52ffc6ra/app.bsky.graph.follow/3lfqdljfwws26', known_followers=None, muted=False, muted_by_list=None, py_type='app.bsky.actor.defs#viewerState'), py_type='app.bsky.actor.defs#profileView'), ProfileView(did='did:plc:2t3zf65ivkmdgkxuonwmzm6c', handle='bizylizy3.bsky.social', associated=None, avatar='https:/ ...

# %%
x = client.get_follows('tyrowo.bsky.social').follows

# %%
cur = 25
print('did ', x[cur].did)
print('handle ', x[cur].handle)
print('following uri ', x[cur].viewer.following)
# following is whether they are following you, it looks like followed_by is if they are following you back.
print('followed_by uri ', x[cur].viewer.followed_by) # will be None if not
# Out:
# did  did:plc:plvbxvoalp3dek7smavb3cr3
# handle  candybluegirl.bsky.social
# following uri  at://did:plc:ktkc7jfakxzjpooj52ffc6ra/app.bsky.graph.follow/3lfqe4h7xup2m
# followed_by uri  at://did:plc:plvbxvoalp3dek7smavb3cr3/app.bsky.graph.follow/3lfqetvuhir2o

# %%
# to delete the following
# client.delete_follow(uri)

# %%
# putting together urls for other cat feeds

# other cat feeds
# caturday - https://bsky.app/profile/numb.comfortab.ly/feed/aaad4sb7tyvjw
# handle - @numb.comfortab.ly
#at://did:plc:pmyqirafcp3jqdhrl7crpq7t/app.bsky.feed.generator/aaad4sb7tyvjw

# new caturday - handle - @skyfeed.xyz
# caturday -
# at://did:plc:tenurhgjptubkk5zf5qhi3og/app.bsky.feed.generator/#caturday

# Siamese cats - https://bsky.app/profile/mrfenman.bsky.social/feed/aaac6wmikqyhq
# handle - @mrfenman.bsky.social
#at://did:plc:jv3qdc5vxujp6taaa7nte35i/app.bsky.feed.generator/aaac6wmikqyhq

# cat pics - https://bsky.app/profile/jaz.bsky.social/feed/cv:cat
# handle - @jaz.bsky.social
#at://did:plc:q6gjnaw2blty4crticxkmujt/app.bsky.feed.generator/cv:cat

# Tuxedo Cats - client.get_profile(actor='blueskyfeeds.com')
# at://did:plc:eubjsqnf5edgvcc6zuoyixhw/app.bsky.feed.generator/tuxedo-cats

# client.get_profile(actor='jaz.bsky.social')

data = client.app.bsky.feed.get_feed({
    'feed': 'at://did:plc:q6gjnaw2blty4crticxkmujt/app.bsky.feed.generator/cv:cat',
    'limit': 30,
}, headers={})

feed = data.feed
next_page = data.cursor
print(data)

# %%
# figuring out how to recreate url of post for clickable print statement
data = client.app.bsky.feed.get_feed({
    'feed': 'at://did:plc:jfhpnnst6flqway4eaeqzj2a/app.bsky.feed.generator/cats',
    'limit': 30,
}, headers={})

feed = data.feed
next_page = data.cursor

print(data.feed[0].post)
print(data.feed[0].post.uri.find('post/'))
print(data.feed[0].post.uri[52 + 5])

URL_BEGIN = 'https://bsky.app/profile/'
URL_POST = '/post/'
URL_HANDLE = data.feed[0].post.author.handle
url_ending_index = data.feed[0].post.uri.find('post/') + 5
url_ending = data.feed[0].post.uri[url_ending_index : ]
print(URL_BEGIN + URL_HANDLE + URL_POST + url_ending)

# tyrowo.bsky.social/post/3lfzygdtqis2y

# %%
# figuring out how to recreate url of post for clickable print statement
# when you initialize the next page as blank, the cursor will point to the beginning of the feed
next_page = ''
data = client.app.bsky.feed.get_feed({
    'feed': 'at://did:plc:jfhpnnst6flqway4eaeqzj2a/app.bsky.feed.generator/cats',
    'limit': 1,
    'cursor': next_page
}, headers={})

feed = data.feed
next_page = data.cursor
print(data)

# %% [markdown]
# # PHASE 3.1 -- FOLLOWS DATABASE UPDATES --
# ## DELETE OLD FOLLOWS AND UPDATE FOLLOW-BACK STATUS PRIOR TO DELETE
#
# ## SETTING UP QUERIES TO GENERATE AND UPLOAD STRAIGHT TO POSTGRES
#
# # FOLLOWS TABLE PRUNE / PRUNING

# %%
pip install atproto
# Out:
# Collecting atproto
#   Downloading atproto-0.0.57-py3-none-any.whl.metadata (14 kB)
# Requirement already satisfied: click<9,>=8.1.3 in /usr/local/lib/python3.11/dist-packages (from atproto) (8.1.8)
# Requirement already satisfied: cryptography<44,>=41.0.7 in /usr/local/lib/python3.11/dist-packages (from atproto) (43.0.3)
# Collecting dnspython<3,>=2.4.0 (from atproto)
#   Downloading dnspython-2.7.0-py3-none-any.whl.metadata (5.8 kB)
# Collecting httpx<0.28.0,>=0.25.0 (from atproto)
#   Downloading httpx-0.27.2-py3-none-any.whl.metadata (7.1 kB)
# Collecting libipld<4,>=2.0.0 (from atproto)
#   Downloading libipld-3.0.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (3.6 kB)
# Requirement already satisfied: pydantic<3,>=2.7 in /usr/local/lib/python3.11/dist-packages (from atproto) (2.10.5)
# Requirement already satisfied: typing-extensions<5,>=4.8.0 in /usr/local/lib/python3.11/dist-packages (from atproto) (4.12.2)
# Collecting websockets<14,>=12 (from atproto)
#   Downloading websockets-13.1-cp311-cp311-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.8 kB)
# Requirement already satisfied: cffi>=1.12 in /usr/local/lib/python3.11/dist-packages (from cryptography<44,>=41.0.7->atproto) (1.17.1)
# Requirement already satisfied: anyio in /usr/local/lib/python3.11/dist-packages (from httpx<0.28.0,>=0.25.0->atproto) (3.7.1)
# Requirement already satisfied: certifi in /usr/local/lib/python3.11/dist-packages (from httpx<0.28.0,>=0.25.0->atproto) (2024.12.14)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.11/dist-packages (from httpx<0.28.0,>=0.25.0->atproto) (1.0.7)
# Requirement already satisfied: idna in /usr/local/lib/python3.11/dist-packages (from httpx<0.28.0,>=0.25.0->atproto) (3.10)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.11/dist-packages (from httpx<0.28.0,>=0.25.0->atproto) (1.3.1)
# Requirement already satisfied: h11<0.15,>=0.13 in /usr/local/lib/python3.11/dist-packages (from httpcore==1.*->httpx<0.28.0,>=0.25.0->atproto) (0.14.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.11/dist-packages (from pydantic<3,>=2.7->atproto) (0.7.0)
# Requirement already satisfied: pydantic-core==2.27.2 in /usr/local/lib/python3.11/dist-packages (from pydantic<3,>=2.7->atproto) (2.27.2)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.11/dist-packages (from cffi>=1.12->cryptography<44,>=41.0.7->atproto) (2.22)
# Downloading atproto-0.0.57-py3-none-any.whl (350 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 350.0/350.0 kB 7.2 MB/s eta 0:00:00
# Downloading dnspython-2.7.0-py3-none-any.whl (313 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 313.6/313.6 kB 15.5 MB/s eta 0:00:00
# Downloading httpx-0.27.2-py3-none-any.whl (76 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 76.4/76.4 kB 4.5 MB/s eta 0:00:00
# Downloading libipld-3.0.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (671 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 671.7/671.7 kB 18.1 MB/s eta 0:00:00
# Downloading websockets-13.1-cp311-cp311-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (164 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 164.8/164.8 kB 9.4 MB/s eta 0:00:00
# Installing collected packages: websockets, libipld, dnspython, httpx, atproto
#   Attempting uninstall: websockets
#     Found existing installation: websockets 14.1
#     Uninstalling websockets-14.1:
#       Successfully uninstalled websockets-14.1
#   Attempting uninstall: httpx
#     Found existing installation: httpx 0.28.1
#     Uninstalling httpx-0.28.1:
#       Successfully uninstalled httpx-0.28.1
# Successfully installed atproto-0.0.57 dnspython-2.7.0 httpx-0.27.2 libipld-3.0.0 websockets-13.1

# %%
from atproto import Client
from google.colab import userdata

BSKY_USERNAME = userdata.get('bsky_username')
BSKY_PASSWORD = userdata.get('bsky_password')

client = Client()
client.login(BSKY_USERNAME, BSKY_PASSWORD)
# Out:
# ProfileViewDetailed(did='did:plc:ktkc7jfakxzjpooj52ffc6ra', handle='tyrowo.com', associated=ProfileAssociated(chat=None, feedgens=0, labeler=False, lists=0, starter_packs=0, py_type='app.bsky.actor.defs#profileAssociated'), avatar='https://cdn.bsky.app/img/avatar/plain/did:plc:ktkc7jfakxzjpooj52ffc6ra/bafkreiepqgg5tlozvv4bw5ficwwixflfprionhnli26hngc3hjn6ygpamu@jpeg', banner='https://cdn.bsky.app/img/banner/plain/did:plc:ktkc7jfakxzjpooj52ffc6ra/bafkreierasgybimbz3pfobqfmay5ufxm7jlqnjeiumdx7dyof6mcss7a4m@jpeg', created_at='2023-08-28T14:18:41.780Z', description='Self-taught professional software developer, exF2P MTG Arena Challenger, ex wr holder speedrunning HotD2_100%, ex streamer, ex melee player. \nGrilling, coding, gaming, magic:tg, tcgs, and most importantly - posting pictures of my cat. 😻\nNO POLITICS\nhe/him', display_name='Tyro, ft Ricky', followers_count=1117, follows_count=3734, indexed_at='2025-01-21T01:55:44.913Z', joined_via_starter_pack=None, labels=[], pinned_post=Main(cid='bafyreihszjgxkh5fmu5je5eldv6i27ubndfcyhwcbjsin4jsbfo2gu45ky', uri='at://did:plc:ktkc7jfakxzjpooj52ffc6ra/app.bsky.feed.post/3lcbntv5rmc2j', py_type='com.atproto.repo.strongRef'), posts_count=141, viewer=ViewerState(blocked_by=False, blocking=None, blocking_by_list=None, followed_by=None, following=None, known_followers=KnownFollowers(count=808, followers=[ProfileViewBasic(did='did:plc:isliyiq3gjuxpwysdpdgj5t3', handle='chateauminette.com', associated=ProfileAssociated(chat=ProfileAssociatedChat(allow_incoming='following', py_type='app.bsky.actor.defs#profileAssociatedChat'), feedgens=None, labeler=None, lists=None, starter_packs=None, py_type='app.bsky.actor.defs#profileAssociated'), avatar='https://cdn.bsky.app/img/avatar/plain/did:plc:isliyiq3gjuxpwysdpdgj5t3/bafkreibdrunuo63uix5ex4e35nqaiya3rtt3v6suongv2ozavvyeu2u4ei@jpeg', created_at='2023-04-30T14:38:48.713Z', display_name='Chateau Minette', labels=[], viewer=ViewerState(blocked_by=False, blocking=None, blocking_by_list=None, followed_by='at://did:plc:isliyiq3gjuxpwysdpdgj5t3/app.bsky.graph.follow/3lg2cp2jeb32r', following='at://did:plc:ktkc7jfakxzjpooj52ffc6ra/app.bsky.graph.follow/3lfux5yfjiq2c', known_followers=None, muted=False, muted_by_list=None, py_type='app.bsky.actor.defs#viewerState'), py_type='app.bsky.actor.defs#profileViewBasic'), ProfileViewBasic(did='did:plc:uth2m47jh7mgtz6pa7nmexv4', handle='y-sr2024.bsky.social', associated=ProfileAssociated(chat=ProfileAssociatedChat(allow_incoming='following', py_type='app.bsky.actor.defs#profileAssociatedChat'), feedgens=None, labeler=None, lists=None, starter_packs=None, py_type='app.bsky.actor.defs#profileAssociated'), avatar='https://cdn.bsky.app/img/avatar/plain/did:plc:uth2m47jh7mgtz6pa7nmexv4/bafkreighofwyxacalxbkmse7rocdsmeseqcn7l7gsgcyw22ou7xkudhyle@jpeg', created_at='2024-02-07T12:05:33.260Z', display_name='ニャー子', labels=[Label(cts='1970-01-01T00:00:00.000Z', src='did:plc:uth2m47jh7mgtz6pa7nmexv4', uri='at://did:plc:uth2m47jh7mgtz6pa7nmexv4/app.bsky.actor.profile/self', val='!no-unauthenticated', cid='bafyreihgy33qxefwki43unusrjbhfxxiagt55cqxns4ucr4e2fioqszeby', exp=None, neg=None, sig=None, ver=None, py_type='com.atproto.label.defs#label')], viewer=ViewerState(blocked_by=False, blocking=None, blocking_by_list=None, followed_by='at://did:plc:uth2m47jh7mgtz6pa7nmexv4/app.bsky.graph.follow/3lfdwxfjx5m2v', following='at://did:plc:ktkc7jfakxzjpooj52ffc6ra/app.bsky.graph.follow/3lfdslm4jlh2h', known_followers=None, muted=False, muted_by_list=None, py_type='app.bsky.actor.defs#viewerState'), py_type='app.bsky.actor.defs#profileViewBasic'), ProfileViewBasic(did='did:plc:gcrqnwh7gumjeiwizyl5auno', handle='skeewiff.bsky.social', associated=ProfileAssociated(chat=ProfileAssociatedChat(allow_incoming='none', py_type='app.bsky.actor.defs#profileAssociatedChat'), feedgens=None, labeler=None, lists=None, starter_packs=None, py_type='app.bsky.actor.defs#profileAssociated'), avatar='https://cdn.bsky.app/img/avatar/plain/did:plc:gcrqnwh7gumje ...

# %%
# follows = client.get_follows('tyrowo.bsky.social').follows
# print(follows)

# %%
following = client.get_profile(actor=BSKY_USERNAME).follows_count
followers = client.get_profile(actor=BSKY_USERNAME).followers_count
print(f'I am following {following} users and I have {followers} followers')
# Out:
# I am following 2400 users and I have 812 followers

# %%
follow_map = {}

following = client.get_profile(actor=BSKY_USERNAME).follows_count
next_page = ''
cur = 0
x = following
# for i in range(100): # so this solved the question - when you reach the last page and use the cursor to go to the next page it just doesn't go anywhere. that's it

# set up query as copy paste lol
# INSERT INTO contacts (first_name, last_name, email)
# VALUES
#     ('Eva', 'Williams', '[[email protected]](../cdn-cgi/l/email-protection.html)'),
#     ('Michael', 'Miller', '[[email protected]](../cdn-cgi/l/email-protection.html)'),
#     ('Sophie', 'Davis', '[[email protected]](../cdn-cgi/l/email-protection.html)')
# RETURNING id;
SCHEMA = '"bsky"'
TABLE_FOLLOWS = '"follows"'
COL_USERID = 'user_id'
COL_USERHANDLE = 'user_handle'
COL_FOLLOWURI = 'follow_uri'
COL_FOLLOWDATE = 'follow_date'
COL_FOLLOWSYOU = 'follows_you'
END_LINE = ','
END_QUERY = ';'
# print(following)
# print('~~~~~~~~~~~~~~~~~ BEGIN COPYING SQL QUERY HERE~~~~~~~~~~~~~~~~~')
print(f'INSERT INTO {SCHEMA}.{TABLE_FOLLOWS} ({COL_USERID}, {COL_USERHANDLE}, {COL_FOLLOWURI}, {COL_FOLLOWDATE}, {COL_FOLLOWSYOU}) ')
print(f'VALUES ')

while x > 0:
  cur_limit = min(x, 100)
  x -= cur_limit
  follows = client.get_follows(actor='tyrowo.bsky.social', cursor= next_page, limit=cur_limit)
  next_page = follows.cursor
  follows = follows.follows
  for follow in follows:
    cur += 1
    if cur != 1:
      print(END_LINE) # need to finish the previous queries line but don
    # need did, user handle, follow_uri, date_added, follows_you
    did = follow.did
    handle = follow.handle
    follow_uri = follow.viewer.following
    # print(f'| {cur} | did {did} | handle {handle} | following uri {follow_uri} | followed by uri {follows_you} |')
    # from that command we see that the follows are sorted by newest to oldest, so we can fake a date added odering by starting at NOW() (because nothing will be older than now in the db) - interval of x hours where x is their order
    date_added = f"NOW() - interval '{cur} hours'"
    # following is whether they are following you, it looks like followed_by is if they are following you back.
    follows_you = False if follow.viewer.followed_by == None else True


    print(f"    ('{did}', '{handle}', '{follow_uri}', {date_added}, '{follows_you}') ") # date_added doesn't need quotations but the others
    # couldn't use {END_LINE if cur < following else ''} in this print statement for some reason following rounds but the limit gets the exact amount no problem...

print(f'RETURNING {COL_USERHANDLE}, {COL_FOLLOWDATE}{END_QUERY}')

# print('~~~~~~~~~~~~~~~~~ STOP COPYING SQL QUERY HERE~~~~~~~~~~~~~~~~~')
# print(f'there were {cur} follows')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-fce01bfa027e> in <cell line: 0>()
#       1 follow_map = {}
#       2
# ----> 3 following = client.get_profile(actor=BSKY_USERNAME).follows_count
#       4 next_page = ''
#       5 cur = 0
#
# NameError: name 'client' is not defined

# %% [markdown]
# * # update query
#
# * ## update users that were added to the database without a date added to have the current timestamp. Thought this was going to be necessary but it's not.
# ```
# UPDATE "bskyAutomation"."follows"
# SET follow_date = NOW(), follows_you = true
# WHERE user_id = 'test';
# ```
#
# * first look at all users not following you, those are the ones we primarily want to check because there's usually nothing to do with people already following you.
#
# ```
# SELECT * FROM "bsky"."follows"
# WHERE follows_you = FALSE;
# ```
# * but we only want the user did's so that we can copy them into a notepad and check them.
#
# ```
# SELECT user_id FROM "bsky"."follows"
# WHERE follows_you = FALSE;
# ```
# ## with the returned follow_uri from the table deletions, copy that column of information into a notepad++ file, making the following edits
# ctrl+h = Replace
#
# (bottom left) search mode = Extended
#
# replace `did:` with `"did:` -- to add an apostrophe at the front. Don't shorten all the way to 'did' or you might have some ids you mess up
#
# replace `\r\n` with `", \r\n` -- removing the line break causes colab to fail once there are a couple hundred or thousand entries.
#
#
# then paste the data into the following cell, if everything was done right they should be a list of string values
#
# ```
# list = [
#   'did:plc:...', 'did:plc:...', 'did:plc:...'
# ]
# ```
# make sure there is an apostrophe at the end of the last entry if you
# # I have set up the following cells to generate an update query with any users that are now following you

# %% [markdown]
# this is a template to copy so you can delete all out of the subsequent cell
# ```
# # paste the user dids of all users not following you
# check_these_user_dids = ([
#
#
#
# ])
# ```

# %%
# paste the user dids of all users not following you
check_these_user_dids = ([



])

# %%
users_to_update = []
users_to_delete_no_longer_exist = []

for i, did in enumerate(check_these_user_dids):
  if i % 50 == 0:
    print(f'checking user {i}. found {len(users_to_update)} updates so far.')
  # was encountering a fatal response error trying to get profiles with some old dids. I presume that if you try to get the profile of a deleted account there is a bad response.
  try:
    cur = client.get_profile(actor=did)
  except:
    print(f'there was an exception with user did: {did}')
    users_to_delete_no_longer_exist.append("'" + did + "'")
    continue
  # print(cur)
  follows_you = cur.viewer.followed_by
  if follows_you != None:
    users_to_update.append("'" + did + "'")

print(users_to_update)
print('errors: ', ','.join(users_to_delete_no_longer_exist)) # trying to figure out an easy way to do this, you can use this print statement to write a query to delete them from the database, but some still actually exist as users. hopefully you don't have too many.
# the best solution I can do is to go to the database, get their handle, and check them one by one to see if they exist by looking up in the app. looking up by handle also got a bad response if they didn't exist so that
# Out:
# []
# errors:

# %%
# errored out user ids after searching for their handles in the db looking up and disposing of them
# ok = ['teedoo.bsky.social' , 'lesaiet.bsky.social' , 'ginnylyn.bsky.social' , 'cheekytubemouse.bsky.social' , 'mssammaher.bsky.social' , 'catloversfanclub.bsky.social' , 'flawlessangel.bsky.social' , 'brandytking.bsky.social']
# for handle in ok:
#   try:
#     profile = client.get_profile(actor=handle)
#     follow_uri = profile.viewer.following
#     client.delete_follow(follow_uri)
#     print(f'unfollowed {handle}')
#   except:
#     print(f'{handle} caused bad response, probably doesnt exist anymore')
# Out:
# unfollowed teedoo.bsky.social
# unfollowed lesaiet.bsky.social
# unfollowed ginnylyn.bsky.social
# unfollowed cheekytubemouse.bsky.social
# mssammaher.bsky.social caused bad response, probably doesnt exist anymore
# catloversfanclub.bsky.social caused bad response, probably doesnt exist anymore
# flawlessangel.bsky.social caused bad response, probably doesnt exist anymore
# brandytking.bsky.social caused bad response, probably doesnt exist anymore

# %%
# create update query for the list of users to update
SCHEMA = '"bsky"'
TABLE_FOLLOWS = '"follows"'
COL_USERID = 'user_id'
COL_USERHANDLE = 'user_handle'
COL_FOLLOWURI = 'follow_uri'
COL_FOLLOWDATE = 'follow_date'
COL_FOLLOWSYOU = 'follows_you'
END_LINE = ','
END_QUERY = ';'

users_in = ','.join(users_to_update)
print(f'UPDATE {SCHEMA}.{TABLE_FOLLOWS}')
print(f'SET {COL_FOLLOWSYOU} = TRUE')
print(f'WHERE {COL_USERID} IN({users_in})')
print(f'RETURNING {COL_USERHANDLE}, {COL_FOLLOWSYOU}{END_QUERY}')
# Out:
# UPDATE "bsky"."follows"
# SET follows_you = TRUE
# WHERE user_id IN('did:plc:l3arxqnpn4f66wgjydb32nxb','did:plc:tmiac6yit3f7jvwtf76hmtmc','did:plc:hyxs4flxbzjyqr6ccsgywf36','did:plc:oqznhz47ni3n72atprct6lzx','did:plc:mdbbfp2l5l4yuwxz27vlk7w4','did:plc:hys34bcodospqicduv5ednq7','did:plc:tjo6tvj3tnrsrwxnmb64umki','did:plc:kp5ccuc4qw7kimieha3mmqna','did:plc:xy3hlehyff6kldbvsaras4nl','did:plc:vidpi6vw4hfvre73kyqnhlmf','did:plc:rbaejlkjps6lm4fykhv3bitl','did:plc:hczxq5huggeay7qkihfoojfv','did:plc:tmcuovgque57j452yu3apjno','did:plc:uykpf4fxpf46pk3iaki2sjfh','did:plc:nrlzb77enlayqokot2yk55p2','did:plc:kqfsgxoqesgrxbrewyejzooo','did:plc:ou6dw6smwzwzapkhlz2tmeo7','did:plc:egf5pner4y4i43ppinlrx66j','did:plc:tcduzdoozceelmwjrvxd2d5s','did:plc:wetjlh3l45nk47e4cczr6xo3','did:plc:7ubuux2lh6ovt3xu5mtvwvjf','did:plc:kcvd7rk7wsvaaapxu4dsvcp5','did:plc:pbak4g6xqlntte2gxqx7ybxh','did:plc:r6rgu354oi2tqwqcawfv2zxs','did:plc:zh3ohlunvuwyckrbpxgxnw65','did:plc:wo3plalvoa64ywtejenivoim','did:plc:wag5ekx6yqfbsckgzskq5ior','did:plc:2egfofb52eplwi36fppzl5jh','did:plc:imezlaeqnxj6skethpr6b3te','did:plc:ml2brl2j5egliqg73r5h5ts5','did:plc:jq37g47267aw7cyviebrf3cp','did:plc:ihqwyvjqndjmuxaweooaqkyg','did:plc:6kdb33x63ai4ar4zc2obby5n','did:plc:bzd2mfum7qibuxdyho222ce7','did:plc:723rutvo6wm5g52zcymucpwv','did:plc:y7oeqshpll66g3oljlcsogky','did:plc:t3blveopeekur4pwsa5udytj','did:plc:nhw5o6ajo2pwo2hfers6l6qw','did:plc:g6asxub65pq235xsao4gs6rk','did:plc:4lchwxeu4wgg4ef6haz74gau','did:plc:vyvpibf6qcl2eeg46fdodykw','did:plc:pzjb55zby3cuksx4mfd6z5yh','did:plc:hvoemtli7pmzid3qf26gw3h2','did:plc:hndf42jhpoxpjwe32kizuyft','did:plc:a3uuelvwvpofflqscriohemz','did:plc:irkb6iiop7fzrjfqizuxueoi','did:plc:d5kvtrrchzuvug6gzqkn7oma','did:plc:rftpg2hkb25gx5ei2mhkbbwl','did:plc:ivyyguv673jzddz74dapnzpo','did:plc:wdt64ebxtwpdwicf2duuy2gu','did:plc:2avmhsghznvrlwmkjid4pyo5','did:plc:fkao2ldh4zer46rdfyqy3pik','did:plc:xs74qbvoeuscq7ugcmaxzjup','did:plc:xbv74e4npjzzswhqawuh6ndw','did:plc:d2qxhusydibbglfhp3kgyuc6','did:plc:m25sdefoju3eanjlhvn6l5ot','did:plc:scemkxkdjho2phtc7u3kkrex','did:plc:opiyrpdbu3zrkeiyvufqfj3n','did:plc:tzn2gv2xwegktpgsinjryb4v','did:plc:a7egwkafbtaaywwxthdilopw','did:plc:dq4q3wzaxzt27xlldwwla4x4','did:plc:xs43crfhmekpbb5q7jq2u2dw','did:plc:svxwteezibp7bxr4sl6umx57','did:plc:7mrnvyd3twedu5qwbmrbkigv','did:plc:j56gset7zz6ebdsupraljifv','did:plc:v656z5odpq4xdzcvsbkgwxvl','did:plc:qdqyjhwpc5mrrlmss74gwsrv','did:plc:uid2kixokl77ibekodcfkbox','did:plc:ai6fo72a54sydfauxcz7nj64','did:plc:jbwgsvi5syd47cmi4brhfx6s','did:plc:4ebtql3wwt2tvrfd4on5oznl','did:plc:5dck3q47r4lhznhe7tonuihx','did:plc:6jonwky7x47ndfcgp7einwdl','did:plc:tisakrm6u2fd2qsovqvn7ors','did:plc:ebykkxyauvtqqcwvmfptt4rx','did:plc:62vbgvnfy7jrazf5o5nh2n5n','did:plc:dhrk6ukry2n6hdiyyti5ryzi','did:plc:54lm7xkvk2lblfw5ybvmuxcs','did:plc:cxp4yfriljziws4n3m3q4vgg','did:plc:h4jhreaw4wtxnpn5jaiv4x3s','did:plc:5wxdce666vn3utprrk7t7kch','did:plc:jd3hlwpzeplo2ptsmsus5xua','did:plc:dh7fq6ssgxig5ihk46kvargw','did:plc:vmgvyoepkmu6kkyizi5ez66q','did:plc:lutle3kh3yhupbft6r5a72j4','did:plc:j533zkq6d55u43khj255ysnq','did:plc:kquu7pgorfysxhs6qqnmlkzh','did:plc:b55eai5fyfdrepkqckqne7sw','did:plc:3qtrprl72k6g3zotmo3txz5z','did:plc:mmnd2mikrjjotm5zvts2omo4','did:plc:tm3r3pa3kttrt7esudezmoty','did:plc:kd7kkuksequhiaipidlemwwt','did:plc:fvoxdqk4kn2djze3l5y3ntiv','did:plc:fuk67atin53p5yqetynmrjts','did:plc:7jzsd4yoap2t6e2qnhduduxo','did:plc:gc4wn3hdwnbaxczyxmgxxucv','did:plc:tuhaknduxuqahtcsemesmat5','did:plc:5j4vxkshqksysfuglrcrspaf','did:plc:4afv5aluhilisnejm7ci6yfo','did:plc:h5l2mb2oztmhlg5hvcf7v5qq','did:plc:kuahd4rdg3tcpz4mhxcmxznv','did:plc:zqxgsik333b6anesmennowct','did:plc:rga6tzffg5f2aohgs3dl77fo','did:plc:fmpdnezjk22dj6ihmwoeubjs','did:plc:7hqxarikcqb3k3j2asvnxszr','did:plc:gmtja2ejq5bqhuyurwifcnm6','did:plc:cy5mlzlh6jgibu7fzuotvkrr','did:plc:uvjsbzxic25elfnmjkv3umjh','did:plc:kewxhhhecqq6voflkh3wdwgg','did:plc:n5ddts5wsauvcnpmtr44fu7u','did:plc:kfoyntjfzmcwjqyuo3tvxqn7','did:plc:cq5ctci6lg7wgmzfwxpzhh6k','did:plc:iiossaaetdvygak3vrvbfjqc','did:plc:vip4npqxilrhtwuc2gr ...
# RETURNING user_handle, follows_you;

# %% [markdown]
# # delete / prune query
# **!! make sure you update the follow status before this so that you don't delete people who have followed you back**
#
#
# * ## delete one user by handle from the db
#
# ```
# DELETE FROM "bsky"."follows"
# WHERE user_handle = 'e1341.bsky.social'
# RETURNING *;
# ```
#
# * ## view users to be deleted
#
# ```
# SELECT * FROM "bsky"."follows"
# WHERE user_id IN(
# SELECT user_id
#     FROM "bsky"."follows"
#     WHERE follows_you = FALSE
#     ORDER BY follow_date ASC
#     LIMIT 1000
# )
# ```
#
# * ## delete those users from the database, returning the User's DID that we will turn into our formula to remove from our friends list
#
# ```
# DELETE FROM "bsky"."follows"
# WHERE user_id IN(
# SELECT user_id
#     FROM "bsky"."follows"
#     WHERE follows_you = FALSE
#     ORDER BY follow_date ASC
#     LIMIT 1
# )
# RETURNING follow_uri;
# ```
# ## with the returned follow_uri from the table deletions, copy that column of information into the following cell as a docstring. The proceeding cell will parse the string into a list of uris.

# %%
# initiate the string to add to our logger file
# IMPORTS ARE NOT SET UP HERE IN THE DELETE SECTION, BECAUSE DELETIONS SHOULD ALWAYS BE PRECEEDED BY A FRIEND LIST UPDATE
LINE_BREAK = '\n'
END_LOGGING = '\n____________________\n'
following = client.get_profile(actor=BSKY_USERNAME).follows_count
followers = client.get_profile(actor=BSKY_USERNAME).followers_count
USER_TIMEZONE = "US/Eastern" # you should fill this in with your own timezone here
cur_timestamp = datetime.datetime.now(zoneinfo.ZoneInfo(USER_TIMEZONE))
# print(cur_timestamp)
logging_text = LINE_BREAK + str(cur_timestamp) + LINE_BREAK + 'DELETING OLDEST FOLLOWS THAT ARE NOT FOLLOWING BACK' + LINE_BREAK + LINE_BREAK + 'prior follower count: ' + str(followers) + LINE_BREAK + 'previously following: ' + str(following) + LINE_BREAK + LINE_BREAK
print(logging_text)
# logging_stats = {}
# Out:
# 2025-01-29 16:43:11.925012-05:00
# DELETING OLDEST FOLLOWERS WHO DID NOT FOLLOW BACK
#
# prior follower count: 2335
# previously following: 5653

# %% [markdown]
# ```
# # paste follow_ids to delete here
# delete_these_follow_uris = """
#
# """
# ```

# %%
# paste follow_ids to delete here
delete_these_follow_uris = """

"""

# %%
# now we can split the raw output into lines
delete_these_follow_uris = delete_these_follow_uris.strip().split('\n')

# but all we need is these lines because it should just be lines of uris ['uri', 'uri', ...]

logging_text = logging_text + f'{len(delete_these_follow_uris)} entries were deleted from the database.' + LINE_BREAK

# %%
print(delete_these_follow_uris)
# Out:
# ['at://did:plc:ktkc7jfakxzjpooj52ffc6ra/app.bsky.graph.follow/3lgiyup77rz2h', 'at://did:plc:ktkc7jfakxzjpooj52ffc6ra/app.bsky.graph.follow/3lgiyuq67ny2f', 'at://did:plc:ktkc7jfakxzjpooj52ffc6ra/app.bsky.graph.follow/3lgiyurajjg2c', 'at://did:plc:ktkc7jfakxzjpooj52ffc6ra/app.bsky.graph.follow/3lgiyutw24p2d', 'at://did:plc:ktkc7jfakxzjpooj52ffc6ra/app.bsky.graph.follow/3lgiyuwk5bk22', 'at://did:plc:ktkc7jfakxzjpooj52ffc6ra/app.bsky.graph.follow/3lgiyuzbs7p2d', 'at://did:plc:ktkc7jfakxzjpooj52ffc6ra/app.bsky.graph.follow/3lgiyv4y3uq2f', 'at://did:plc:ktkc7jfakxzjpooj52ffc6ra/app.bsky.graph.follow/3lgiyvhhdmx22', 'at://did:plc:ktkc7jfakxzjpooj52ffc6ra/app.bsky.graph.follow/3lgiyvj6cgc22', 'at://did:plc:ktkc7jfakxzjpooj52ffc6ra/app.bsky.graph.follow/3lgiyvpzsf62m', 'at://did:plc:ktkc7jfakxzjpooj52ffc6ra/app.bsky.graph.follow/3lgiz2i6j7o2m', 'at://did:plc:ktkc7jfakxzjpooj52ffc6ra/app.bsky.graph.follow/3lgkfpdeh4s2c', 'at://did:plc:ktkc7jfakxzjpooj52ffc6ra/app.bsky.graph.follow/3lgkfpibb2g22', 'at://did:plc:ktkc7jfakxzjpooj52ffc6ra/app.bsky.graph.follow/3lgkfpjenvp22', 'at://did:plc:ktkc7jfakxzjpooj52ffc6ra/app.bsky.graph.follow/3lgkfpuw63g22', 'at://did:plc:ktkc7jfakxzjpooj52ffc6ra/app.bsky.graph.follow/3lgkfpvzjho2o', 'at://did:plc:ktkc7jfakxzjpooj52ffc6ra/app.bsky.graph.follow/3lgkfq2oueq2c', 'at://did:plc:ktkc7jfakxzjpooj52ffc6ra/app.bsky.graph.follow/3lgkfq4lamk2l', 'at://did:plc:ktkc7jfakxzjpooj52ffc6ra/app.bsky.graph.follow/3lgkfq5zt7y2c', 'at://did:plc:ktkc7jfakxzjpooj52ffc6ra/app.bsky.graph.follow/3lgkfqbehj32a', 'at://did:plc:ktkc7jfakxzjpooj52ffc6ra/app.bsky.graph.follow/3lgkfqf6dsy26', 'at://did:plc:ktkc7jfakxzjpooj52ffc6ra/app.bsky.graph.follow/3lgkfqgc2ka2d', 'at://did:plc:ktkc7jfakxzjpooj52ffc6ra/app.bsky.graph.follow/3lgkfqhfebq26', 'at://did:plc:ktkc7jfakxzjpooj52ffc6ra/app.bsky.graph.follow/3lgkfqifxyo22', 'at://did:plc:ktkc7jfakxzjpooj52ffc6ra/app.bsky.graph.follow/3lgkfqjk64g2h', 'at://did:plc:ktkc7jfakxzjpooj52ffc6ra/app.bsky.graph.follow/3lgkfqnlcko2o', 'at://did:plc:ktkc7jfakxzjpooj52ffc6ra/app.bsky.graph.follow/3lgkfqpvmt32x', 'at://did:plc:ktkc7jfakxzjpooj52ffc6ra/app.bsky.graph.follow/3lgkfqqz5va26', 'at://did:plc:ktkc7jfakxzjpooj52ffc6ra/app.bsky.graph.follow/3lgkfqsynzd23', 'at://did:plc:ktkc7jfakxzjpooj52ffc6ra/app.bsky.graph.follow/3lgkfqurxyt23', 'at://did:plc:ktkc7jfakxzjpooj52ffc6ra/app.bsky.graph.follow/3lgkfqxaya722', 'at://did:plc:ktkc7jfakxzjpooj52ffc6ra/app.bsky.graph.follow/3lgkfqyrow62f', 'at://did:plc:ktkc7jfakxzjpooj52ffc6ra/app.bsky.graph.follow/3lgkfqzwg2s2m', 'at://did:plc:ktkc7jfakxzjpooj52ffc6ra/app.bsky.graph.follow/3lgkfr4re7s2m', 'at://did:plc:ktkc7jfakxzjpooj52ffc6ra/app.bsky.graph.follow/3lgjpjqblzo2l', 'at://did:plc:ktkc7jfakxzjpooj52ffc6ra/app.bsky.graph.follow/3lgjpjrywsi22', 'at://did:plc:ktkc7jfakxzjpooj52ffc6ra/app.bsky.graph.follow/3lgjpjtnomk2a', 'at://did:plc:ktkc7jfakxzjpooj52ffc6ra/app.bsky.graph.follow/3lgjpjz5tq62l', 'at://did:plc:ktkc7jfakxzjpooj52ffc6ra/app.bsky.graph.follow/3lgjpk34icv2m', 'at://did:plc:ktkc7jfakxzjpooj52ffc6ra/app.bsky.graph.follow/3lgjpk6swe52m', 'at://did:plc:ktkc7jfakxzjpooj52ffc6ra/app.bsky.graph.follow/3lgjpkea42c23', 'at://did:plc:ktkc7jfakxzjpooj52ffc6ra/app.bsky.graph.follow/3lgjpkijaxk24', 'at://did:plc:ktkc7jfakxzjpooj52ffc6ra/app.bsky.graph.follow/3lgjpkm527n2d', 'at://did:plc:ktkc7jfakxzjpooj52ffc6ra/app.bsky.graph.follow/3lgjpkn3rbe22', 'at://did:plc:ktkc7jfakxzjpooj52ffc6ra/app.bsky.graph.follow/3lgjpko6iwv2d', 'at://did:plc:ktkc7jfakxzjpooj52ffc6ra/app.bsky.graph.follow/3lgjpkp4myg2l', 'at://did:plc:ktkc7jfakxzjpooj52ffc6ra/app.bsky.graph.follow/3lgjpkqgxtb26', 'at://did:plc:ktkc7jfakxzjpooj52ffc6ra/app.bsky.graph.follow/3lgjpkrsdjf2c', 'at://did:plc:ktkc7jfakxzjpooj52ffc6ra/app.bsky.graph.follow/3lgjpksw2dk2a', 'at://did:plc:ktkc7jfakxzjpooj52ffc6ra/app.bsky.graph.follow/3lgjpkutxvk2c', 'at://did:plc:ktkc7jfakxzjpooj52ffc6ra/app.bsky.graph.follow/3lgjpkxnwrv2m', 'at://did:plc:ktkc7jfakxzjpooj52ffc6ra/app.bsky.graph.follow/3lgjpkziq7v ...

# %%
# run the deletions
# DELETE
# THESE ARE DELETIONS
# THIS WILL DELETE ALL IN THE LIST OF THE ABOVE CELL FROM YOUR FRIENDS LIST
for i, uri in enumerate(delete_these_follow_uris):
  if i % 50 == 0:
    print(f'on deletion #{i}')
  cur = client.delete_follow(uri)
print(f'successfully deleted {len(delete_these_follow_uris)} follows.')
logging_text = logging_text + f'Successfully unfollowed {len(delete_these_follow_uris)} users.' + LINE_BREAK
# Out:
# on deletion #0
# on deletion #50
# on deletion #100
# on deletion #150
# on deletion #200
# on deletion #250
# on deletion #300
# on deletion #350
# on deletion #400
# on deletion #450
# on deletion #500
# on deletion #550
# on deletion #600
# on deletion #650
# on deletion #700
# on deletion #750
# on deletion #800
# on deletion #850
# on deletion #900
# on deletion #950
# on deletion #1000
# on deletion #1050
# on deletion #1100
# on deletion #1150
# successfully deleted 1200 follows.

# %%
# finish logging and submit log to github
following = client.get_profile(actor=BSKY_USERNAME).follows_count
followers = client.get_profile(actor=BSKY_USERNAME).followers_count

logging_text = logging_text + LINE_BREAK + 'cur followers: ' + str(followers) + LINE_BREAK + 'now following: ' + str(following) + LINE_BREAK
# print(logging_text)

# LOGGING ALL THE CHANGES TO OUR LOGGING FILE IN GITHUB
GITHUB_TOKEN = userdata.get('github_token')
GITHUB_REPO = userdata.get('github_user/repo')
FILE_PATH = "LOGGING_001.txt"  # Replace with the file path in your repo
BRANCH = "main"  # Replace with your branch name
COMMIT_MESSAGE = "Logging for follower deletions on " + str(cur_timestamp)

# Step 1: Get the file's current content and SHA
url = f"https://api.github.com/repos/{GITHUB_REPO}/contents/{FILE_PATH}"
headers = {"Authorization": f"token {GITHUB_TOKEN}"}
response = requests.get(url, headers=headers)
response_json = response.json()

# Decode the content of the file
file_sha = response_json["sha"]
content = base64.b64decode(response_json["content"]).decode("utf-8")

# Step 2: Modify the file content
new_content = content + LINE_BREAK + logging_text + END_LOGGING
encoded_content = base64.b64encode(new_content.encode("utf-8")).decode("utf-8")

# Step 3: Push the updated content
data = {
    "message": COMMIT_MESSAGE,
    "content": encoded_content,
    "sha": file_sha,
    "branch": BRANCH,
}
update_response = requests.put(url, headers=headers, json=data)

if update_response.status_code == 200:
    print("Logging file updated successfully! Here's what was added to the logs:\n")
    print(logging_text + END_LOGGING)
else:
    print(f"Error: {update_response.json()}")
# Out:
# Logging file updated successfully! Here's what was added to the logs:
#
#
# 2025-01-29 16:43:11.925012-05:00
# DELETING OLDEST FOLLOWERS WHO DID NOT FOLLOW BACK
#
# prior follower count: 2335
# previously following: 5653
#
# 1200 entries were deleted from the database.
# Successfully unfollowed 1200 users.
#
#
# cur followers: 2335
# now following: 4453
#
# ____________________

# %% [markdown]
# # PHASE 3.2 -- FOLLOWS DATABASE UPDATES --
# ## UPDATING FULL FRIENDS LIST WITH ANY CHANGES THAT HAVE OCCURRED.
#
# ## PRODUCES UPDATE QUERIES, INSERT QUERIES, AND DELETE QUERIES
#
# # FOLLOWS TABLE FULL UPDATE
#
#
# so what are we doing here?
# When we look at the friends list we have in our db and compare it to our up to date database we're comparing all 5 properties
#
# user_id, user_handle, follow_uri, follow_date, follows_you
#
# * the did and the handle should never be updated.
#
# * the follow_uri should not need to be updated, we could compare it for changes but I don't think that's ever necessary. Usually it will go to None if we stop following them, but in that case the database entry will be deleted. Just in case we'll do a comparison check to what we have in the database with what exists in bluesky, and if there's ever a difference we will see it and I'll have to make another function to handle it.
#
# * the follow_date will not need to be updated ever once it is registered, but new users will be entered with a timestamp of NOW().
#
# * follows_you is the important one to check. we want to make sure that we have up-to-date info on our follows. Either update that they are following you back, or update that they have stopped following you.
#
# from this list we see we need to have 4 queries every time we do a mass update:
# 1. insert any new users to the db who were not there before
# 2. update users that were following and now are not
# 3. update users that were Not following and now are
# 4. delete any follows that exist in the database but no longer exist in our friends list (either they were deleted or were banned from bluesky)

# %%
pip install atproto
# Out:
# Requirement already satisfied: atproto in /usr/local/lib/python3.11/dist-packages (0.0.58)
# Requirement already satisfied: click<9,>=8.1.3 in /usr/local/lib/python3.11/dist-packages (from atproto) (8.1.8)
# Requirement already satisfied: cryptography<44,>=41.0.7 in /usr/local/lib/python3.11/dist-packages (from atproto) (43.0.3)
# Requirement already satisfied: dnspython<3,>=2.4.0 in /usr/local/lib/python3.11/dist-packages (from atproto) (2.7.0)
# Requirement already satisfied: httpx<0.28.0,>=0.25.0 in /usr/local/lib/python3.11/dist-packages (from atproto) (0.27.2)
# Requirement already satisfied: libipld<4,>=2.0.0 in /usr/local/lib/python3.11/dist-packages (from atproto) (3.0.0)
# Requirement already satisfied: pydantic<3,>=2.7 in /usr/local/lib/python3.11/dist-packages (from atproto) (2.10.6)
# Requirement already satisfied: typing-extensions<5,>=4.8.0 in /usr/local/lib/python3.11/dist-packages (from atproto) (4.12.2)
# Requirement already satisfied: websockets<14,>=12 in /usr/local/lib/python3.11/dist-packages (from atproto) (13.1)
# Requirement already satisfied: cffi>=1.12 in /usr/local/lib/python3.11/dist-packages (from cryptography<44,>=41.0.7->atproto) (1.17.1)
# Requirement already satisfied: anyio in /usr/local/lib/python3.11/dist-packages (from httpx<0.28.0,>=0.25.0->atproto) (3.7.1)
# Requirement already satisfied: certifi in /usr/local/lib/python3.11/dist-packages (from httpx<0.28.0,>=0.25.0->atproto) (2024.12.14)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.11/dist-packages (from httpx<0.28.0,>=0.25.0->atproto) (1.0.7)
# Requirement already satisfied: idna in /usr/local/lib/python3.11/dist-packages (from httpx<0.28.0,>=0.25.0->atproto) (3.10)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.11/dist-packages (from httpx<0.28.0,>=0.25.0->atproto) (1.3.1)
# Requirement already satisfied: h11<0.15,>=0.13 in /usr/local/lib/python3.11/dist-packages (from httpcore==1.*->httpx<0.28.0,>=0.25.0->atproto) (0.14.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.11/dist-packages (from pydantic<3,>=2.7->atproto) (0.7.0)
# Requirement already satisfied: pydantic-core==2.27.2 in /usr/local/lib/python3.11/dist-packages (from pydantic<3,>=2.7->atproto) (2.27.2)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.11/dist-packages (from cffi>=1.12->cryptography<44,>=41.0.7->atproto) (2.22)

# %%
from atproto import Client
from google.colab import userdata

# these imports are to use github apis to do logging, base64 is to parse the json
import requests
import base64
# datetime for logging
import datetime
import zoneinfo

BSKY_USERNAME = userdata.get('bsky_username')
BSKY_PASSWORD = userdata.get('bsky_password')

client = Client()
client.login(BSKY_USERNAME, BSKY_PASSWORD)
# Out:
# ProfileViewDetailed(did='did:plc:ktkc7jfakxzjpooj52ffc6ra', handle='tyrowo.com', associated=ProfileAssociated(chat=None, feedgens=0, labeler=False, lists=0, starter_packs=0, py_type='app.bsky.actor.defs#profileAssociated'), avatar='https://cdn.bsky.app/img/avatar/plain/did:plc:ktkc7jfakxzjpooj52ffc6ra/bafkreiepqgg5tlozvv4bw5ficwwixflfprionhnli26hngc3hjn6ygpamu@jpeg', banner='https://cdn.bsky.app/img/banner/plain/did:plc:ktkc7jfakxzjpooj52ffc6ra/bafkreierasgybimbz3pfobqfmay5ufxm7jlqnjeiumdx7dyof6mcss7a4m@jpeg', created_at='2023-08-28T14:18:41.780Z', description='Cat poster. Self-taught professional software developer, exF2P MTG Arena Challenger, ex wr holder speedrunning HotD2_100%, ex streamer, ex melee player. \nGrilling, coding, gaming, magic:tg, tcgs, and my kitty, Ricky 😻\nNO POLITICS\nhe/him', display_name='Tyro, ft Ricky', followers_count=2593, follows_count=6328, indexed_at='2025-01-31T21:22:03.213Z', joined_via_starter_pack=None, labels=[], pinned_post=Main(cid='bafyreihszjgxkh5fmu5je5eldv6i27ubndfcyhwcbjsin4jsbfo2gu45ky', uri='at://did:plc:ktkc7jfakxzjpooj52ffc6ra/app.bsky.feed.post/3lcbntv5rmc2j', py_type='com.atproto.repo.strongRef'), posts_count=198, viewer=ViewerState(blocked_by=False, blocking=None, blocking_by_list=None, followed_by=None, following=None, known_followers=KnownFollowers(count=2145, followers=[ProfileViewBasic(did='did:plc:isliyiq3gjuxpwysdpdgj5t3', handle='chateauminette.com', associated=ProfileAssociated(chat=ProfileAssociatedChat(allow_incoming='following', py_type='app.bsky.actor.defs#profileAssociatedChat'), feedgens=None, labeler=None, lists=None, starter_packs=None, py_type='app.bsky.actor.defs#profileAssociated'), avatar='https://cdn.bsky.app/img/avatar/plain/did:plc:isliyiq3gjuxpwysdpdgj5t3/bafkreibdrunuo63uix5ex4e35nqaiya3rtt3v6suongv2ozavvyeu2u4ei@jpeg', created_at='2023-04-30T14:38:48.713Z', display_name='Chateau Minette', labels=[], viewer=ViewerState(blocked_by=False, blocking=None, blocking_by_list=None, followed_by='at://did:plc:isliyiq3gjuxpwysdpdgj5t3/app.bsky.graph.follow/3lg2cp2jeb32r', following='at://did:plc:ktkc7jfakxzjpooj52ffc6ra/app.bsky.graph.follow/3lfux5yfjiq2c', known_followers=None, muted=False, muted_by_list=None, py_type='app.bsky.actor.defs#viewerState'), py_type='app.bsky.actor.defs#profileViewBasic'), ProfileViewBasic(did='did:plc:5p6dvkv2oewtrk4tg6kjxvfz', handle='manelcamacho.bsky.social', associated=ProfileAssociated(chat=ProfileAssociatedChat(allow_incoming='none', py_type='app.bsky.actor.defs#profileAssociatedChat'), feedgens=None, labeler=None, lists=None, starter_packs=None, py_type='app.bsky.actor.defs#profileAssociated'), avatar='https://cdn.bsky.app/img/avatar/plain/did:plc:5p6dvkv2oewtrk4tg6kjxvfz/bafkreidn5ebplo6xlomimqqpfdi6yquankw4r3ukdfeelxu7fl2xgvfclq@jpeg', created_at='2023-07-29T05:24:24.944Z', display_name='Manu  🌊🐳🐦\u200d⬛🏔️🌎', labels=[Label(cts='1970-01-01T00:00:00.000Z', src='did:plc:5p6dvkv2oewtrk4tg6kjxvfz', uri='at://did:plc:5p6dvkv2oewtrk4tg6kjxvfz/app.bsky.actor.profile/self', val='!no-unauthenticated', cid='bafyreigi6ud7e6i5pvkfw7ufs6sr747brere7azlt3y4aimzghdd7wj7ga', exp=None, neg=None, sig=None, ver=None, py_type='com.atproto.label.defs#label')], viewer=ViewerState(blocked_by=False, blocking=None, blocking_by_list=None, followed_by='at://did:plc:5p6dvkv2oewtrk4tg6kjxvfz/app.bsky.graph.follow/3lggkroicc32p', following='at://did:plc:ktkc7jfakxzjpooj52ffc6ra/app.bsky.graph.follow/3lggkndelsx2d', known_followers=None, muted=False, muted_by_list=None, py_type='app.bsky.actor.defs#viewerState'), py_type='app.bsky.actor.defs#profileViewBasic'), ProfileViewBasic(did='did:plc:2hxnaryilszltnna7vlsllsu', handle='virgosplaining.bsky.social', associated=None, avatar='https://cdn.bsky.app/img/avatar/plain/did:plc:2hxnaryilszltnna7vlsllsu/bafkreigvcsh3fxkfdo4debyz5z75hxgc43uoqofg7fzsyxqnxr5id2rypy@jpeg', created_at='2023-08-25T01:49:30.988Z', display_name='divided by zero', labels=[], viewer=ViewerState(blocked_by=False, blocking=None, blocking_by_ ...

# %%
# initiate the string to add to our logger file
LINE_BREAK = '\n'
END_LOGGING = '\n____________________\n'
following = client.get_profile(actor=BSKY_USERNAME).follows_count
followers = client.get_profile(actor=BSKY_USERNAME).followers_count
USER_TIMEZONE = "US/Eastern" # you should fill this in with your own timezone here
cur_timestamp = datetime.datetime.now(zoneinfo.ZoneInfo(USER_TIMEZONE))
# print(cur_timestamp)
logging_text = LINE_BREAK + str(cur_timestamp) + LINE_BREAK + 'UPDATING "FOLLOWS" TABLE IN DATABASE' + LINE_BREAK + LINE_BREAK + 'prior follower count: ' + str(followers) + LINE_BREAK + 'previously following: ' + str(following) + LINE_BREAK + LINE_BREAK
print(logging_text)
# logging_stats = {}
# Out:
# 2025-01-31 17:36:09.578035-05:00
# UPDATING "FOLLOWS" TABLE IN DATABASE
#
# prior follower count: 2593
# previously following: 6328

# %%
SCHEMA = '"bsky"'
TABLE_FOLLOWS = '"follows"'
COL_USERID = 'user_id'
COL_USERHANDLE = 'user_handle'
COL_FOLLOWURI = 'follow_uri'
COL_FOLLOWDATE = 'follow_date'
COL_FOLLOWSYOU = 'follows_you'
END_LINE = ','
END_QUERY = ';'

# %% [markdown]
# ```
# SELECT * FROM "bsky"."follows"
# ```

# %% [markdown]
# ```
# # paste select all query from followers table into here
# select_all_follows = '''
#
#
#
# '''
# ```

# %%
# paste select all query from followers table into here
select_all_follows = '''



'''

# %%
# set up map - key = did, values = [did, handle, follow_uri, follow_date, follows_you]
db_follows = {}

# !! for some reason when I input my select statements, it's breaking the final column into its own line at the end. So I have to do some extra processing beforehand to clean up the True and False values
split_rows = 'FALSE'.join(select_all_follows.strip().split('\nFALSE'))
split_rows = 'TRUE'.join(split_rows.split('\nTRUE'))
# print(split_rows)

# now we can split the raw output into lines
split_rows = split_rows.split('\n')

for row in split_rows:
  # char to split on is '	' I think it's a tab,
  # DO NOT use the default split(), because we are using a timestamp for the follow_date, which has a space in it. that means we will get an extra column for date+time
  values = row.split('	')
  db_follows[values[0]] = values

# print(db_follows)
# now we have a map of what exists in our database as is
logging_text = logging_text + f'{len(db_follows)} entries were found in the database "follows" table prior to updating.' + LINE_BREAK + LINE_BREAK

# %%
# next we have to create 3 results lists: two updates, and an insert list. The delete users will then be converted from the remaining map
# also a 4th list to look at any messed up follow links
update_stopped_following = []
update_started_following = []
insert_new_follows = []
follow_link_mismatches = []

# generate our account's follows list
following = client.get_profile(actor=BSKY_USERNAME).follows_count
print(f'currently following {following} users')
next_page = ''
remaining = following
while remaining > 0:
  print (f'starting the next page of follows. {remaining} followers remaining to check.')
  cur_limit = min(remaining, 100)
  remaining -= cur_limit
  follows = client.get_follows(actor=BSKY_USERNAME, cursor= next_page, limit=cur_limit)
  next_page = follows.cursor
  follows = follows.follows
  for follow in follows:
    # need did, user handle, follow_uri, date_added, follows_you
    did = follow.did
    handle = follow.handle
    follow_uri = follow.viewer.following
    date_added = "NOW()"
    # following is whether they are following you, it looks like followed_by is if they are following you back.
    follows_you = 'FALSE' if follow.viewer.followed_by == None else 'TRUE' # need to format it as a string so it matches what we've got

    # now we have our 4 conditions to check for
    if did not in db_follows:
      # need to add to the insert list
      insert_new_follows.append(f"    ('{did}', '{handle}', '{follow_uri}', {date_added}, {follows_you})") # date_added doesn't need quotations but the others
    else:
      # this did exists as a row in our database, so let's do some comparisons
      cur_row = db_follows[did] # cur row is [did, handle, follow_uri, date_added, follows_you] same as above
      if follow_uri != cur_row[2]:
        # I'm not sure what causes this but it did happen a few times.
        print(f'!! follow uris do not match for user {handle}! {follow_uri} != {cur_row[2]}')
        follow_link_mismatches.append([follow_uri, cur_row[2]])
      if follows_you != cur_row[4]:
        # so the follows you doesn't match, which means that if follows_you is true then we need to add this to the stopped following, and otherwise add it to the
        if cur_row[4] == 'TRUE':
          update_stopped_following.append(f"'{did}'")
        else:
          update_started_following.append(f"'{did}'")
      # after the checks we are finished with this entry, so delete it from the map
      del db_follows[did]

    # couldn't use {END_LINE if cur < following else ''} in this print statement for some reason following rounds but the limit gets the exact amount no problem...
logging_text = logging_text + f'Analysis of follows shows: ' + LINE_BREAK
logging_text = logging_text + f'  Started Following: {len(update_started_following)} ' + LINE_BREAK
logging_text = logging_text + f'  Stopped Following: {len(update_stopped_following)} ' + LINE_BREAK
logging_text = logging_text + f'  New Follows Added To DB: {len(insert_new_follows)} ' + LINE_BREAK
logging_text = logging_text + f'  Follow Link Mismatches: {len(follow_link_mismatches)} ' + LINE_BREAK
# Out:
# currently following 6328 users
# starting the next page of follows. 6328 followers remaining to check.
# starting the next page of follows. 6228 followers remaining to check.
# starting the next page of follows. 6128 followers remaining to check.
# starting the next page of follows. 6028 followers remaining to check.
# starting the next page of follows. 5928 followers remaining to check.
# starting the next page of follows. 5828 followers remaining to check.
# starting the next page of follows. 5728 followers remaining to check.
# starting the next page of follows. 5628 followers remaining to check.
# starting the next page of follows. 5528 followers remaining to check.
# starting the next page of follows. 5428 followers remaining to check.
# starting the next page of follows. 5328 followers remaining to check.
# starting the next page of follows. 5228 followers remaining to check.
# starting the next page of follows. 5128 followers remaining to check.
# starting the next page of follows. 5028 followers remaining to check.
# starting the next page of follows. 4928 followers remaining to check.
# starting the next page of follows. 4828 followers remaining to check.
# starting the next page of follows. 4728 followers remaining to check.
# starting the next page of follows. 4628 followers remaining to check.
# starting the next page of follows. 4528 followers remaining to check.
# starting the next page of follows. 4428 followers remaining to check.
# starting the next page of follows. 4328 followers remaining to check.
# starting the next page of follows. 4228 followers remaining to check.
# starting the next page of follows. 4128 followers remaining to check.
# starting the next page of follows. 4028 followers remaining to check.
# starting the next page of follows. 3928 followers remaining to check.
# starting the next page of follows. 3828 followers remaining to check.
# !! follow uris do not match for user tyrowo.com! None != None
# starting the next page of follows. 3728 followers remaining to check.
# starting the next page of follows. 3628 followers remaining to check.
# starting the next page of follows. 3528 followers remaining to check.
# starting the next page of follows. 3428 followers remaining to check.
# starting the next page of follows. 3328 followers remaining to check.
# starting the next page of follows. 3228 followers remaining to check.
# starting the next page of follows. 3128 followers remaining to check.
# starting the next page of follows. 3028 followers remaining to check.
# starting the next page of follows. 2928 followers remaining to check.
# starting the next page of follows. 2828 followers remaining to check.
# starting the next page of follows. 2728 followers remaining to check.
# starting the next page of follows. 2628 followers remaining to check.
# starting the next page of follows. 2528 followers remaining to check.
# starting the next page of follows. 2428 followers remaining to check.
# starting the next page of follows. 2328 followers remaining to check.
# starting the next page of follows. 2228 followers remaining to check.
# starting the next page of follows. 2128 followers remaining to check.
# starting the next page of follows. 2028 followers remaining to check.
# starting the next page of follows. 1928 followers remaining to check.
# starting the next page of follows. 1828 followers remaining to check.
# starting the next page of follows. 1728 followers remaining to check.
# starting the next page of follows. 1628 followers remaining to check.
# starting the next page of follows. 1528 followers remaining to check.
# starting the next page of follows. 1428 followers remaining to check.
# starting the next page of follows. 1328 followers remaining to check.
# starting the next page of follows. 1228 followers remaining to check.
# starting the next page of follows. 1128 followers remaining to check.
# starting the next page of follows. 1028 followers remaining to check.
# starting the next page of follows. 928 followers remaining to check.
# starting the next page of follows. 828 followers remaining to check.
# starting the next page of follows. 728 followers remaining to check.
# starting the next page of follows. 628 followers remaining to check.
# starting the next page of follows. 528 followers remaining to check.
# starting the next page of follows. 428 followers remaining to check.
# starting the next page of follows. 328 followers remaining to check.
# starting the next page of follows. 228 followers remaining to check.
# starting the next page of follows. 128 followers remaining to check.
# starting the next page of follows. 28 followers remaining to check.

# %%
def generate_update_query_no_longer_following(user_list):
  if not user_list:
    print('NO CHANGES NECESSARY')
    return
  users_in = ','.join(user_list)
  print(f'UPDATE {SCHEMA}.{TABLE_FOLLOWS}')
  print(f'SET {COL_FOLLOWSYOU} = FALSE')
  print(f'WHERE {COL_USERID} IN({users_in})')
  print(f'RETURNING {COL_USERHANDLE}, {COL_FOLLOWSYOU}{END_QUERY}')

def generate_update_query_now_following(user_list):
  if not user_list:
    print('NO CHANGES NECESSARY')
    return
  users_in = ','.join(user_list)
  print(f'UPDATE {SCHEMA}.{TABLE_FOLLOWS}')
  print(f'SET {COL_FOLLOWSYOU} = TRUE')
  print(f'WHERE {COL_USERID} IN({users_in})')
  print(f'RETURNING {COL_USERHANDLE}, {COL_FOLLOWSYOU}{END_QUERY}')

def generate_insert_query(rows_list):
  if not rows_list:
    print('NO CHANGES NECESSARY')
    return
  values = ', \n'.join(rows_list)
  print(f'INSERT INTO {SCHEMA}.{TABLE_FOLLOWS} ({COL_USERID}, {COL_USERHANDLE}, {COL_FOLLOWURI}, {COL_FOLLOWDATE}, {COL_FOLLOWSYOU}) ')
  print(f'VALUES ')
  print(values)
  print(f'RETURNING {COL_USERHANDLE}, {COL_FOLLOWDATE}{END_QUERY}')

# for users no longer following or users that no longer exist, weren't found in the comparison
def generate_delete_query(remaining_users_map):
  if not remaining_users_map:
    print('NO CHANGES NECESSARY')
    return
  user_list = [f"'{key}'" for key in remaining_users_map.keys()]
  users_in = ','.join(user_list)
  print(f'DELETE FROM {SCHEMA}.{TABLE_FOLLOWS}')
  print(f'WHERE {COL_USERID} IN({users_in})')
  print(f'RETURNING {COL_USERHANDLE}{END_QUERY}')

def generate_update_follow_uri_query(new_uri, old_uri):
  print(f'UPDATE {SCHEMA}.{TABLE_FOLLOWS}')
  print(f'SET {COL_FOLLOWURI} = {new_uri}')
  print(f'WHERE {COL_FOLLOWURI} = {old_uri}')
  print(f'RETURNING {COL_USERHANDLE}, {COL_FOLLOWURI}{END_QUERY}')

# %%
for new, old in follow_link_mismatches:
  print('---------------------')
  print(' ')
  generate_update_follow_uri_query(f"'{new}'", f"'{old}'")
  print(' ')
  print('---------------------')
if not follow_link_mismatches:
  print('NO CHANGES NECESSARY')
# Out:
# ---------------------
#
# UPDATE "bsky"."follows"
# SET follow_uri = 'None'
# WHERE follow_uri = 'None'
# RETURNING user_handle, follow_uri;
#
# ---------------------

# %%
generate_update_query_no_longer_following(update_stopped_following)
# Out:
# NO CHANGES NECESSARY

# %%
generate_update_query_now_following(update_started_following)
# Out:
# UPDATE "bsky"."follows"
# SET follows_you = TRUE
# WHERE user_id IN('did:plc:3h6mshnzjqq2wv3yweuepztl','did:plc:lp7fm3rnuqiy3q53e7dsfsbk','did:plc:egl7qlss7fuqcplqbevf54a6','did:plc:vzwjc43kbhl4ck43jojabcns','did:plc:lzfstkplsllfzuyurjuacpf5','did:plc:bsfkrvkgspgv7nx7yyvn6kfy','did:plc:7zmorwyqckpcplxag2zp34o3','did:plc:nmvyvypnjv4ydvbi6s3h3izi','did:plc:r35gvkfs32uox2rklgdyujhp','did:plc:pzrzdivp4yzgpytj37vuoysk','did:plc:v624rttntnmx4g4ltl2abjvx','did:plc:3ejhoisou6ylus6nqhmzn4cz','did:plc:knrrkraqpdjoi5ecdtjahfa6','did:plc:6g4qdh7mxv5yzq3uguuobnrl','did:plc:7p4i5gtnhtgcyk4jnfubhcbr','did:plc:e4tiigurd24ecejasr3zci6k','did:plc:i6c4h7vnkhj4iott3xbvkxs5','did:plc:2igtxyppnkc2onqak5xs4tw6','did:plc:hbdn7zl3cjchgmwbxeltcvs3','did:plc:oe6ivekvkkrmxuhniogcz5io','did:plc:recnwd5i5obdruaqibf44rmr','did:plc:chssimgrj5rl5trj4cimvopf','did:plc:ud44iierzn26ekcwk6mi7hgm','did:plc:unwafe7xicjkgxqclhrsxws6','did:plc:q53d2zruuh2u5vdecekc2qao','did:plc:nztqzaeezch2wv7hvrmsiujf','did:plc:upo56wwceuz2r77fd5lhu6ir','did:plc:xrmheurzfyojksa5qnvonryi','did:plc:2ssadcfd7ha6nlbt66syvfwa','did:plc:czyry3shham4xnaatr3tooqs','did:plc:qbxsyi2gnhqrcm37ao6hsw2z','did:plc:hjsycikerjvu4xzpeypmgjfk','did:plc:wz74jsydgnjs2t453zeizg2c','did:plc:4bhiok3npxadun5pzrjttgx5','did:plc:iyn6znf2tf6xwgtervhogbjb','did:plc:eo3fvj2gg72utnjwpdamieu2','did:plc:udiuh3iz6yfbnvcmtdvpfzqo','did:plc:gz3q2kw3riea7xg7eafmdcow','did:plc:l6xikn3gp77tzjnjxnb6r2tq','did:plc:md2ars4slqh7dols43tpy644','did:plc:ocpzeltihiisreympuhfdbau','did:plc:a3br24vm2hs7twedr6y6krhh','did:plc:phzdkqrprqwdjdjrkchsy2kn','did:plc:srwm6cedykjyekrp27oioxp5','did:plc:egusciesba25vkr7f5jbu753','did:plc:aru27wldp7ov4pm5fvyy2cn6','did:plc:paapaii6vmwqwkouprj6lj2b','did:plc:5znc2i33emfldfpl7ujbj5km','did:plc:njiwxr5z6npfbjx2etecr634','did:plc:fgffakayfeu457rmgr4tx3pe','did:plc:wlxfuv6zn6cnpq6bol6ysgbj','did:plc:4penildk4ny5jkpnsgzobuca','did:plc:75f52qltpehafpuza7yikw7f','did:plc:ljcijtpwp25xne36fpst3g5o','did:plc:ludbkazh2ssw7vbvmqebhsus','did:plc:hrfuejaz4mynu762y6z4mimk','did:plc:op7aigfe6n6itudsjyu6lrot','did:plc:i3ivtng5f6zsfsn6lsq5i4nt','did:plc:e7xdpse2xxshn4u2kvz5bzkz','did:plc:2l7wcu7gtlm6klvhmni76z5t','did:plc:5ldlnsqixnlwuts3uooevqeb','did:plc:6opqhof4arkxokttpbb6q2i2','did:plc:eowngxwcrpnmtp3ufah7jvlu','did:plc:fl6uenek5ab4gkaxcraj2yzf','did:plc:wbiaan2bl2mjonghjvluipco','did:plc:mkjit6yfb7jp7twp6ifjxmjo','did:plc:m3u44qxfxh5kkzgadzmnzfrg','did:plc:ssrqr6ifbjjpzmpoxwod6hyd','did:plc:hq3rmekjpiykqlqqambbtnhh','did:plc:njmimnefshv6oxpjjk4tolgu','did:plc:o7mmwgcxn55jvzbiglrnyodx','did:plc:ujeg5gp7byrjnrvlh6lazvc6','did:plc:pmooeamwi4ad43gaelebchni','did:plc:u6fw57o3j3nbioiulekbwe3u','did:plc:nwcnmqzgnljymcyhn25wfbgv','did:plc:ctcn4dorlf5ttmdono62uird','did:plc:7ppi3s4ybftbtg3dm23tit3u','did:plc:bwgfqgjwiccldfmdg7w247bc','did:plc:mxts7z6axz7w4a6awyv6ciz7','did:plc:qkv74bmhh4v5d75z6uj4ogla','did:plc:preogocvkxsksfmc5vnl6g4f','did:plc:6w7iacmgl7ccz3ytq6v6eikx','did:plc:hupispcdzeoeepwunbekinri','did:plc:hjp5rfhvmyyf73eqg5h5nvny','did:plc:v33bmwfrawdvhoczvsv6o2dy','did:plc:5smdvutwkofqdrm7n6l6mwhi','did:plc:76juygj4a6nvsh4udnx5jzo6','did:plc:ovdyjkhiivi3ygdiibjqmxxx','did:plc:66q7h2zksbogwhwuh4uvolbp','did:plc:k7bubzo33mv75vfbmgriwo54','did:plc:dqip774d5wyzrwow7xq67scf','did:plc:k4ebpfzbvzaqiwcuxhg3wo73','did:plc:6xfjvdn4aszegspcubh7msg4','did:plc:ae3bmka7dywnt65odzzjfvho','did:plc:e6nrzdv2zf5iwyrfn435alil','did:plc:pbtjzjtg4u2qgrwoxrvy5nj5','did:plc:si4ngrsfb4lk44h5b2vpzybp','did:plc:geeogowkusfg6nuy6236g6pt','did:plc:xqatq4jqzu5whbudbw6gjzjt','did:plc:emldswy74gkeyvla2jpdime4','did:plc:zpz7nuigwks2zzqt3xvd3mum','did:plc:th27vt3ebb44ieniuj7krlur','did:plc:6nhaznwqd7zkgwalcumarjfo','did:plc:mwpubvpiaddthywa6tqvg7kv','did:plc:deavp5ox4kzq3f32llidy63g','did:plc:hhzc5lcdmp65g6hxw4cewpz2','did:plc:nk6a3nduxkwmr5ameq4b3xfw','did:plc:pf6obs7z6ng6lposupm7ghrt','did:plc:njx4laa4eczn3q4nw7hlqgor','did:plc:na5jhjoejzyr4bu4n2pd3exi','did:plc:zjcdv6sffcgm6fjdaowf2sel','did:plc:4wiwytvdhctlwpersrirudjw','did:plc:izfrsbjty3eqdnf2xv776xbv','did:plc:h6fqh3nntw6d2l4fhtj ...
# RETURNING user_handle, follows_you;

# %%
generate_insert_query(insert_new_follows)
# Out:
# INSERT INTO "bsky"."follows" (user_id, user_handle, follow_uri, follow_date, follows_you)
# VALUES
#     ('did:plc:2w3rvm3y64u2trnz3xdzznqy', 'smelting.bsky.social', 'at://did:plc:ktkc7jfakxzjpooj52ffc6ra/app.bsky.graph.follow/3lh32lr42pd2c', NOW(), FALSE),
#     ('did:plc:pb7cnqz3t27zfqvxwrqfbtyn', 'envy2024.bsky.social', 'at://did:plc:ktkc7jfakxzjpooj52ffc6ra/app.bsky.graph.follow/3lh32lqq7vs2d', NOW(), FALSE),
#     ('did:plc:hbo3vaow3gmkjr47wcrkpdza', 'crapconsumer.bsky.social', 'at://did:plc:ktkc7jfakxzjpooj52ffc6ra/app.bsky.graph.follow/3lh32lqd5ea2o', NOW(), FALSE),
#     ('did:plc:rswm6hiaalijwbuodzu2mchj', 'milotic.bsky.social', 'at://did:plc:ktkc7jfakxzjpooj52ffc6ra/app.bsky.graph.follow/3lh32lmi2tb2x', NOW(), FALSE),
#     ('did:plc:xhcl6cbefxy7nsgq6x6ht67f', 'zumphry.com', 'at://did:plc:ktkc7jfakxzjpooj52ffc6ra/app.bsky.graph.follow/3lh32llzamm2h', NOW(), FALSE),
#     ('did:plc:7vcveodd4rn45stgjo3kfekr', 'uglyjacket.bsky.social', 'at://did:plc:ktkc7jfakxzjpooj52ffc6ra/app.bsky.graph.follow/3lh32lllk4p2a', NOW(), FALSE),
#     ('did:plc:s4244lh2ulkkbm6jjvwjaaeg', '90sslowjamz.bsky.social', 'at://did:plc:ktkc7jfakxzjpooj52ffc6ra/app.bsky.graph.follow/3lh32ll4hy524', NOW(), FALSE),
#     ('did:plc:hlmt2ablujd6hjbltzw365qw', 'alygory.bsky.social', 'at://did:plc:ktkc7jfakxzjpooj52ffc6ra/app.bsky.graph.follow/3lh32lko6pn2l', NOW(), FALSE),
#     ('did:plc:r5j3cgakfx2hxesisdbc7evj', 'lizhebert.bsky.social', 'at://did:plc:ktkc7jfakxzjpooj52ffc6ra/app.bsky.graph.follow/3lh32lkbb3q2p', NOW(), FALSE),
#     ('did:plc:3gy33x3wdrjau2rzu57r47us', 'bough.cloud', 'at://did:plc:ktkc7jfakxzjpooj52ffc6ra/app.bsky.graph.follow/3lh32lilt7222', NOW(), FALSE),
#     ('did:plc:rhf3ht2f4qym52xcmteoge2g', 'slime-golem.biz', 'at://did:plc:ktkc7jfakxzjpooj52ffc6ra/app.bsky.graph.follow/3lh32lhjvq52l', NOW(), FALSE),
#     ('did:plc:5e22yjxdv4oce7vytcx4z3bp', 'sccoast.bsky.social', 'at://did:plc:ktkc7jfakxzjpooj52ffc6ra/app.bsky.graph.follow/3lh32lh4pua2c', NOW(), FALSE),
#     ('did:plc:rqwp2yogebmbcyo7zv3q2uz2', 'silphium.bsky.social', 'at://did:plc:ktkc7jfakxzjpooj52ffc6ra/app.bsky.graph.follow/3lh32lgqhnz2m', NOW(), FALSE),
#     ('did:plc:qvx3z4s6u3rbvkdivhgxmx64', 'skyrimdiet.bsky.social', 'at://did:plc:ktkc7jfakxzjpooj52ffc6ra/app.bsky.graph.follow/3lh32lg6wws2d', NOW(), FALSE),
#     ('did:plc:2ecsx2punx7djbqlcwpsyjnc', 'slig.bsky.social', 'at://did:plc:ktkc7jfakxzjpooj52ffc6ra/app.bsky.graph.follow/3lh32lfsy6s2f', NOW(), FALSE),
#     ('did:plc:5vfx772jqq7ryibzoq2cat2r', 'bhendricksen.bsky.social', 'at://did:plc:ktkc7jfakxzjpooj52ffc6ra/app.bsky.graph.follow/3lh32lflwtk22', NOW(), TRUE),
#     ('did:plc:tzgpavof4crvsy6gqmil62o3', 'felistrawberry.bsky.social', 'at://did:plc:ktkc7jfakxzjpooj52ffc6ra/app.bsky.graph.follow/3lh32ldh5ek2d', NOW(), FALSE),
#     ('did:plc:zgbfimpnmurqfxsjqpgneotn', 'goblin.news', 'at://did:plc:ktkc7jfakxzjpooj52ffc6ra/app.bsky.graph.follow/3lh32lcyktc22', NOW(), FALSE),
#     ('did:plc:7r46wb2sdsmtieu7asxr2rsp', 'verylarge.bsky.social', 'at://did:plc:ktkc7jfakxzjpooj52ffc6ra/app.bsky.graph.follow/3lh32lcle3k26', NOW(), FALSE),
#     ('did:plc:f7tzucxlil2hedwqswlrwit3', 'spelllcheck.bsky.social', 'at://did:plc:ktkc7jfakxzjpooj52ffc6ra/app.bsky.graph.follow/3lh32lc4y5q2o', NOW(), FALSE),
#     ('did:plc:l5r23amjf5ef4w24ilkohmrl', 'atomly.com', 'at://did:plc:ktkc7jfakxzjpooj52ffc6ra/app.bsky.graph.follow/3lh32latnf32c', NOW(), FALSE),
#     ('did:plc:ed7pahjketlkh5kxvlsdjot7', 'emilonwheels.bsky.social', 'at://did:plc:ktkc7jfakxzjpooj52ffc6ra/app.bsky.graph.follow/3lh32laf6dx2a', NOW(), FALSE),
#     ('did:plc:nw3g6e6pu777y7iwty64bmx7', 'zeklandia.bsky.social', 'at://did:plc:ktkc7jfakxzjpooj52ffc6ra/app.bsky.graph.follow/3lh32l7t2uj2x', NOW(), FALSE),
#     ('did:plc:e7suvtytpfkjye2ogjw5txie', 'doctormollura.bsky.social', 'at://did:plc:ktkc7jfakxzjpooj52ffc6ra/app.bsky.graph.follow/3lh32l7ef3s22', NOW(), FALSE),
#     ('did:plc:vcbu6prt755clcqdhpdugeuv', 'carrion1750.bsky.social', 'at://did:plc:ktkc7jfakxzjpooj52ffc6ra/app.bsky.graph.follow/3lh32l72vcy2p', NOW(), FALSE),
#     ('did:plc:eydm34yt7qjxe62to7hkexow', 'lynndaj.bsky.social', 'at://did:plc:ktkc7jfakxzjpooj52ffc6ra/app.bsky.graph.follow/3lh32l5t5yt23', NOW(), FALSE),
#     ('did:plc:oiqaiatx6xu6bdtg7ejnr4mu', 'rhombergerer.bsky.social', 'at://did:plc:ktkc7jfakxzjpooj52ffc6ra/app.bsky.graph.follow/3lh32l5fxji2c', NOW(), FALSE),
#     ('did:plc:reo7ah66nruqpfb3expeqsfk', 'beeep.computer', 'at://did:plc:ktkc7jfakxzjpooj52ffc6ra/app.bsky.graph.follow/3lh32l4z5xq2o', NOW(), FALSE),
#     ('did:plc:u4362xtt53pa7zx5l33od5uf', 'fnowae.bsky.social', 'at://did:plc:ktkc7jfakxzjpooj52ffc6ra/app.bsky.graph.follow/3lh32l3nodk26', NOW(), FALSE),
#     ('did:plc:flur5wqte3jtblp7lsabb33i', 'invisiblegalaxy.bsky.social', 'at://did:plc:ktkc7jfakxzjpooj52ffc6ra/app.bsky.graph.follow/3lh32l37xs222', NOW(), FALSE),
#     ('did:plc:hfsacxkvriefl5xphvtlcxt6', 'ratsavant.bsky.social', 'at://did:plc:ktkc7jfakxzjpooj52ffc6ra/app.bsky.graph.follow/3lh32l2seyc2f', NOW(), FALSE),
#     ('did:plc:qk63kkxcxr3jupwhfolneilr', 'lisadudleymusic.bsky.social', 'at://did:plc:ktkc7jfakxzjpooj52ffc6ra/app.bsky.graph.follow/3lh32kzfokk22', NOW(), FALSE),
#     ('did:plc:wwbnbdl6wpjdhtnwncrzwziu', 'equalizer13.bsky.social', 'at://did:plc:ktkc7jfakxzjpooj52ffc6ra/app.bsky.graph.follow/3lh32kyu3nl2c', NOW(), FALSE),
#     ('did:plc:3f4nho7sqokzf4jkhrltn7kz', 'razzlebathbone.bsky.social', 'at://did:plc:ktkc7jfakxzjpooj52ffc6ra/app.bsky.graph.follow/3lh32kxjyit23', NOW(), FALSE),
#     ('did:plc:n23dvbendbzktfinf7rqnqre', 'leslielyons.bsky.social', 'at://did:plc:ktkc7jfakxzjpooj52ffc6ra/app.bsky.graph.follow/3lh32kwzzgc2f', NOW(), FALSE),
#     ('did:plc:r62sgp3jtjvdy2yzun7n44t5', 'jajcrob.bsky.social', 'at://did:plc:ktkc7jfakxzjpooj52ffc6ra/app.bsky.graph.follow/3lh32kwmlhq2c', NOW(), FALSE),
#     ('did:plc:f7wfny55ckcktocsgviu4iyr', 'horky.bsky.social', 'at://did:plc:ktkc7jfakxzjpooj52ffc6ra/app.bsky.graph.follow/3lh32kvdy7j2x', NOW(), FALSE),
#     ('did:plc:vehfow75bn4dmlzbmobqdq57', 'mmardon.bsky.social', 'at://did:plc:ktkc7jfakxzjpooj52ffc6ra/app.bsky.graph.follow/3lh32kuy5op2a', NOW(), FALSE),
#     ('did:plc:tj2sxhqq37yb6bl3lv7ffef6', 'snazzysocksmoon.bsky.social', 'at://did:plc:ktkc7jfakxzjpooj52ffc6ra/app.bsky.graph.follow/3lh32kuk7x222', NOW(), FALSE),
#     ('did:plc:gqetrhqtfewl6o4meuoqgmcr', 'midgie.bsky.social', 'at://did:plc:ktkc7jfakxzjpooj52ffc6ra/app.bsky.graph.follow/3lh32ku3dgj2x', NOW(), FALSE),
#     ('did:plc:dl5eqdwr5cmfditx6rhigcdj', 'jabroxenbrodium.bsky.social', 'at://did:plc:ktkc7jfakxzjpooj52ffc6ra/app.bsky.graph.follow/3lh32ktoo7i2o', NOW(), FALSE),
#     ('did:plc:aplvqaodapxq3byd4ibiqqhn', 'magichateball.org', 'at://did:plc:ktkc7jfakxzjpooj52ffc6ra/app.bsky.graph.follow/3lh32ksasgq2o', NOW(), FALSE),
#     ('did:plc:s7im66dmkz46mgisxpf5vlas', 'grobiansyboe.bsky.social', 'at://did:plc:ktkc7jfakxzjpooj52ffc6ra/app.bsky.graph.follow/3lh32krkmty2c', NOW(), FALSE),
#     ('did:plc:pcfc6i2bqugcwxmugauap5gd', 'particledogs.bsky.social', 'at://did:plc:ktkc7jfakxzjpooj52ffc6ra/app.bsky.graph.follow/3lh32kr633c26', NOW(), FALSE),
#     ('did:plc:crlitsp74mxiz2fik4ccpvq3', 'onwit.bsky.social', 'at://did:plc:ktkc7jfakxzjpooj52ffc6ra/app.bsky.graph.follow/3lh32kpuqmr2m', NOW(), FALSE),
#     ('did:plc:mt6kvnfozuqdzyhdejsyujkz', 'twistyn0odle.bsky.social', 'at://did:plc:ktkc7jfakxzjpooj52ffc6ra/app.bsky.graph.follow/3lh32kpgggs2d', NOW(), FALSE),
#     ('did:plc:d5vcfslnbof6iscg6bkioloa', 'puddleofbrain.bsky.social', 'at://did:plc:ktkc7jfakxzjpooj52ffc6ra/app.bsky.graph.follow/3lh32kovl6a2c', NOW(), FALSE),
#     ('did:plc:wxitx26q3udrbotfvh24zqln', 'spamps.bsky.social', 'at://did:plc:ktkc7jfakxzjpooj52ffc6ra/app.bsky.graph.follow/3lh32kofjin2l', NOW(), FALSE),
#     ('did:plc:ys2jt5dl6j2wkpvlo52vzeva', 'latho17.bsky.social', 'at://did:plc:ktkc7jfakxzjpooj52ffc6ra/app.bsky.graph.follow/3lh32kmzkut23', NOW(), FALSE),
#     ('did:plc:o55ucbt7nx6lasu24nxs6iac', 'aniceburrito.bsky.social', 'at://did:plc:ktkc7jfakxzjpooj52ffc6ra/app.bsky.graph.follow/3lh32kmjar42h', NOW(), FALSE),
#     ('did:plc:vwqgae4dt2enixnvdrn7csi5', 'laurdog.bsky.social', 'at://did:plc:ktkc7jfakxzjpooj52ffc6ra/app.bsky.graph.follow/3lh32km3jdi2c', NOW(), FALSE),
#     ('did:plc:mo2mkccfufliwu2dwbbnp7lt', 'glopdemon.bsky.social', 'at://did:plc:ktkc7jfakxzjpooj52ffc6ra/app.bsky.graph.follow/3lh32klkoi22d', NOW(), FALSE),
#     ('did:plc:gydoax5gf5bspailorp5okhv', 'ericaevans.bsky.social', 'at://did:plc:ktkc7jfakxzjpooj52ffc6ra/app.bsky.graph.follow/3lh32kl4l3y2c', NOW(), FALSE),
#     ('did:plc:tpa35hvgf5gufs7s5hyfkgda', 'greased7.bsky.social', 'at://did:plc:ktkc7jfakxzjpooj52ffc6ra/app.bsky.graph.follow/3lh32kjw2oi2c', NOW(), FALSE),
#     ('did:plc:ebg25rue2p3lwzsoxrnoymxs', '2x2l.bsky.social', 'at://did:plc:ktkc7jfakxzjpooj52ffc6ra/app.bsky.graph.follow/3lh32kjgvgd2c', NOW(), FALSE),
#     ('did:plc:dw7kiekqdqzi3jctopd26os4', 'ajoff.bsky.social', 'at://did:plc:ktkc7jfakxzjpooj52ffc6ra/app.bsky.graph.follow/3lh32kivsuz2p', NOW(), FALSE),
#     ('did:plc:agrfaaiqi3g3icmwkv2uqiag', 'wagyuhotdog.bsky.social', 'at://did:plc:ktkc7jfakxzjpooj52ffc6ra/app.bsky.graph.follow/3lh32khkwi32c', NOW(), FALSE),
#     ('did:plc:5wx2xqojlf5zp5gbru7rzvgy', 'goththot.bsky.social', 'at://did:plc:ktkc7jfakxzjpooj52ffc6ra/app.bsky.graph.follow/3lh32kgvcly2o', NOW(), FALSE),
#     ('did:plc:2n5cra5hdtqjedvgsyhpzaup', 'jeremycollier.bsky.social', 'at://did:plc:ktkc7jfakxzjpooj52ffc6ra/app.bsky.graph.follow/3lh32kgcpbi2c', NOW(), FALSE),
#     ('did:plc:24vulh4rnnqzznduz55lqgpl', 'bug-deal.bsky.social', 'at://did:plc:ktkc7jfakxzjpooj52ffc6ra/app.bsky.graph.follow/3lh32kfrsav2l', NOW(), FALSE),
#     ('did:plc:3p5h2o6ubo5tgyl7cqdpyly5', 'oldmarley.bsky.social', 'at://did:plc:ktkc7jfakxzjpooj52ffc6ra/app.bsky.graph.follow/3lh32kejrya2c', NOW(), FALSE),
#     ('did:plc:63eat45qktzydi6tjx63ehj2', 'goddamvirginian.bsky.social', 'at://did:plc:ktkc7jfakxzjpooj52ffc6ra/app.bsky.graph.follow/3lh32kdzvhb2f', NOW(), FALSE),
#     ('did:plc:6yimq5uopkweoskivr43e5tb', 'ayeeye-mindfuque.bsky.social', 'at://did:plc:ktkc7jfakxzjpooj52ffc6ra/app.bsky.graph.follow/3lh32kdm6wc2d', NOW(), FALSE),
#     ('did:plc:7lvrj5e2dnmize4qd7muxoxd', 'smk24.bsky.social', 'at://did:plc:ktkc7jfakxzjpooj52ffc6ra/app.bsky.graph.follow/3lh32kd5udl23', NOW(), FALSE),
#     ('did:plc:pn6fjka577iku2owyt2l4omk', 'mick-rock.bsky.social', 'at://did:plc:ktkc7jfakxzjpooj52ffc6ra/app.bsky.graph.follow/3lh32kazqzf2l', NOW(), FALSE),
#     ('did:plc:xmckl6ma6jz3i3i2oz4byizc', 'jennie50000.bsky.social', 'at://did:plc:ktkc7jfakxzjpooj52ffc6ra/app.bsky.graph.follow/3lh32kaloro2a', NOW(), FALSE),
#     ('did:plc:xqjosddlnivxow3ekdibkbu3', 'oldredpanda.bsky.social', 'at://did:plc:ktkc7jfakxzjpooj52ffc6ra/app.bsky.graph.follow/3lh32ka3x4s2d', NOW(), TRUE),
#     ('did:plc:etxej3ogvh36sx6mi5quw7g4', 'clownbaby.bsky.social', 'at://did:plc:ktkc7jfakxzjpooj52ffc6ra/app.bsky.graph.follow/3lh32k652os22', NOW(), FALSE),
#     ('did:plc:zfdcq3kfaq3ghghd7juhhuvp', 'bat8rac.bsky.social', 'at://did:plc:ktkc7jfakxzjpooj52ffc6ra/app.bsky.graph.follow/3lh32k5rq6j2f', NOW(), FALSE),
#     ('did:plc:no55rqysapbnvxsizhgbvvzw', 'jerolyn.bsky.social', 'at://did:plc:ktkc7jfakxzjpooj52ffc6ra/app.bsky.graph.follow/3lh32k5fs3e2l', NOW(), FALSE),
#     ('did:plc:62mo4nm7sramq4wfiw3x5xk7', 'decornery.bsky.social', 'at://did:plc:ktkc7jfakxzjpooj52ffc6ra/app.bsky.graph.follow/3lh32k4a72l2c', NOW(), FALSE),
#     ('did:plc:x4x6srl6w6tk2mtuxnwxhsuv', 'marvmarvmary.bsky.social', 'at://did:plc:ktkc7jfakxzjpooj52ffc6ra/app.bsky.graph.follow/3lh32k3skgm2l', NOW(), FALSE),
#     ('did:plc:knwifumqakbhy3r2eshoyvaq', 'bigjunco.bsky.social', 'at://did:plc:ktkc7jfakxzjpooj52ffc6ra/app.bsky.graph.follow/3lh32k2f2ey2c', NOW(), FALSE),
#     ('did:plc:4rf34f26cp3yvzoamsxgotte', 'pantslesshero.bsky.social', 'at://did:plc:ktkc7jfakxzjpooj52ffc6ra/app.bsky.graph.follow/3lh32jztu5j2x', NOW(), FALSE),
#     ('did:plc:e7bynn2teh5w5ekt3rnbvtye', 'arronator.bsky.social', 'at://did:plc:ktkc7jfakxzjpooj52ffc6ra/app.bsky.graph.follow/3lh32jz6spu2h', NOW(), FALSE),
#     ('did:plc:pjygcxhjptmvgrcwvh3beftf', 'portdrift.bsky.social', 'at://did:plc:ktkc7jfakxzjpooj52ffc6ra/app.bsky.graph.follow/3lh32jprgct2c', NOW(), FALSE),
#     ('did:plc:adnvlimftdlmitz2n7aaha2p', 'barredspiral.bsky.social', 'at://did:plc:ktkc7jfakxzjpooj52ffc6ra/app.bsky.graph.follow/3lh32jpby2e2h', NOW(), FALSE),
#     ('did:plc:55gik2ksxydzavkiuhudzro5', 'charlie44107.bsky.social', 'at://did:plc:ktkc7jfakxzjpooj52ffc6ra/app.bsky.graph.follow/3lh32jokuh323', NOW(), FALSE),
#     ('did:plc:eaq4ycj4noeevby7wqli7hr4', 'coachyelich.bsky.social', 'at://did:plc:ktkc7jfakxzjpooj52ffc6ra/app.bsky.graph.follow/3lh32jo45ds2d', NOW(), FALSE),
#     ('did:plc:5m4dnmdabc3hypaj57gbbovj', 'macguyver23.bsky.social', 'at://did:plc:ktkc7jfakxzjpooj52ffc6ra/app.bsky.graph.follow/3lh32jmspl323', NOW(), FALSE),
#     ('did:plc:froql56j34p7n4klgy2x4mtf', 'aragonk.bsky.social', 'at://did:plc:ktkc7jfakxzjpooj52ffc6ra/app.bsky.graph.follow/3lh32jmcaly2c', NOW(), FALSE),
#     ('did:plc:fwiuqleurfw4b3gt5l7rubcj', 'ryanhill-sandoval.bsky.social', 'at://did:plc:ktkc7jfakxzjpooj52ffc6ra/app.bsky.graph.follow/3lh32jlu2iq2c', NOW(), FALSE),
#     ('did:plc:bjizeqzm6millr3tfyn55owt', 'inga0606.bsky.social', 'at://did:plc:ktkc7jfakxzjpooj52ffc6ra/app.bsky.graph.follow/3lh32jlkdvo2a', NOW(), FALSE),
#     ('did:plc:h7xhhvlynrzyog3m2h4ranaj', 'farmdizzle.bsky.social', 'at://did:plc:ktkc7jfakxzjpooj52ffc6ra/app.bsky.graph.follow/3lh32jkzghk22', NOW(), FALSE),
#     ('did:plc:whssaxwlkxdmam7opxv3mdj3', 'wordsquirrel.bsky.social', 'at://did:plc:ktkc7jfakxzjpooj52ffc6ra/app.bsky.graph.follow/3lh32jiyf5z2f', NOW(), FALSE),
#     ('did:plc:usdj5vrkhyff4eifu5u3uj5s', 'zalecat.bsky.social', 'at://did:plc:ktkc7jfakxzjpooj52ffc6ra/app.bsky.graph.follow/3lh32jijhl22d', NOW(), FALSE),
#     ('did:plc:tmx2ts22ouglxty2choeckrf', 'funeralpig.bsky.social', 'at://did:plc:ktkc7jfakxzjpooj52ffc6ra/app.bsky.graph.follow/3lh32jhx4tj2m', NOW(), FALSE),
#     ('did:plc:b4wruqutpbnsio3bghq2tv4q', 'jfs60.bsky.social', 'at://did:plc:ktkc7jfakxzjpooj52ffc6ra/app.bsky.graph.follow/3lh32jhjq6b2p', NOW(), FALSE),
#     ('did:plc:5fycyjpjv2azgp3yuosxiikp', 'maylai.bsky.social', 'at://did:plc:ktkc7jfakxzjpooj52ffc6ra/app.bsky.graph.follow/3lh32jftksk22', NOW(), FALSE),
#     ('did:plc:4pgnxoh7oewpea4snw2r5ypv', 'sbrendag.bsky.social', 'at://did:plc:ktkc7jfakxzjpooj52ffc6ra/app.bsky.graph.follow/3lh32jfjhzo2a', NOW(), FALSE),
#     ('did:plc:kfv2yxeeauarzeeks5nq4kw5', 'tlewie.bsky.social', 'at://did:plc:ktkc7jfakxzjpooj52ffc6ra/app.bsky.graph.follow/3lh32jdl4xe2l', NOW(), FALSE),
#     ('did:plc:4bpnr3jjcw235244hglgrm2g', 'choclvr.bsky.social', 'at://did:plc:ktkc7jfakxzjpooj52ffc6ra/app.bsky.graph.follow/3lh32jd56bc26', NOW(), FALSE),
#     ('did:plc:kvh4xdbpbvwjcbquzyphbc7h', 'avadasya.bsky.social', 'at://did:plc:ktkc7jfakxzjpooj52ffc6ra/app.bsky.graph.follow/3lh32jbweld2c', NOW(), FALSE),
#     ('did:plc:waexhpgcg4qzev4drfafd7uk', 'shrewtape.bsky.social', 'at://did:plc:ktkc7jfakxzjpooj52ffc6ra/app.bsky.graph.follow/3lh32jbjayj2p', NOW(), FALSE),
#     ('did:plc:sreos5uohxsnsv6g4rawwdh7', 'kathryncamille.bsky.social', 'at://did:plc:ktkc7jfakxzjpooj52ffc6ra/app.bsky.graph.follow/3lh32jb2rmo2a', NOW(), FALSE),
#     ('did:plc:d4ubfuuaf5crhg356dvtuc4x', 'galfridus.bsky.social', 'at://did:plc:ktkc7jfakxzjpooj52ffc6ra/app.bsky.graph.follow/3lh32jakfjb2f', NOW(), FALSE),
#     ('did:plc:gymkumpcgbtgvvh622qphpxg', 'heathercakes.bsky.social', 'at://did:plc:ktkc7jfakxzjpooj52ffc6ra/app.bsky.graph.follow/3lh32j3pxsg2a', NOW(), FALSE),
#     ('did:plc:lhu6wz7d4ruw6k4ptidbfp7i', 'crannyboy.bsky.social', 'at://did:plc:ktkc7jfakxzjpooj52ffc6ra/app.bsky.graph.follow/3lh32j3addk22', NOW(), FALSE),
#     ('did:plc:t4t5fcsp3ukql4fs7c3zimlg', 'nnnimrodel.bsky.social', 'at://did:plc:ktkc7jfakxzjpooj52ffc6ra/app.bsky.graph.follow/3lh32j2jrqi2x', NOW(), FALSE),
#     ('did:plc:msgsr5xilsyc626sloopsptq', 'cheekymonkeyh.bsky.social', 'at://did:plc:ktkc7jfakxzjpooj52ffc6ra/app.bsky.graph.follow/3lh32iywjka2c', NOW(), FALSE),
#     ('did:plc:gkfm6qxqarogah3bahgqw7es', 'natxplays.bsky.social', 'at://did:plc:ktkc7jfakxzjpooj52ffc6ra/app.bsky.graph.follow/3lh32iydgra2x', NOW(), FALSE),
#     ('did:plc:hhqvgc2vtfdaa7gsr5awfgib', 'koffruns.bsky.social', 'at://did:plc:ktkc7jfakxzjpooj52ffc6ra/app.bsky.graph.follow/3lh32iy3peu24', NOW(), FALSE),
#     ('did:plc:jkt7kws4fzuxdqxvysescbvi', 'sickandtired2.bsky.social', 'at://did:plc:ktkc7jfakxzjpooj52ffc6ra/app.bsky.graph.follow/3lh32iwk7gb2f', NOW(), FALSE),
#     ('did:plc:kxsl4cjvl5cyf2spu4tebywh', 'wildbirdcreative.bsky.social', 'at://did:plc:ktkc7jfakxzjpooj52ffc6ra/app.bsky.graph.follow/3lh32iw25p22d', NOW(), FALSE),
#     ('did:plc:nda3cp34tvjvshalqzdzitz4', 'fredbux.bsky.social', 'at://did:plc:ktkc7jfakxzjpooj52ffc6ra/app.bsky.graph.follow/3lh32ivfcwh2p', NOW(), FALSE),
#     ('did:plc:xwio3g6ms6bo6wapl7tn2mve', 'richardcuddy.bsky.social', 'at://did:plc:ktkc7jfakxzjpooj52ffc6ra/app.bsky.graph.follow/3lh32isxehd2c', NOW(), FALSE),
#     ('did:plc:qhdklf2jclke2fboszi72v2u', 'candlestick.bsky.social', 'at://did:plc:ktkc7jfakxzjpooj52ffc6ra/app.bsky.graph.follow/3lh32isk6x222', NOW(), FALSE),
#     ('did:plc:7onksm54ijfehk2lrzswuci3', 'vashtaa.bsky.social', 'at://did:plc:ktkc7jfakxzjpooj52ffc6ra/app.bsky.graph.follow/3lh32is2grs2d', NOW(), FALSE),
#     ('did:plc:xsqpy75xlp4qysfobxzqqz3t', 'monica-avila.bsky.social', 'at://did:plc:ktkc7jfakxzjpooj52ffc6ra/app.bsky.graph.follow/3lh32iqtyij2m', NOW(), FALSE),
#     ('did:plc:2mbyv7yb4apy5ux7ise24uip', 'pappa-p1984.bsky.social', 'at://did:plc:ktkc7jfakxzjpooj52ffc6ra/app.bsky.graph.follow/3lh32iqleo62a', NOW(), FALSE),
#     ('did:plc:khfzuw4cubjn7rclbanc4kqb', 'gateshawk.bsky.social', 'at://did:plc:ktkc7jfakxzjpooj52ffc6ra/app.bsky.graph.follow/3lh32iperqr2m', NOW(), FALSE),
#     ('did:plc:2rt7wwhny25626s6suer5cfr', 'xandranicholai.bsky.social', 'at://did:plc:ktkc7jfakxzjpooj52ffc6ra/app.bsky.graph.follow/3lh32iosith2p', NOW(), FALSE),
#     ('did:plc:mgfyztwkfe2bmxrvoedf7rgm', 'andylivs79.bsky.social', 'at://did:plc:ktkc7jfakxzjpooj52ffc6ra/app.bsky.graph.follow/3lh32inffkc22', NOW(), FALSE),
#     ('did:plc:hlzbjh5sdnwskctwlkc3tjqx', 'crispyonigiri.bsky.social', 'at://did:plc:ktkc7jfakxzjpooj52ffc6ra/app.bsky.graph.follow/3lh32imwzzu2h', NOW(), FALSE),
#     ('did:plc:ymaiureu5ho4osnyy6lvdv3c', 'ccdigital.bsky.social', 'at://did:plc:ktkc7jfakxzjpooj52ffc6ra/app.bsky.graph.follow/3lh32imjnh32c', NOW(), FALSE),
#     ('did:plc:yuizitjc2xz6zvayytm5souf', 'jaydenthefurry1.bsky.social', 'at://did:plc:ktkc7jfakxzjpooj52ffc6ra/app.bsky.graph.follow/3lh32iktnvt2c', NOW(), FALSE),
#     ('did:plc:dcma3jnnlenrpfh4frfou6so', 'morningview-ok.bsky.social', 'at://did:plc:ktkc7jfakxzjpooj52ffc6ra/app.bsky.graph.follow/3lh32ikdrxu2h', NOW(), FALSE),
#     ('did:plc:fvagb6cq2vwppywvhzffgz24', 'shoobahlab.bsky.social', 'at://did:plc:ktkc7jfakxzjpooj52ffc6ra/app.bsky.graph.follow/3lh32ijqsod2c', NOW(), FALSE),
#     ('did:plc:6u6lre45gs2pjhszclxgal7o', 'danschellauthor.bsky.social', 'at://did:plc:ktkc7jfakxzjpooj52ffc6ra/app.bsky.graph.follow/3lh32ii34se2l', NOW(), TRUE),
#     ('did:plc:stxceafbfewtgpb4wvkxrabg', 'teal29.bsky.social', 'at://did:plc:ktkc7jfakxzjpooj52ffc6ra/app.bsky.graph.follow/3lh32ihjsd22d', NOW(), FALSE),
#     ('did:plc:xl34k4otpyzzsiae6edpttie', 'openness.bsky.social', 'at://did:plc:ktkc7jfakxzjpooj52ffc6ra/app.bsky.graph.follow/3lh32igwtcd23', NOW(), FALSE),
#     ('did:plc:3bwbxjbptio2ikewuqpgiuyc', 'ellenpisa.bsky.social', 'at://did:plc:ktkc7jfakxzjpooj52ffc6ra/app.bsky.graph.follow/3lh32ifrs3u2h', NOW(), FALSE),
#     ('did:plc:g7l5fkzed23ya53dtyk76olt', 'byte-trash.bsky.social', 'at://did:plc:ktkc7jfakxzjpooj52ffc6ra/app.bsky.graph.follow/3lh32ifcff72p', NOW(), FALSE),
#     ('did:plc:a3kmijxehuzrlcey7e6buamo', 'vtkim.bsky.social', 'at://did:plc:ktkc7jfakxzjpooj52ffc6ra/app.bsky.graph.follow/3lh32idf7ki2o', NOW(), FALSE),
#     ('did:plc:hfeimqgl6662sxzhwcru3n7b', 'anime772.bsky.social', 'at://did:plc:ktkc7jfakxzjpooj52ffc6ra/app.bsky.graph.follow/3lh32icx4pg2a', NOW(), FALSE),
#     ('did:plc:4ebjxq25fhyfoe75qp6d4zjt', 'hailuvsingnie.bsky.social', 'at://did:plc:ktkc7jfakxzjpooj52ffc6ra/app.bsky.graph.follow/3lh32icblq72p', NOW(), FALSE),
#     ('did:plc:pwo5hominnhvfnourzr3seza', 'athensmusicjunkie.com', 'at://did:plc:ktkc7jfakxzjpooj52ffc6ra/app.bsky.graph.follow/3lh32iahmdk22', NOW(), FALSE),
#     ('did:plc:nwfttjfzwwagejye2lrmyvhy', 'lemonpepperpussy.bsky.social', 'at://did:plc:ktkc7jfakxzjpooj52ffc6ra/app.bsky.graph.follow/3lh32i7zyje24', NOW(), FALSE),
#     ('did:plc:ln2pj7r2bvf522pdd4fxzwip', 'bonedaddytattoo.bsky.social', 'at://did:plc:ktkc7jfakxzjpooj52ffc6ra/app.bsky.graph.follow/3lh32i6vkiu24', NOW(), FALSE),
#     ('did:plc:hdzx74sfpp7gobju6dd7gdbr', 'sandtats.bsky.social', 'at://did:plc:ktkc7jfakxzjpooj52ffc6ra/app.bsky.graph.follow/3lh32i6far42h', NOW(), FALSE),
#     ('did:plc:u4suhjxk3on4ykbyf4xktxca', 'quietbiscuit.bsky.social', 'at://did:plc:ktkc7jfakxzjpooj52ffc6ra/app.bsky.graph.follow/3lh32i53jwd2c', NOW(), FALSE),
#     ('did:plc:t42xiyh4acnarbl4dbdxb4w7', 'surprisepinata.bsky.social', 'at://did:plc:ktkc7jfakxzjpooj52ffc6ra/app.bsky.graph.follow/3lh32hzwd4i2x', NOW(), FALSE),
#     ('did:plc:krev3z3zn6cg7ujbqfywk6vw', 'psycat1017.bsky.social', 'at://did:plc:ktkc7jfakxzjpooj52ffc6ra/app.bsky.graph.follow/3lh32hyrxyc22', NOW(), FALSE),
#     ('did:plc:cmdh7oiehj4kyr2efbijfgex', 'djkirkbride.bsky.social', 'at://did:plc:ktkc7jfakxzjpooj52ffc6ra/app.bsky.graph.follow/3lh32hye7cr2f', NOW(), FALSE),
#     ('did:plc:jrgek2r4wz5abc74rddhuekm', 'dosbootleg.bsky.social', 'at://did:plc:ktkc7jfakxzjpooj52ffc6ra/app.bsky.graph.follow/3lh32hxciki2o', NOW(), FALSE),
#     ('did:plc:dbtcfdzyoc54jux6oaif3huv', 'margarita60.bsky.social', 'at://did:plc:ktkc7jfakxzjpooj52ffc6ra/app.bsky.graph.follow/3lh32hwubch2p', NOW(), FALSE),
#     ('did:plc:3iyxkarvjhywe3yn3nz5ndpt', 'ywbl.bsky.social', 'at://did:plc:ktkc7jfakxzjpooj52ffc6ra/app.bsky.graph.follow/3lh32hvkrd226', NOW(), FALSE),
#     ('did:plc:cuk75pp2gij5voz756bgtgvs', 'benchpressgang.bsky.social', 'at://did:plc:ktkc7jfakxzjpooj52ffc6ra/app.bsky.graph.follow/3lh32hv64pj2f', NOW(), FALSE),
#     ('did:plc:3thh3suw7cze564h4lc7aev7', 'katydid.bsky.social', 'at://did:plc:ktkc7jfakxzjpooj52ffc6ra/app.bsky.graph.follow/3lh32htvklu2l', NOW(), FALSE),
#     ('did:plc:yotrfjk3kl6qwx3soiw4epyg', 'fuzzyreapurrrr.bsky.social', 'at://did:plc:ktkc7jfakxzjpooj52ffc6ra/app.bsky.graph.follow/3lh32htjxm32c', NOW(), FALSE),
#     ('did:plc:rsmuvkfau4i2vx47krlru54i', 'pappyparki.bsky.social', 'at://did:plc:ktkc7jfakxzjpooj52ffc6ra/app.bsky.graph.follow/3lh32hs6xr424', NOW(), FALSE),
#     ('did:plc:d37hesjsyh7ecab2entmpqgr', 'northern-gal.bsky.social', 'at://did:plc:ktkc7jfakxzjpooj52ffc6ra/app.bsky.graph.follow/3lh32hrofnb2m', NOW(), FALSE),
#     ('did:plc:dlrllkq5mke4qjlaaq6sc5og', 'eireneis.bsky.social', 'at://did:plc:ktkc7jfakxzjpooj52ffc6ra/app.bsky.graph.follow/3lh32hqx43o2a', NOW(), FALSE),
#     ('did:plc:7xzvcgqkznmuy3uxtilg5gqh', 'beanaton.bsky.social', 'at://did:plc:ktkc7jfakxzjpooj52ffc6ra/app.bsky.graph.follow/3lh32hqjdom2h', NOW(), FALSE),
#     ('did:plc:rqqqtzyqdciabve3ari2pioq', 'shanzival.bsky.social', 'at://did:plc:ktkc7jfakxzjpooj52ffc6ra/app.bsky.graph.follow/3lh32hp7tle2l', NOW(), FALSE),
#     ('did:plc:6p6jimmoyz3n2ci2qc3wos2w', 'memphisbelle1114.bsky.social', 'at://did:plc:ktkc7jfakxzjpooj52ffc6ra/app.bsky.graph.follow/3lh32hona4e24', NOW(), FALSE),
#     ('did:plc:tulq5vhb3qej2ia2beomu6nk', 'forefinger.bsky.social', 'at://did:plc:ktkc7jfakxzjpooj52ffc6ra/app.bsky.graph.follow/3lh32hngsnj2f', NOW(), FALSE),
#     ('did:plc:bpiyitsdunbn3gc7fs5u7esp', 'jeanflarouche.bsky.social', 'at://did:plc:ktkc7jfakxzjpooj52ffc6ra/app.bsky.graph.follow/3lh32hmy6pl2c', NOW(), FALSE),
#     ('did:plc:6q3wjmvdauid4gtmo5fwz2jt', 'theangrytinman.bsky.social', 'at://did:plc:ktkc7jfakxzjpooj52ffc6ra/app.bsky.graph.follow/3lh32hmmj2k22', NOW(), FALSE),
#     ('did:plc:u5r4jzzylrkxi3f6xlatnqkh', 'jossyp88.bsky.social', 'at://did:plc:ktkc7jfakxzjpooj52ffc6ra/app.bsky.graph.follow/3lh32hldjhb2m', NOW(), FALSE),
#     ('did:plc:2wbj7mn6di75rz3xbssnlabx', 'bashfulbeepress.bsky.social', 'at://did:plc:ktkc7jfakxzjpooj52ffc6ra/app.bsky.graph.follow/3lh32hiwoj72p', NOW(), TRUE),
#     ('did:plc:thmtc4bogmvdobiadgfcktdr', 'miran67.bsky.social', 'at://did:plc:ktkc7jfakxzjpooj52ffc6ra/app.bsky.graph.follow/3lh32hii5hu24', NOW(), FALSE),
#     ('did:plc:7mwfcsj3a24muoem4h6cgigs', 'vtrxnh.bsky.social', 'at://did:plc:ktkc7jfakxzjpooj52ffc6ra/app.bsky.graph.follow/3lh32hhy2tz2f', NOW(), FALSE),
#     ('did:plc:hueq2xvl44kmyng5bbmnnnwm', 'wiselife.bsky.social', 'at://did:plc:ktkc7jfakxzjpooj52ffc6ra/app.bsky.graph.follow/3lh32hhhdnc2d', NOW(), FALSE),
#     ('did:plc:lahpi75dx2be4t4egulqmset', 'nrx.bsky.social', 'at://did:plc:ktkc7jfakxzjpooj52ffc6ra/app.bsky.graph.follow/3lh32hgzy4x2p', NOW(), FALSE),
#     ('did:plc:53t7afdsnclkf6zokyx7cfkn', 'relic1962.bsky.social', 'at://did:plc:ktkc7jfakxzjpooj52ffc6ra/app.bsky.graph.follow/3lh32hfrzts22', NOW(), FALSE),
#     ('did:plc:ohhro2cbftxqjr75vb7yf5f5', 'littlewitchkay.bsky.social', 'at://did:plc:ktkc7jfakxzjpooj52ffc6ra/app.bsky.graph.follow/3lh32hejsi22d', NOW(), FALSE),
#     ('did:plc:r3h3avd5bdvdxrlnm2zgpzpj', 'catscatscats6.bsky.social', 'at://did:plc:ktkc7jfakxzjpooj52ffc6ra/app.bsky.graph.follow/3lh32hdyxhr2f', NOW(), FALSE),
#     ('did:plc:itnqpzqc76rf6uhjixoteuiz', 'magicash.bsky.social', 'at://did:plc:ktkc7jfakxzjpooj52ffc6ra/app.bsky.graph.follow/3lh32h6m2432c', NOW(), FALSE),
#     ('did:plc:5qr4uhaajqrynyseyuvavyv7', 'cell007.bsky.social', 'at://did:plc:ktkc7jfakxzjpooj52ffc6ra/app.bsky.graph.follow/3lh32h5ya662a', NOW(), FALSE),
#     ('did:plc:v5hbekbuw7zv5hrr6i4xezx4', 'rae14.bsky.social', 'at://did:plc:ktkc7jfakxzjpooj52ffc6ra/app.bsky.graph.follow/3lh32h5dijz2m', NOW(), FALSE),
#     ('did:plc:pyyxmahptto7hwefzkmvonwz', 'honey-bubbles.bsky.social', 'at://did:plc:ktkc7jfakxzjpooj52ffc6ra/app.bsky.graph.follow/3lh32h3d5rc2d', NOW(), FALSE),
#     ('did:plc:awof3r6iql6epmf2yceww7g2', 'storiesbooksandtea.bsky.social', 'at://did:plc:ktkc7jfakxzjpooj52ffc6ra/app.bsky.graph.follow/3lh32h2sxy42l', NOW(), FALSE),
#     ('did:plc:bqgoawzwm6wqr55kxeyr4r7c', 'riverotter.bsky.social', 'at://did:plc:ktkc7jfakxzjpooj52ffc6ra/app.bsky.graph.follow/3lh32h2bine24', NOW(), FALSE),
#     ('did:plc:ixumxjgzwpvvlwhxvzanckye', 'nondigital-james.bsky.social', 'at://did:plc:ktkc7jfakxzjpooj52ffc6ra/app.bsky.graph.follow/3lh32gyu3va2o', NOW(), FALSE),
#     ('did:plc:6azxj2umjumomvoirjk5us3y', 'rosycb.bsky.social', 'at://did:plc:ktkc7jfakxzjpooj52ffc6ra/app.bsky.graph.follow/3lh32gyfun72p', NOW(), FALSE),
#     ('did:plc:4ihdrryvihs7uyuvqbov7tlt', 'jamesgameboy.bsky.social', 'at://did:plc:ktkc7jfakxzjpooj52ffc6ra/app.bsky.graph.follow/3lh32gxygqu24', NOW(), FALSE),
#     ('did:plc:oos6hk7a4xugfayzjas7h3bx', 'feralhousewifelife.bsky.social', 'at://did:plc:ktkc7jfakxzjpooj52ffc6ra/app.bsky.graph.follow/3lh32gx63et23', NOW(), FALSE),
#     ('did:plc:jevz5ocbpxfa3cthex56uaca', 'piikotheartist.bsky.social', 'at://did:plc:ktkc7jfakxzjpooj52ffc6ra/app.bsky.graph.follow/3lh32gvvend23', NOW(), FALSE),
#     ('did:plc:bjnsu47uqi56pwacvtzze6c4', 'linduh83.bsky.social', 'at://did:plc:ktkc7jfakxzjpooj52ffc6ra/app.bsky.graph.follow/3lh32guqc2q2x', NOW(), FALSE),
#     ('did:plc:gvmzqkwjb5hpxa2wx2632tg7', 'lbattis.bsky.social', 'at://did:plc:ktkc7jfakxzjpooj52ffc6ra/app.bsky.graph.follow/3lh32gudmdl2c', NOW(), FALSE),
#     ('did:plc:dlspnhez2nexpcimz43cofu6', 'sunshinespud.bsky.social', 'at://did:plc:ktkc7jfakxzjpooj52ffc6ra/app.bsky.graph.follow/3lh32glciag2a', NOW(), FALSE),
#     ('did:plc:mpo5zwscm2zqg5z7jwd7j7t6', 'washingtonkrystal.bsky.social', 'at://did:plc:ktkc7jfakxzjpooj52ffc6ra/app.bsky.graph.follow/3lh32gku2em2l', NOW(), FALSE),
#     ('did:plc:qhdmwy34tftqvgatlpvda3zo', 'omnipresentponi.bsky.social', 'at://did:plc:ktkc7jfakxzjpooj52ffc6ra/app.bsky.graph.follow/3lh32gkhifz2m', NOW(), FALSE),
#     ('did:plc:znkuvgrxj2lvnr2q354aetw5', 'hearthkeeper.bsky.social', 'at://did:plc:ktkc7jfakxzjpooj52ffc6ra/app.bsky.graph.follow/3lh32gh7yhg2a', NOW(), FALSE),
#     ('did:plc:5ouqtm454lluk7gaf26avk44', 'philloz3000.bsky.social', 'at://did:plc:ktkc7jfakxzjpooj52ffc6ra/app.bsky.graph.follow/3lh32ggrrzt23', NOW(), FALSE),
#     ('did:plc:n6qzgqs23joyeopz5dqlttfq', 'taz329.bsky.social', 'at://did:plc:ktkc7jfakxzjpooj52ffc6ra/app.bsky.graph.follow/3lh32gfgsge2l', NOW(), FALSE),
#     ('did:plc:5na4ryrn6m32hvc6sryfnchd', 'plant-based99.bsky.social', 'at://did:plc:ktkc7jfakxzjpooj52ffc6ra/app.bsky.graph.follow/3lh32gexoy62a', NOW(), FALSE),
#     ('did:plc:eyv2siqybjuyqgw6p3jfz555', 'azdeathdoula.bsky.social', 'at://did:plc:ktkc7jfakxzjpooj52ffc6ra/app.bsky.graph.follow/3lh32g4ok2r2m', NOW(), FALSE),
#     ('did:plc:3aau6lxz5robmbwvj76tnx4k', 'penguina8.bsky.social', 'at://did:plc:ktkc7jfakxzjpooj52ffc6ra/app.bsky.graph.follow/3lh32g4byb62a', NOW(), FALSE),
#     ('did:plc:tia46o6urglgojgae4sfvihv', 'bigpapachunk.bsky.social', 'at://did:plc:ktkc7jfakxzjpooj52ffc6ra/app.bsky.graph.follow/3lh32g3niks22', NOW(), FALSE),
#     ('did:plc:sbqbm25f7lfae56by4vx3dt2', 'buntari.bsky.social', 'at://did:plc:ktkc7jfakxzjpooj52ffc6ra/app.bsky.graph.follow/3lh32g2q7wb2m', NOW(), FALSE),
#     ('did:plc:flufufsfbu2sc7qipf27jka5', 'genirae.bsky.social', 'at://did:plc:ktkc7jfakxzjpooj52ffc6ra/app.bsky.graph.follow/3lh32fyzru222', NOW(), FALSE),
#     ('did:plc:tfpssovy4db6fmvschveeyzb', 'snakeroot.bsky.social', 'at://did:plc:ktkc7jfakxzjpooj52ffc6ra/app.bsky.graph.follow/3lh32fyiuvs26', NOW(), FALSE),
#     ('did:plc:xdjq3n5zvkbiv7nbms3ail54', 'childlesscat82.bsky.social', 'at://did:plc:ktkc7jfakxzjpooj52ffc6ra/app.bsky.graph.follow/3lh32fxyhw42l', NOW(), FALSE),
#     ('did:plc:2qhovphbzldcbyfintuqhb6k', 'zenarch42.bsky.social', 'at://did:plc:ktkc7jfakxzjpooj52ffc6ra/app.bsky.graph.follow/3lh32fxfc4s22', NOW(), FALSE),
#     ('did:plc:vgiqmzlzrdkq6aww2lu7sgze', 'nhfarmgirl.bsky.social', 'at://did:plc:ktkc7jfakxzjpooj52ffc6ra/app.bsky.graph.follow/3lh32fwrfuo2a', NOW(), FALSE),
#     ('did:plc:lssa4w3afvuired5j46rkd7q', 'smcd67.bsky.social', 'at://did:plc:ktkc7jfakxzjpooj52ffc6ra/app.bsky.graph.follow/3lh32fwcg2i2o', NOW(), FALSE),
#     ('did:plc:4zz2egpdvnotukmmjhphpwg2', 'crisgoode.bsky.social', 'at://did:plc:ktkc7jfakxzjpooj52ffc6ra/app.bsky.graph.follow/3lh32fumq7y2x', NOW(), FALSE),
#     ('did:plc:uehkbim4czpjt4jmn4btc7rn', 'dvlnside24.bsky.social', 'at://did:plc:ktkc7jfakxzjpooj52ffc6ra/app.bsky.graph.follow/3lh32fu5qgz2f', NOW(), FALSE),
#     ('did:plc:pfwuzqne4zotuy2yep6pbido', 'willyhampter.bsky.social', 'at://did:plc:ktkc7jfakxzjpooj52ffc6ra/app.bsky.graph.follow/3lh32ftqxy42l', NOW(), FALSE),
#     ('did:plc:5eqipks4jm2d6j2derkc5rxp', 'helenmaria10.bsky.social', 'at://did:plc:ktkc7jfakxzjpooj52ffc6ra/app.bsky.graph.follow/3lh32fs3e5y2c', NOW(), FALSE),
#     ('did:plc:mmmipsjjx6p5vnwtyrspfugz', 'melitoast.bsky.social', 'at://did:plc:ktkc7jfakxzjpooj52ffc6ra/app.bsky.graph.follow/3lh32frlvlq2x', NOW(), FALSE),
#     ('did:plc:k4nutws6zunjiixelp4hfemk', 'benvoliobird.bsky.social', 'at://did:plc:ktkc7jfakxzjpooj52ffc6ra/app.bsky.graph.follow/3lh32fr3ivb2f', NOW(), FALSE),
#     ('did:plc:e5w4lzvblaykjfvzjwvzct2y', 'mindspositiviti.bsky.social', 'at://did:plc:ktkc7jfakxzjpooj52ffc6ra/app.bsky.graph.follow/3lh32fqlxnt2c', NOW(), FALSE),
#     ('did:plc:kx3yaaqnsitgmndkzlwuekc4', 'the-nameless-one.bsky.social', 'at://did:plc:ktkc7jfakxzjpooj52ffc6ra/app.bsky.graph.follow/3lh32fq5cfs26', NOW(), FALSE),
#     ('did:plc:qowkqmwpidwrufoxth2icveq', 'taffy512.bsky.social', 'at://did:plc:ktkc7jfakxzjpooj52ffc6ra/app.bsky.graph.follow/3lh32fotb3a2h', NOW(), FALSE),
#     ('did:plc:bqb4s4fhac27epwqikwwuyei', 'drmercedes.bsky.social', 'at://did:plc:ktkc7jfakxzjpooj52ffc6ra/app.bsky.graph.follow/3lh32foglfq2x', NOW(), FALSE),
#     ('did:plc:e26ux6dipzhiwglalbraaarw', 'pot-pie.bsky.social', 'at://did:plc:ktkc7jfakxzjpooj52ffc6ra/app.bsky.graph.follow/3lh32fnz6mc22', NOW(), FALSE),
#     ('did:plc:t4isymjij62qryzxdqdlnc76', 'gmaconda.bsky.social', 'at://did:plc:ktkc7jfakxzjpooj52ffc6ra/app.bsky.graph.follow/3lh32fnletl2c', NOW(), FALSE),
#     ('did:plc:iro7hayoa3cjlvrszx2xflxb', 'andimkennedy.bsky.social', 'at://did:plc:ktkc7jfakxzjpooj52ffc6ra/app.bsky.graph.follow/3lh32flzfpc26', NOW(), FALSE),
#     ('did:plc:xga44y543owikxt26oke5zrn', 'almafever.bsky.social', 'at://did:plc:ktkc7jfakxzjpooj52ffc6ra/app.bsky.graph.follow/3lh32flngg32c', NOW(), FALSE),
#     ('did:plc:mncfedmx2l5mrl32wscxysh7', 'denjiikat73.bsky.social', 'at://did:plc:ktkc7jfakxzjpooj52ffc6ra/app.bsky.graph.follow/3lh32fkvhst2c', NOW(), TRUE),
#     ('did:plc:dvmqpaw6qrrtmdi3evyvzbuc', 'tstld.bsky.social', 'at://did:plc:ktkc7jfakxzjpooj52ffc6ra/app.bsky.graph.follow/3lh32fkh2es26', NOW(), FALSE),
#     ('did:plc:xr5mkvjeid33xvq53cu6rvob', 'grandmaonion.bsky.social', 'at://did:plc:ktkc7jfakxzjpooj52ffc6ra/app.bsky.graph.follow/3lh32fgua7e24', NOW(), FALSE),
#     ('did:plc:lcmpv4giefef3rkkc3kvvzy7', 'carolinacalling.bsky.social', 'at://did:plc:ktkc7jfakxzjpooj52ffc6ra/app.bsky.graph.follow/3lh32fgeocr2m', NOW(), FALSE),
#     ('did:plc:23jwyzoe6m4ot7p7gwe7kqyf', 'annesmien.bsky.social', 'at://did:plc:ktkc7jfakxzjpooj52ffc6ra/app.bsky.graph.follow/3lh32ff2chi2c', NOW(), FALSE),
#     ('did:plc:gyzxmbggrdq5kg6pgdrkazup', 'nlhyatt.bsky.social', 'at://did:plc:ktkc7jfakxzjpooj52ffc6ra/app.bsky.graph.follow/3lh32feon2323', NOW(), FALSE),
#     ('did:plc:ximuiypn436gmrtlihrrbypb', 'majoval.bsky.social', 'at://did:plc:ktkc7jfakxzjpooj52ffc6ra/app.bsky.graph.follow/3lh32fe77rk22', NOW(), FALSE),
#     ('did:plc:2rch3alrdspicfv53rib255o', 'escapefromflatland.bsky.social', 'at://did:plc:ktkc7jfakxzjpooj52ffc6ra/app.bsky.graph.follow/3lh32fcxjpi2h', NOW(), FALSE),
#     ('did:plc:r4bfhyrdtfr3t5vhjvmkfpjy', 'skweekie747.bsky.social', 'at://did:plc:ktkc7jfakxzjpooj52ffc6ra/app.bsky.graph.follow/3lh32fch7et2c', NOW(), FALSE),
#     ('did:plc:guhlbusbnn2zcdl6uzsqn53t', 'baybayfriend.bsky.social', 'at://did:plc:ktkc7jfakxzjpooj52ffc6ra/app.bsky.graph.follow/3lh32fbymqj2f', NOW(), FALSE),
#     ('did:plc:3ji47cfbh2xlzgm3jpt4bry5', 'reefgirl.bsky.social', 'at://did:plc:ktkc7jfakxzjpooj52ffc6ra/app.bsky.graph.follow/3lh32fbmvvx2p', NOW(), FALSE),
#     ('did:plc:5i523s7a2g7dgvhvorhrpkxg', 'jeffreytayler.bsky.social', 'at://did:plc:ktkc7jfakxzjpooj52ffc6ra/app.bsky.graph.follow/3lh32fa4exc2d', NOW(), FALSE),
#     ('did:plc:fqaj36oncjrukd4op22hrqmc', 'horanin.bsky.social', 'at://did:plc:ktkc7jfakxzjpooj52ffc6ra/app.bsky.graph.follow/3lh32f7qb5l2c', NOW(), FALSE),
#     ('did:plc:wq66imfu57aigytmkhwrmrjt', 'katielbc.bsky.social', 'at://did:plc:ktkc7jfakxzjpooj52ffc6ra/app.bsky.graph.follow/3lh32f7gjr424', NOW(), FALSE),
#     ('did:plc:6ncvkh6mjtifbd776zew4tk2', 'ramunet.bsky.social', 'at://did:plc:ktkc7jfakxzjpooj52ffc6ra/app.bsky.graph.follow/3lh32f5w74k22', NOW(), FALSE),
#     ('did:plc:nhtzmhgy6c4bfsymx7mb7so5', 'octobersober.bsky.social', 'at://did:plc:ktkc7jfakxzjpooj52ffc6ra/app.bsky.graph.follow/3lh32f5faby2o', NOW(), FALSE),
#     ('did:plc:474u4xt2cdyjkxgvg47wslje', 'patate4.bsky.social', 'at://did:plc:ktkc7jfakxzjpooj52ffc6ra/app.bsky.graph.follow/3lh32f4ufkg2a', NOW(), FALSE),
#     ('did:plc:tigwupoh5oczpp5rmwyu4smt', 'farawayeyes67.bsky.social', 'at://did:plc:ktkc7jfakxzjpooj52ffc6ra/app.bsky.graph.follow/3lh32f3l5ob2m', NOW(), FALSE),
#     ('did:plc:3dscdtm3wjigo7utcyfnqtie', 'jirohwein.bsky.social', 'at://did:plc:ktkc7jfakxzjpooj52ffc6ra/app.bsky.graph.follow/3lh32f34n2a2o', NOW(), FALSE),
#     ('did:plc:ofbkkezsleua2juj45gdisz5', 'magabuster.bsky.social', 'at://did:plc:ktkc7jfakxzjpooj52ffc6ra/app.bsky.graph.follow/3lh32f2tnuy2x', NOW(), FALSE),
#     ('did:plc:n7bh5kf6n2ldd4e37eee5yvu', 'pepsi5959563.bsky.social', 'at://did:plc:ktkc7jfakxzjpooj52ffc6ra/app.bsky.graph.follow/3lh32eyftm222', NOW(), FALSE),
#     ('did:plc:mt2whtc5mjxsgxsxlhc2tgtz', 'msredtail.bsky.social', 'at://did:plc:ktkc7jfakxzjpooj52ffc6ra/app.bsky.graph.follow/3lh32exx7tc22', NOW(), FALSE),
#     ('did:plc:fpgx5sc6wh2gzfy65e6mrs5d', 'ifritablackcat.bsky.social', 'at://did:plc:ktkc7jfakxzjpooj52ffc6ra/app.bsky.graph.follow/3lh32exdhyk22', NOW(), FALSE),
#     ('did:plc:4nnyyukkw7yype2573wub7pd', 'donlikesit.bsky.social', 'at://did:plc:ktkc7jfakxzjpooj52ffc6ra/app.bsky.graph.follow/3lh32evzwdo2a', NOW(), TRUE),
#     ('did:plc:vbb3fqltvbyqqayqk75ie2pz', 'george-at-work.bsky.social', 'at://did:plc:ktkc7jfakxzjpooj52ffc6ra/app.bsky.graph.follow/3lh32evihbs22', NOW(), FALSE),
#     ('did:plc:yxwcbwyaox6gizl3vvzqgmeu', 'shadowzzk.bsky.social', 'at://did:plc:ktkc7jfakxzjpooj52ffc6ra/app.bsky.graph.follow/3lh32ev4j3d2c', NOW(), FALSE),
#     ('did:plc:uoefotk4efete6z6726bytjt', 'mixerlieber.bsky.social', 'at://did:plc:ktkc7jfakxzjpooj52ffc6ra/app.bsky.graph.follow/3lh32es3rbm2l', NOW(), FALSE),
#     ('did:plc:ivr67auopxsmaxbqrnvos4fj', 'robertveres.bsky.social', 'at://did:plc:ktkc7jfakxzjpooj52ffc6ra/app.bsky.graph.follow/3lh32erldua2h', NOW(), FALSE),
#     ('did:plc:b2t7xjivgxv4ejjbzgi5llqx', 'catmahm.bsky.social', 'at://did:plc:ktkc7jfakxzjpooj52ffc6ra/app.bsky.graph.follow/3lh32er6etu2l', NOW(), FALSE),
#     ('did:plc:v56pr2gxsrlrhaxkm3tx4kzt', 'tastre74.bsky.social', 'at://did:plc:ktkc7jfakxzjpooj52ffc6ra/app.bsky.graph.follow/3lh32eqrhfd23', NOW(), FALSE),
#     ('did:plc:o3yawawj3y2tmwnconlk5zv3', 'spitfire129.bsky.social', 'at://did:plc:ktkc7jfakxzjpooj52ffc6ra/app.bsky.graph.follow/3lh32epaoss26', NOW(), TRUE),
#     ('did:plc:q6ih6y7qk2ekywaotw5qzyzf', 'tcstigernation.bsky.social', 'at://did:plc:ktkc7jfakxzjpooj52ffc6ra/app.bsky.graph.follow/3lh32eosypi2h', NOW(), FALSE),
#     ('did:plc:t2dv5gg3p5ufumoa3jdhhpme', 'avoidavoidavoid.bsky.social', 'at://did:plc:ktkc7jfakxzjpooj52ffc6ra/app.bsky.graph.follow/3lh32eob6gh2c', NOW(), FALSE),
#     ('did:plc:h6eiy27hitmsq4mclzuzv5bw', 'chutson99.bsky.social', 'at://did:plc:ktkc7jfakxzjpooj52ffc6ra/app.bsky.graph.follow/3lh32enpm5u24', NOW(), FALSE),
#     ('did:plc:k2qvkfou3p4mjup5yt35sle4', 'wiseposter.bsky.social', 'at://did:plc:ktkc7jfakxzjpooj52ffc6ra/app.bsky.graph.follow/3lh32enasc72c', NOW(), FALSE),
#     ('did:plc:ur6gukevhaycvnbvlyp35uvx', 'kristen76.bsky.social', 'at://did:plc:ktkc7jfakxzjpooj52ffc6ra/app.bsky.graph.follow/3lh32emszti2h', NOW(), FALSE),
#     ('did:plc:adw33b5u5d6atz5sjjpu6r55', 'raerdaemon.bsky.social', 'at://did:plc:ktkc7jfakxzjpooj52ffc6ra/app.bsky.graph.follow/3lh32elj4hb2m', NOW(), FALSE),
#     ('did:plc:lvsax6mlqnmil55k5a5rball', 'jessie-belle.bsky.social', 'at://did:plc:ktkc7jfakxzjpooj52ffc6ra/app.bsky.graph.follow/3lh32ekxwim24', NOW(), FALSE),
#     ('did:plc:x7zxiua34o66ehayfkb4tuqn', 'slimmack69.bsky.social', 'at://did:plc:ktkc7jfakxzjpooj52ffc6ra/app.bsky.graph.follow/3lh32ekil2e2l', NOW(), FALSE),
#     ('did:plc:j5v7pwzpg6wqkhrtqd2wasj6', 'quanky.bsky.social', 'at://did:plc:ktkc7jfakxzjpooj52ffc6ra/app.bsky.graph.follow/3lh32ejy4rt2c', NOW(), FALSE),
#     ('did:plc:7v7msgpnvddbazy5ogqris7b', 'ghola.bsky.social', 'at://did:plc:ktkc7jfakxzjpooj52ffc6ra/app.bsky.graph.follow/3lh32ejgip222', NOW(), FALSE),
#     ('did:plc:hi7hzbodaugl2ky32fbk2bh5', 'glasscatty.bsky.social', 'at://did:plc:ktkc7jfakxzjpooj52ffc6ra/app.bsky.graph.follow/3lh32ehvix32c', NOW(), FALSE),
#     ('did:plc:2r37m4k5qkffs66q6tov3h6g', 'debfly.bsky.social', 'at://did:plc:ktkc7jfakxzjpooj52ffc6ra/app.bsky.graph.follow/3lh32eg7cl32c', NOW(), FALSE),
#     ('did:plc:osildmmd45g5qey4wlcisfrj', 'buffy.bsky.social', 'at://did:plc:ktkc7jfakxzjpooj52ffc6ra/app.bsky.graph.follow/3lh32efl2z42l', NOW(), FALSE),
#     ('did:plc:dqgpjjl4nwc34w3abki6c6jp', 'cebgames.bsky.social', 'at://did:plc:ktkc7jfakxzjpooj52ffc6ra/app.bsky.graph.follow/3lh32eeu27k22', NOW(), FALSE),
#     ('did:plc:pbrxhtf67pbjqmu62qu2yqip', 'gabagoo2187.bsky.social', 'at://did:plc:ktkc7jfakxzjpooj52ffc6ra/app.bsky.graph.follow/3lh32eeb3ul23', NOW(), FALSE),
#     ('did:plc:5ch2irkm6wvh4pu6sdi2nac3', 'skbeachlvr.bsky.social', 'at://did:plc:ktkc7jfakxzjpooj52ffc6ra/app.bsky.graph.follow/3lh32ed5jxb2m', NOW(), FALSE),
#     ('did:plc:iz7zoedsjz4nfq3nl2zj6rda', 'simon6934.bsky.social', 'at://did:plc:ktkc7jfakxzjpooj52ffc6ra/app.bsky.graph.follow/3lh32ecljuc22', NOW(), FALSE),
#     ('did:plc:yrls4czcbwcxaybwmdv3svpd', 'graycelynn.bsky.social', 'at://did:plc:ktkc7jfakxzjpooj52ffc6ra/app.bsky.graph.follow/3lh32ebztwq2h', NOW(), FALSE),
#     ('did:plc:y6q66ca2kcma6rvdhwu5mb6l', 'thobgubnol.bsky.social', 'at://did:plc:ktkc7jfakxzjpooj52ffc6ra/app.bsky.graph.follow/3lh32ebgbye2l', NOW(), FALSE),
#     ('did:plc:qzjcutjhc5g7ztmhz7k5silo', 'nanimoshitenai.bsky.social', 'at://did:plc:ktkc7jfakxzjpooj52ffc6ra/app.bsky.graph.follow/3lh32eazals26', NOW(), FALSE),
#     ('did:plc:voyysfzqyfojsvidgszn3sxb', 'splatanadreemurr.bsky.social', 'at://did:plc:ktkc7jfakxzjpooj52ffc6ra/app.bsky.graph.follow/3lh32e7md4q2o', NOW(), FALSE),
#     ('did:plc:ygaxpkhzqvlnnxjh3yrcvajl', 'nudlicica.bsky.social', 'at://did:plc:ktkc7jfakxzjpooj52ffc6ra/app.bsky.graph.follow/3lh32e6zhxa2h', NOW(), FALSE),
#     ('did:plc:jfckrdxrqq3tdfxekd4fs4zc', 'fearsomefish21.bsky.social', 'at://did:plc:ktkc7jfakxzjpooj52ffc6ra/app.bsky.graph.follow/3lh32e4viqq2x', NOW(), FALSE),
#     ('did:plc:g5plpixnheuktrhf2v62vh6k', 'rubinix.bsky.social', 'at://did:plc:ktkc7jfakxzjpooj52ffc6ra/app.bsky.graph.follow/3lh32e4avls26', NOW(), FALSE),
#     ('did:plc:f2ycpdmz5e7tavqvqltsu3kj', 'cat-jane.bsky.social', 'at://did:plc:ktkc7jfakxzjpooj52ffc6ra/app.bsky.graph.follow/3lh32e3tp5h2c', NOW(), FALSE),
#     ('did:plc:nunrj622vxyqnbszcouztlm4', 'thurjulie.bsky.social', 'at://did:plc:ktkc7jfakxzjpooj52ffc6ra/app.bsky.graph.follow/3lh32e2bp6323', NOW(), FALSE),
#     ('did:plc:u2mosg3rpudwmobbyxt46buk', 'hellabarnes.bsky.social', 'at://did:plc:ktkc7jfakxzjpooj52ffc6ra/app.bsky.graph.follow/3lh32dzpftd24', NOW(), FALSE),
#     ('did:plc:rruaubhlfwaw4vq7h4nkpe3k', 'tacosandsleep.bsky.social', 'at://did:plc:ktkc7jfakxzjpooj52ffc6ra/app.bsky.graph.follow/3lh32dz5ak72c', NOW(), FALSE),
#     ('did:plc:pr2gqn43wlik5vguo5s52zyp', 'nikkimwalls.bsky.social', 'at://did:plc:ktkc7jfakxzjpooj52ffc6ra/app.bsky.graph.follow/3lh32dyic5k22', NOW(), FALSE),
#     ('did:plc:k7azyrv46vvzctaf5k4nam2u', 'scorpioryzen.bsky.social', 'at://did:plc:ktkc7jfakxzjpooj52ffc6ra/app.bsky.graph.follow/3lh32dwzvts26', NOW(), FALSE),
#     ('did:plc:kame6u5eixxkvufriabjcwkd', 'cr-72206.bsky.social', 'at://did:plc:ktkc7jfakxzjpooj52ffc6ra/app.bsky.graph.follow/3lh32dwlwbb2f', NOW(), FALSE),
#     ('did:plc:4lphwqrzusksqj4jkwbnwln2', 'laurellr.bsky.social', 'at://did:plc:ktkc7jfakxzjpooj52ffc6ra/app.bsky.graph.follow/3lh32dvjv3o2a', NOW(), FALSE),
#     ('did:plc:khif4p653idkwkya4qgy5pog', 'marmar1119.bsky.social', 'at://did:plc:ktkc7jfakxzjpooj52ffc6ra/app.bsky.graph.follow/3lh32dut27222', NOW(), FALSE),
#     ('did:plc:bci6dfr2muziqbzpm36oc3vo', 'omniscientpanda.bsky.social', 'at://did:plc:ktkc7jfakxzjpooj52ffc6ra/app.bsky.graph.follow/3lh32duilpe2l', NOW(), FALSE),
#     ('did:plc:2ji4cmweqk4lpn6fsyraot7i', 'lanyardigan.bsky.social', 'at://did:plc:ktkc7jfakxzjpooj52ffc6ra/app.bsky.graph.follow/3lh32dt23sr2m', NOW(), FALSE),
#     ('did:plc:w3zzvsdfr6h3j734ykrjafr5', 'joanconnors01.bsky.social', 'at://did:plc:ktkc7jfakxzjpooj52ffc6ra/app.bsky.graph.follow/3lh32dskzy42l', NOW(), FALSE),
#     ('did:plc:3dq3qobjub6kjkvh5vglaylk', '12malloryjensen.bsky.social', 'at://did:plc:ktkc7jfakxzjpooj52ffc6ra/app.bsky.graph.follow/3lh32dryebo2a', NOW(), FALSE),
#     ('did:plc:yqr7gd22wy2xuvq2ur4ce2n5', 'softbloodkitty.bsky.social', 'at://did:plc:ktkc7jfakxzjpooj52ffc6ra/app.bsky.graph.follow/3lh32dreay22d', NOW(), FALSE),
#     ('did:plc:ilps7seahlbrbolrb74vvzyz', 'muhareb2025.bsky.social', 'at://did:plc:ktkc7jfakxzjpooj52ffc6ra/app.bsky.graph.follow/3lh32dqwjwd23', NOW(), FALSE),
#     ('did:plc:5fabgperxtv3acyhbmxmjsjj', 'crystallibrarian.bsky.social', 'at://did:plc:ktkc7jfakxzjpooj52ffc6ra/app.bsky.graph.follow/3lh32dpbfp226', NOW(), FALSE),
#     ('did:plc:zwauuk6ugofeulsjn74iscjl', 'dietdrphil.bsky.social', 'at://did:plc:ktkc7jfakxzjpooj52ffc6ra/app.bsky.graph.follow/3lh32dorwlc26', NOW(), FALSE),
#     ('did:plc:gubjx3vkvxgccehf6nnbmjcm', 'katonya.bsky.social', 'at://did:plc:ktkc7jfakxzjpooj52ffc6ra/app.bsky.graph.follow/3lh32do6zrj2f', NOW(), FALSE),
#     ('did:plc:g252e67j7zrqyf2g4avhhkvl', 'dbjmn3700.bsky.social', 'at://did:plc:ktkc7jfakxzjpooj52ffc6ra/app.bsky.graph.follow/3lh32dmmbyk22', NOW(), FALSE),
#     ('did:plc:amigijvsnkq6s6j3ebpixkhe', 'una39.bsky.social', 'at://did:plc:ktkc7jfakxzjpooj52ffc6ra/app.bsky.graph.follow/3lh32dm6fmk22', NOW(), FALSE),
#     ('did:plc:uk3sbpkqwwxuambonr7ibhjs', 'misskevin.bsky.social', 'at://did:plc:ktkc7jfakxzjpooj52ffc6ra/app.bsky.graph.follow/3lh32dlpshd2c', NOW(), FALSE),
#     ('did:plc:vpasos7mkklwfcfabr3oocrq', 'sarahdselecta.bsky.social', 'at://did:plc:ktkc7jfakxzjpooj52ffc6ra/app.bsky.graph.follow/3lh32dl6df72o', NOW(), FALSE),
#     ('did:plc:gormnems4iydljgsojdyvpvt', 'freyja-lynx.dev', 'at://did:plc:ktkc7jfakxzjpooj52ffc6ra/app.bsky.graph.follow/3lh32dkjqs22d', NOW(), FALSE),
#     ('did:plc:7puvmrcagisfax72vgr2gnst', 'wagontrain.bsky.social', 'at://did:plc:ktkc7jfakxzjpooj52ffc6ra/app.bsky.graph.follow/3lh32djzllc26', NOW(), FALSE),
#     ('did:plc:6zq43swq4gbevh7epypcjsyd', 'harukaamagatos.bsky.social', 'at://did:plc:ktkc7jfakxzjpooj52ffc6ra/app.bsky.graph.follow/3lh32djj5li2h', NOW(), FALSE),
#     ('did:plc:mq3vgvebnhr7xrzskkssgb2x', 'atouchofdaphne.bsky.social', 'at://did:plc:ktkc7jfakxzjpooj52ffc6ra/app.bsky.graph.follow/3lh32dhtocl23', NOW(), FALSE),
#     ('did:plc:cxs26r3e6ui7skeoh6pziu2l', 'isaberela.bsky.social', 'at://did:plc:ktkc7jfakxzjpooj52ffc6ra/app.bsky.graph.follow/3lh32dh7ues22', NOW(), FALSE),
#     ('did:plc:j43b6ufis5n75foguchbshtp', 'kaffrn.bsky.social', 'at://did:plc:ktkc7jfakxzjpooj52ffc6ra/app.bsky.graph.follow/3lh32dgsmlk22', NOW(), FALSE),
#     ('did:plc:kh4sx5mb4nvltzixb4g4hmls', 'witwarrior.bsky.social', 'at://did:plc:ktkc7jfakxzjpooj52ffc6ra/app.bsky.graph.follow/3lh32dedirw2a', NOW(), FALSE),
#     ('did:plc:45japgdaleuojv5mbhkzco7b', 'badlaughtrack.bsky.social', 'at://did:plc:ktkc7jfakxzjpooj52ffc6ra/app.bsky.graph.follow/3lh32ddv2ii2x', NOW(), FALSE),
#     ('did:plc:qr72s5epdofw5bem3gycdeoy', 'mcardigan.bsky.social', 'at://did:plc:ktkc7jfakxzjpooj52ffc6ra/app.bsky.graph.follow/3lh32dcfovc26', NOW(), FALSE),
#     ('did:plc:4hjpj3myugkuhh5dm56mqyev', 'judithanne.bsky.social', 'at://did:plc:ktkc7jfakxzjpooj52ffc6ra/app.bsky.graph.follow/3lh32dbvhzj2f', NOW(), FALSE),
#     ('did:plc:vnjg2g2s6bvpqtwfxcsu47xx', 'lucasdaf.bsky.social', 'at://did:plc:ktkc7jfakxzjpooj52ffc6ra/app.bsky.graph.follow/3lh32dbi2dj2f', NOW(), FALSE),
#     ('did:plc:ditsqjllens4jjlaomxjvcbn', 'julsfore.bsky.social', 'at://did:plc:ktkc7jfakxzjpooj52ffc6ra/app.bsky.graph.follow/3lh32da3ji22d', NOW(), FALSE),
#     ('did:plc:rcibti2zf7ny7pr2aa3beewp', 'damienvanpraag.bsky.social', 'at://did:plc:ktkc7jfakxzjpooj52ffc6ra/app.bsky.graph.follow/3lh32d7skms22', NOW(), FALSE),
#     ('did:plc:d4neqqn7gywcley3mdsyggbi', 'onewhosucceeds.bsky.social', 'at://did:plc:ktkc7jfakxzjpooj52ffc6ra/app.bsky.graph.follow/3lh32d7cork2p', NOW(), FALSE),
#     ('did:plc:huthh4ziw7pbrn7hndj4jseo', 'enceladust.bsky.social', 'at://did:plc:ktkc7jfakxzjpooj52ffc6ra/app.bsky.graph.follow/3lh32d6sla222', NOW(), FALSE),
#     ('did:plc:vzo6dwjjd4vofihyugk4j4vs', 'amylynne3.bsky.social', 'at://did:plc:ktkc7jfakxzjpooj52ffc6ra/app.bsky.graph.follow/3lh32d65m7j2m', NOW(), FALSE),
#     ('did:plc:rg6cry5tlhptnacptl4ycwin', 'oulipo-type.bsky.social', 'at://did:plc:ktkc7jfakxzjpooj52ffc6ra/app.bsky.graph.follow/3lh32d5odxs2p', NOW(), FALSE),
#     ('did:plc:uregza2dbu4ha43tdapfn6gl', '3deified.art', 'at://did:plc:ktkc7jfakxzjpooj52ffc6ra/app.bsky.graph.follow/3lh32d3whzs26', NOW(), FALSE),
#     ('did:plc:pcoch2f3r53fo7xqobz23suv', 'ayla7766.bsky.social', 'at://did:plc:ktkc7jfakxzjpooj52ffc6ra/app.bsky.graph.follow/3lh32d3hdop2o', NOW(), FALSE),
#     ('did:plc:dj6oqzybcf5d2cfdysqkpmyt', 'depressedavacado.bsky.social', 'at://did:plc:ktkc7jfakxzjpooj52ffc6ra/app.bsky.graph.follow/3lh32d2vi6j2m', NOW(), TRUE),
# ...
#     ('did:plc:6v7iwxsj6luphshkrzbjznic', 'lyratcm.bsky.social', 'at://did:plc:ktkc7jfakxzjpooj52ffc6ra/app.bsky.graph.follow/3lh32bg7j2c2p', NOW(), FALSE),
#     ('did:plc:g67fokfk4j5ccolzpjbeqd2w', 'lasers.bsky.social', 'at://did:plc:ktkc7jfakxzjpooj52ffc6ra/app.bsky.graph.follow/3lh32beoiji2f', NOW(), FALSE),
#     ('did:plc:tlcxmsfld4aztapjhjrxhcu2', 'carolyn-howes.bsky.social', 'at://did:plc:ktkc7jfakxzjpooj52ffc6ra/app.bsky.graph.follow/3lh32be6wh324', NOW(), FALSE),
#     ('did:plc:677twbpxxdmbr2qwqt3tpok5', 'edden676.bsky.social', 'at://did:plc:ktkc7jfakxzjpooj52ffc6ra/app.bsky.graph.follow/3lh32bdo4a32c', NOW(), FALSE),
#     ('did:plc:iqgyzwzxz27hharqjbscei6p', 'ozscot42.bsky.social', 'at://did:plc:ktkc7jfakxzjpooj52ffc6ra/app.bsky.graph.follow/3lh32bd2ldk2d', NOW(), FALSE),
#     ('did:plc:wru6rbeunonkjimhfaprjnzf', 'dizzyhands.bsky.social', 'at://did:plc:ktkc7jfakxzjpooj52ffc6ra/app.bsky.graph.follow/3lh32bcckod2c', NOW(), FALSE),
#     ('did:plc:2xxu3mmsx2zqs2ithrnvjbgg', 'chitwncolorado.bsky.social', 'at://did:plc:ktkc7jfakxzjpooj52ffc6ra/app.bsky.graph.follow/3lh32batwid2c', NOW(), FALSE),
#     ('did:plc:nl3g2n6kvk6wretitcszzidb', 'clemjtrem.bsky.social', 'at://did:plc:ktkc7jfakxzjpooj52ffc6ra/app.bsky.graph.follow/3lh32baj43r2m', NOW(), FALSE),
#     ('did:plc:bvwk4fp6neqfr6a2xbv7bogc', 'manuel68.bsky.social', 'at://did:plc:ktkc7jfakxzjpooj52ffc6ra/app.bsky.graph.follow/3lh32b7zqys22', NOW(), FALSE),
#     ('did:plc:mujoejgllxmvsipuzti4sbdl', 'windowkitty.bsky.social', 'at://did:plc:ktkc7jfakxzjpooj52ffc6ra/app.bsky.graph.follow/3lh32b6wqy72o', NOW(), FALSE),
#     ('did:plc:5wp6g3y5euayfbf3ocmgife2', 'loreoftay.bsky.social', 'at://did:plc:ktkc7jfakxzjpooj52ffc6ra/app.bsky.graph.follow/3lh32b5krq226', NOW(), FALSE),
#     ('did:plc:ah6annh77ajouikdurfhin3i', 'mrstamper.bsky.social', 'at://did:plc:ktkc7jfakxzjpooj52ffc6ra/app.bsky.graph.follow/3lh32b55tkk22', NOW(), FALSE),
#     ('did:plc:g5ynkg7hi5vw6h6j5x7cu6y2', 'wmullerg.bsky.social', 'at://did:plc:ktkc7jfakxzjpooj52ffc6ra/app.bsky.graph.follow/3lh32b4r3cs2p', NOW(), FALSE),
#     ('did:plc:rfdkpapsr6tfhz47zstdz4g3', 'badbisque.bsky.social', 'at://did:plc:ktkc7jfakxzjpooj52ffc6ra/app.bsky.graph.follow/3lh32b35rpk2p', NOW(), FALSE),
#     ('did:plc:5a3olefimhowph5fosqvfibs', 'kjamesnow.bsky.social', 'at://did:plc:ktkc7jfakxzjpooj52ffc6ra/app.bsky.graph.follow/3lh32b2oklh2o', NOW(), FALSE),
#     ('did:plc:nnc32n2gldpvhx6pl4ttv765', '666tweet.bsky.social', 'at://did:plc:ktkc7jfakxzjpooj52ffc6ra/app.bsky.graph.follow/3lh32b25xw22d', NOW(), FALSE),
#     ('did:plc:o4lutjylg3474vfxmzdyyk6g', 'fridalamaldita.bsky.social', 'at://did:plc:ktkc7jfakxzjpooj52ffc6ra/app.bsky.graph.follow/3lh32azn7xj2m', NOW(), FALSE),
#     ('did:plc:h4hy7fxemfcteteja7p5xj3v', 'gardenfan99.bsky.social', 'at://did:plc:ktkc7jfakxzjpooj52ffc6ra/app.bsky.graph.follow/3lh32az2fmc26', NOW(), FALSE),
#     ('did:plc:tyyv44xow6c3ypblhchfinxf', 'everambr4.bsky.social', 'at://did:plc:ktkc7jfakxzjpooj52ffc6ra/app.bsky.graph.follow/3lh32aykrmc26', NOW(), FALSE),
#     ('did:plc:stzxyo2douhh3rvqvnz5ceni', 'evildirkus.bsky.social', 'at://did:plc:ktkc7jfakxzjpooj52ffc6ra/app.bsky.graph.follow/3lh32awmxh62a', NOW(), FALSE),
#     ('did:plc:sbie35spzncotdbw54mxkuzm', 'jotchua.bsky.social', 'at://did:plc:ktkc7jfakxzjpooj52ffc6ra/app.bsky.graph.follow/3lh32aw6m5d23', NOW(), FALSE),
#     ('did:plc:qffy4fqlwqm2hxrqmuyavdkk', 'queencatia.com', 'at://did:plc:ktkc7jfakxzjpooj52ffc6ra/app.bsky.graph.follow/3lh32avo55a2h', NOW(), FALSE),
#     ('did:plc:tjbpjif5l32x7ktu7a7vrvbx', 'cqpar.bsky.social', 'at://did:plc:ktkc7jfakxzjpooj52ffc6ra/app.bsky.graph.follow/3lh32av7vd22d', NOW(), FALSE),
#     ('did:plc:7ugwxbselyp3bd5pkpl5pd5m', 'realguyfawkes.bsky.social', 'at://did:plc:ktkc7jfakxzjpooj52ffc6ra/app.bsky.graph.follow/3lh32atpryw2a', NOW(), FALSE),
#     ('did:plc:3lanwpirrguo3ual7ltiqvu5', 'siestalynn-123.bsky.social', 'at://did:plc:ktkc7jfakxzjpooj52ffc6ra/app.bsky.graph.follow/3lh32at5xcq2x', NOW(), FALSE),
#     ('did:plc:5hesxh62pwabxkrchcl2cjaj', 'imacooki3.bsky.social', 'at://did:plc:ktkc7jfakxzjpooj52ffc6ra/app.bsky.graph.follow/3lh32asoi7s26', NOW(), FALSE),
#     ('did:plc:uxb434jy6kyjopmwx2zrroo2', 'hummingdeer.bsky.social', 'at://did:plc:ktkc7jfakxzjpooj52ffc6ra/app.bsky.graph.follow/3lh32as6gji2x', NOW(), FALSE),
#     ('did:plc:tpkxf6dylyeuy3hl3qz4gxxm', 'mnmkoch.bsky.social', 'at://did:plc:ktkc7jfakxzjpooj52ffc6ra/app.bsky.graph.follow/3lh32aquv4324', NOW(), FALSE),
#     ('did:plc:5yrovzoxiethfp23ijk3d6v4', 'jstnobody.bsky.social', 'at://did:plc:ktkc7jfakxzjpooj52ffc6ra/app.bsky.graph.follow/3lh32aqfm5y2x', NOW(), FALSE),
#     ('did:plc:xqneg7cnkhfoibrgclfhqn5b', 'pm48.bsky.social', 'at://did:plc:ktkc7jfakxzjpooj52ffc6ra/app.bsky.graph.follow/3lh32apsqni2x', NOW(), FALSE),
#     ('did:plc:lvwfuueqn2yvanrhzaatu3jw', 'melkmel.bsky.social', 'at://did:plc:ktkc7jfakxzjpooj52ffc6ra/app.bsky.graph.follow/3lh32apdvw22p', NOW(), FALSE),
#     ('did:plc:u7vbxmnxfgxyq6m626vg6jtm', 'thrawn21.bsky.social', 'at://did:plc:ktkc7jfakxzjpooj52ffc6ra/app.bsky.graph.follow/3lh32am4faq2f', NOW(), FALSE),
#     ('did:plc:izxt5sjqw7aocd3ggnq4x3hj', 'brenda-bailey-86.bsky.social', 'at://did:plc:ktkc7jfakxzjpooj52ffc6ra/app.bsky.graph.follow/3lh32alo6es22', NOW(), FALSE),
#     ('did:plc:7bperxoia2f7kaanu6aanhjn', 'wanda1212.bsky.social', 'at://did:plc:ktkc7jfakxzjpooj52ffc6ra/app.bsky.graph.follow/3lh32al73gw2a', NOW(), FALSE),
#     ('did:plc:37gky7cmsibjwnx64yezjdu7', 'ornamentalkudzu.bsky.social', 'at://did:plc:ktkc7jfakxzjpooj52ffc6ra/app.bsky.graph.follow/3lh32akpgho2a', NOW(), FALSE),
#     ('did:plc:y2iompefnf6ptz5l6h6ri2sf', 'jimcribley.bsky.social', 'at://did:plc:ktkc7jfakxzjpooj52ffc6ra/app.bsky.graph.follow/3lh32ak4rwl2c', NOW(), FALSE),
#     ('did:plc:45ueewjdrplnv2acdsbhhxqx', 'superfluousthomas.bsky.social', 'at://did:plc:ktkc7jfakxzjpooj52ffc6ra/app.bsky.graph.follow/3lh32aiyos324', NOW(), FALSE),
#     ('did:plc:ywt7ql6gj6ri5oltyilhjetr', 'rusty8491.bsky.social', 'at://did:plc:ktkc7jfakxzjpooj52ffc6ra/app.bsky.graph.follow/3lh32aijins2p', NOW(), FALSE),
#     ('did:plc:olmmbgowcwhffolxd7usndzt', 'greenspace01.bsky.social', 'at://did:plc:ktkc7jfakxzjpooj52ffc6ra/app.bsky.graph.follow/3lh32ahasqa2f', NOW(), FALSE),
#     ('did:plc:lu2lfevqi5jaeha64oshdejy', 'angelsolora34.bsky.social', 'at://did:plc:ktkc7jfakxzjpooj52ffc6ra/app.bsky.graph.follow/3lh32af67uq2f', NOW(), FALSE),
#     ('did:plc:j2tps5ctnwlekuilyh4ifyds', 'brambl3.bsky.social', 'at://did:plc:ktkc7jfakxzjpooj52ffc6ra/app.bsky.graph.follow/3lh32aely7c26', NOW(), FALSE),
#     ('did:plc:ftupd5pz6hx73rtpp3lzvg7m', 'alyn3.bsky.social', 'at://did:plc:ktkc7jfakxzjpooj52ffc6ra/app.bsky.graph.follow/3lh32addhq62c', NOW(), FALSE),
#     ('did:plc:2v3ob4dlpfkk5qfyrakxhvk4', 'bynya.bsky.social', 'at://did:plc:ktkc7jfakxzjpooj52ffc6ra/app.bsky.graph.follow/3lh32acu2xb2m', NOW(), FALSE),
#     ('did:plc:5q4573t2zuqltw7bomhtngje', 'unbroknsoul.bsky.social', 'at://did:plc:ktkc7jfakxzjpooj52ffc6ra/app.bsky.graph.follow/3lh32ac3iuc2p', NOW(), FALSE),
#     ('did:plc:dkmcrr7ydeutgwvsuakpgqo3', 'tigerjake18.bsky.social', 'at://did:plc:ktkc7jfakxzjpooj52ffc6ra/app.bsky.graph.follow/3lh32aa4ovl24', NOW(), FALSE),
#     ('did:plc:gstfsmi5wmp4vfmxkjn7fdvx', 'isnotbot.bsky.social', 'at://did:plc:ktkc7jfakxzjpooj52ffc6ra/app.bsky.graph.follow/3lh32a7okq22d', NOW(), FALSE),
#     ('did:plc:aipnw5pn6q2mrz7nf7ixxiqk', 'helenavis.bsky.social', 'at://did:plc:ktkc7jfakxzjpooj52ffc6ra/app.bsky.graph.follow/3lh32a4elik26', NOW(), FALSE),
#     ('did:plc:4mfehgb222d73ugc5bd2kjhr', 'jrw72.bsky.social', 'at://did:plc:ktkc7jfakxzjpooj52ffc6ra/app.bsky.graph.follow/3lh32a2gjxb2m', NOW(), FALSE),
#     ('did:plc:43jx6ilf7e66o6siiu4ti2vm', 'runnergirlsteph.bsky.social', 'at://did:plc:ktkc7jfakxzjpooj52ffc6ra/app.bsky.graph.follow/3lh327zyepa2f', NOW(), FALSE),
#     ('did:plc:4bed532zeezgl367hwcjnk2p', 'nikocopperred.bsky.social', 'at://did:plc:ktkc7jfakxzjpooj52ffc6ra/app.bsky.graph.follow/3lh327zhrlb2m', NOW(), FALSE),
#     ('did:plc:cyci4jcstclmb4txs2zdcijh', 'princessdonutrulz.bsky.social', 'at://did:plc:ktkc7jfakxzjpooj52ffc6ra/app.bsky.graph.follow/3lh327z2r4w2a', NOW(), FALSE),
#     ('did:plc:e7mchv4jv53gyuefftfmsnf5', 'aloysius1973.bsky.social', 'at://did:plc:ktkc7jfakxzjpooj52ffc6ra/app.bsky.graph.follow/3lh327xssds22', NOW(), FALSE),
#     ('did:plc:z7elwjem7h6gnm2eaqlr3xv3', 'lostlucity.bsky.social', 'at://did:plc:ktkc7jfakxzjpooj52ffc6ra/app.bsky.graph.follow/3lh327xexlt2c', NOW(), FALSE),
#     ('did:plc:ikyoi4pf64fglupzigy3zdar', 'bobblycat.bsky.social', 'at://did:plc:ktkc7jfakxzjpooj52ffc6ra/app.bsky.graph.follow/3lh327ws7v42l', NOW(), FALSE),
#     ('did:plc:lpaogpe5ybg4iukhxy6loya6', 'milovetic.bsky.social', 'at://did:plc:ktkc7jfakxzjpooj52ffc6ra/app.bsky.graph.follow/3lh327vr3sk22', NOW(), FALSE),
#     ('did:plc:nu5ckpgmlb5pmo2lijlq5vvw', 'clumsy-artist.bsky.social', 'at://did:plc:ktkc7jfakxzjpooj52ffc6ra/app.bsky.graph.follow/3lh327ve7qc22', NOW(), FALSE),
#     ('did:plc:vcfot6owwaw5alstfv4bprzd', 'skidzmcghee.bsky.social', 'at://did:plc:ktkc7jfakxzjpooj52ffc6ra/app.bsky.graph.follow/3lh327ud4n42l', NOW(), TRUE),
#     ('did:plc:xo5vtdphafwrs7nkbmch7yf6', 'ladyjadyn.bsky.social', 'at://did:plc:ktkc7jfakxzjpooj52ffc6ra/app.bsky.graph.follow/3lh327t7osy2h', NOW(), FALSE),
#     ('did:plc:rwm2eutp2c4v6iqm3xkxtxlu', 'antilles464.bsky.social', 'at://did:plc:ktkc7jfakxzjpooj52ffc6ra/app.bsky.graph.follow/3lh327sqxn222', NOW(), FALSE),
#     ('did:plc:p4z6rqeiccmghumbketx77pr', 'heidisilver21.bsky.social', 'at://did:plc:ktkc7jfakxzjpooj52ffc6ra/app.bsky.graph.follow/3lh327sckta23', NOW(), FALSE),
#     ('did:plc:lnwstupmpnzh7hvol7luquut', 'perdidanafeira.bsky.social', 'at://did:plc:ktkc7jfakxzjpooj52ffc6ra/app.bsky.graph.follow/3lh327rvxyd2c', NOW(), FALSE),
#     ('did:plc:teuzemlw5tlqudvitnwqp2jf', 'tokingp0tato.bsky.social', 'at://did:plc:ktkc7jfakxzjpooj52ffc6ra/app.bsky.graph.follow/3lh327qt33j2m', NOW(), FALSE),
#     ('did:plc:2a5adjn6br22zsdll6rd5pjh', 'jskodak.bsky.social', 'at://did:plc:ktkc7jfakxzjpooj52ffc6ra/app.bsky.graph.follow/3lh327q7cxl2c', NOW(), FALSE),
#     ('did:plc:f7anlvaw75adysumfubcgkuy', 'lillieshalosh.bsky.social', 'at://did:plc:ktkc7jfakxzjpooj52ffc6ra/app.bsky.graph.follow/3lh327oy3ba2f', NOW(), FALSE),
#     ('did:plc:wrlmz4a3axdb3bzx7xccragn', 'randykraft.bsky.social', 'at://did:plc:ktkc7jfakxzjpooj52ffc6ra/app.bsky.graph.follow/3lh327ohzde2l', NOW(), FALSE),
#     ('did:plc:ehttchd4kl6t4psj4ahnuqrm', 'sneakii.bsky.social', 'at://did:plc:ktkc7jfakxzjpooj52ffc6ra/app.bsky.graph.follow/3lh327nfmy324', NOW(), FALSE),
#     ('did:plc:yahy55fipnw6vuuuitjmcfuc', 'smog-monster.bsky.social', 'at://did:plc:ktkc7jfakxzjpooj52ffc6ra/app.bsky.graph.follow/3lh327mxjl62c', NOW(), FALSE),
#     ('did:plc:lkicuossg2grpom7sp3pnls6', 'maniagnosis.bsky.social', 'at://did:plc:ktkc7jfakxzjpooj52ffc6ra/app.bsky.graph.follow/3lh327lt5vj2m', NOW(), FALSE),
#     ('did:plc:bl54b4zdym3jzuimzhag4cum', '516b.bsky.social', 'at://did:plc:ktkc7jfakxzjpooj52ffc6ra/app.bsky.graph.follow/3lh327lf2va2x', NOW(), FALSE),
#     ('did:plc:tqz6flcrizrbuyqrdm6kd4by', 'heathermcmanus.bsky.social', 'at://did:plc:ktkc7jfakxzjpooj52ffc6ra/app.bsky.graph.follow/3lh327kbine2l', NOW(), TRUE),
#     ('did:plc:ks7alt32dku4rccmpgxbszdb', 'isabel227.bsky.social', 'at://did:plc:ktkc7jfakxzjpooj52ffc6ra/app.bsky.graph.follow/3lh327jojri2x', NOW(), FALSE),
#     ('did:plc:wg5rpgdfkslwywyacz6ksrtm', 'katzpix.bsky.social', 'at://did:plc:ktkc7jfakxzjpooj52ffc6ra/app.bsky.graph.follow/3lh327iwqx222', NOW(), FALSE),
#     ('did:plc:ar5qbrroijg3b6xcd6mynbqt', 'daddycat.bsky.social', 'at://did:plc:ktkc7jfakxzjpooj52ffc6ra/app.bsky.graph.follow/3lh327iiat22d', NOW(), FALSE),
#     ('did:plc:hmqcckvala3erwbsbpb5hk7b', 'persiantinkerbell.bsky.social', 'at://did:plc:ktkc7jfakxzjpooj52ffc6ra/app.bsky.graph.follow/3lh327h4r4d2c', NOW(), FALSE),
#     ('did:plc:2ezgaad2nk3aqyfifsd5ei4l', 'mcrowno.bsky.social', 'at://did:plc:ktkc7jfakxzjpooj52ffc6ra/app.bsky.graph.follow/3lh327gp4pt24', NOW(), FALSE),
#     ('did:plc:lneqe5rbpdw5ngwezlk4cvsl', 'hauntedpizzabagel.bsky.social', 'at://did:plc:ktkc7jfakxzjpooj52ffc6ra/app.bsky.graph.follow/3lh327fhdi22p', NOW(), FALSE),
#     ('did:plc:usydlsegkdznjlkexcwh4xqm', 'tonnioc.bsky.social', 'at://did:plc:ktkc7jfakxzjpooj52ffc6ra/app.bsky.graph.follow/3lh327crgik22', NOW(), FALSE),
#     ('did:plc:bhwcivspr7r6oqmydmrbrfiz', 'califcurmudgeon.bsky.social', 'at://did:plc:ktkc7jfakxzjpooj52ffc6ra/app.bsky.graph.follow/3lh3277msvp2o', NOW(), FALSE),
#     ('did:plc:fude5ushxfluopl4phlhf37s', 'lolmeepicninja.bsky.social', 'at://did:plc:ktkc7jfakxzjpooj52ffc6ra/app.bsky.graph.follow/3lh326xl5g324', NOW(), FALSE),
#     ('did:plc:nrv7nbfu57ts7i77omg4obxp', 'seeshel40.bsky.social', 'at://did:plc:ktkc7jfakxzjpooj52ffc6ra/app.bsky.graph.follow/3lh326x6xig2a', NOW(), FALSE),
#     ('did:plc:35lusvcotd7hmpblmrquner6', 'duardeo.bsky.social', 'at://did:plc:ktkc7jfakxzjpooj52ffc6ra/app.bsky.graph.follow/3lh326wu3dc2p', NOW(), FALSE),
#     ('did:plc:2kprhcqb4xvbjhdchz3kxh45', 'ozryem.bsky.social', 'at://did:plc:ktkc7jfakxzjpooj52ffc6ra/app.bsky.graph.follow/3lh326vq5yk22', NOW(), FALSE),
#     ('did:plc:a4soz6zjtao4vdgqocbnv3xe', 'lovedollmagazine.bsky.social', 'at://did:plc:ktkc7jfakxzjpooj52ffc6ra/app.bsky.graph.follow/3lh326v7dyx2o', NOW(), FALSE),
#     ('did:plc:ex7qgryep7uxyy7ba552sjfj', 'svicbindra.bsky.social', 'at://did:plc:ktkc7jfakxzjpooj52ffc6ra/app.bsky.graph.follow/3lh326u2ycw2c', NOW(), FALSE),
#     ('did:plc:oem6npiqcrieuojf2zzecjrt', 'chibleymays.bsky.social', 'at://did:plc:ktkc7jfakxzjpooj52ffc6ra/app.bsky.graph.follow/3lh326tp42p2o', NOW(), FALSE),
#     ('did:plc:27capbj45emrfyevxaeh4tbd', 'tjtransue.bsky.social', 'at://did:plc:ktkc7jfakxzjpooj52ffc6ra/app.bsky.graph.follow/3lh326t6ufc22', NOW(), FALSE),
#     ('did:plc:5f73g75vy4fwrv2gc2kxphfe', 'igameforpain.bsky.social', 'at://did:plc:ktkc7jfakxzjpooj52ffc6ra/app.bsky.graph.follow/3lh326qhmug2a', NOW(), FALSE),
#     ('did:plc:3c3gdqaeuqpqs5edmsywhrfn', 'terryroth.bsky.social', 'at://did:plc:ktkc7jfakxzjpooj52ffc6ra/app.bsky.graph.follow/3lh326p6giw2a', NOW(), TRUE),
#     ('did:plc:zqitic5bdasiwh4azp4xfn7y', 'ambartworks.bsky.social', 'at://did:plc:ktkc7jfakxzjpooj52ffc6ra/app.bsky.graph.follow/3lh326ore6k26', NOW(), FALSE),
#     ('did:plc:l75hwpwq3nlqv4qm5tjw4gaq', 'koolfooltattoo.bsky.social', 'at://did:plc:ktkc7jfakxzjpooj52ffc6ra/app.bsky.graph.follow/3lh326obk6c2p', NOW(), FALSE),
#     ('did:plc:rjllp6lfixhdjeu3gnhsrd6z', 'dhampir984.bsky.social', 'at://did:plc:ktkc7jfakxzjpooj52ffc6ra/app.bsky.graph.follow/3lh326npsmq2f', NOW(), FALSE),
#     ('did:plc:yxztxonlvqsyrbyzil3ohqed', 'alluringskull.bsky.social', 'at://did:plc:ktkc7jfakxzjpooj52ffc6ra/app.bsky.graph.follow/3lh2xzo7ypd2c', NOW(), FALSE),
#     ('did:plc:sakjkzqsvqfuzetg7w5werpq', 'luvsiclikeadog.bsky.social', 'at://did:plc:ktkc7jfakxzjpooj52ffc6ra/app.bsky.graph.follow/3lh2xz7ltkp2p', NOW(), FALSE),
#     ('did:plc:7t3knuvyz744ba6e2smxaruw', 'just-maurice.bsky.social', 'at://did:plc:ktkc7jfakxzjpooj52ffc6ra/app.bsky.graph.follow/3lh2xxrncoj2c', NOW(), FALSE),
#     ('did:plc:2itlokydpe7lu74nwstkkbsb', 'robnsobe.bsky.social', 'at://did:plc:ktkc7jfakxzjpooj52ffc6ra/app.bsky.graph.follow/3lh2xxhkl3i26', NOW(), FALSE),
#     ('did:plc:2iwp7qyik4vuwcqmx2i54ign', 'drumjustinp.bsky.social', 'at://did:plc:ktkc7jfakxzjpooj52ffc6ra/app.bsky.graph.follow/3lh2xxb3lg72a', NOW(), FALSE),
#     ('did:plc:4ad6pxf5uxtmsazrkxj3krx5', 'carolamueller.bsky.social', 'at://did:plc:ktkc7jfakxzjpooj52ffc6ra/app.bsky.graph.follow/3lh2xuytzcp23', NOW(), FALSE),
#     ('did:plc:muyvftnlabmtsskktmohqsls', 'clancey1234.bsky.social', 'at://did:plc:ktkc7jfakxzjpooj52ffc6ra/app.bsky.graph.follow/3lh2xuugmdd2c', NOW(), FALSE),
#     ('did:plc:cfnqg4gh5y4fvo7hixcruzy3', 'thorbenson.bsky.social', 'at://did:plc:ktkc7jfakxzjpooj52ffc6ra/app.bsky.graph.follow/3lh2xtltin72o', NOW(), FALSE)
# RETURNING user_handle, follow_date;

# %%
generate_delete_query(db_follows)
# Out:
# DELETE FROM "bsky"."follows"
# WHERE user_id IN('did:plc:uabgcavopnqfvfmzmnxjvls5')
# RETURNING user_handle;

# %%
# finish logging and submit log to github
following = client.get_profile(actor=BSKY_USERNAME).follows_count
followers = client.get_profile(actor=BSKY_USERNAME).followers_count

logging_text = logging_text + 'Successfully produced queries and made changes to table as necessary.' + LINE_BREAK
logging_text = logging_text + LINE_BREAK + 'cur followers: ' + str(followers) + LINE_BREAK + 'now following: ' + str(following) + LINE_BREAK
# print(logging_text)

# LOGGING ALL THE CHANGES TO OUR LOGGING FILE IN GITHUB
GITHUB_TOKEN = userdata.get('github_token')
GITHUB_REPO = userdata.get('github_user/repo')
FILE_PATH = "LOGGING_001.txt"  # Replace with the file path in your repo
BRANCH = "main"  # Replace with your branch name
COMMIT_MESSAGE = "Logging for table updates on " + str(cur_timestamp)

# Step 1: Get the file's current content and SHA
url = f"https://api.github.com/repos/{GITHUB_REPO}/contents/{FILE_PATH}"
headers = {"Authorization": f"token {GITHUB_TOKEN}"}
response = requests.get(url, headers=headers)
response_json = response.json()

# Decode the content of the file
file_sha = response_json["sha"]
content = base64.b64decode(response_json["content"]).decode("utf-8")

# Step 2: Modify the file content
new_content = content + LINE_BREAK + logging_text + END_LOGGING
encoded_content = base64.b64encode(new_content.encode("utf-8")).decode("utf-8")

# Step 3: Push the updated content
data = {
    "message": COMMIT_MESSAGE,
    "content": encoded_content,
    "sha": file_sha,
    "branch": BRANCH,
}
update_response = requests.put(url, headers=headers, json=data)

if update_response.status_code == 200:
    print("Logging file updated successfully! Here's what was added to the logs:\n")
    print(logging_text + END_LOGGING)
else:
    print(f"Error: {update_response.json()}")
# Out:
# Logging file updated successfully! Here's what was added to the logs:
#
#
# 2025-01-31 17:36:09.578035-05:00
# UPDATING "FOLLOWS" TABLE IN DATABASE
#
# prior follower count: 2593
# previously following: 6328
#
# 5783 entries were found in the database "follows" table prior to updating.
#
# Analysis of follows shows:
#   Started Following: 209
#   Stopped Following: 0
#   New Follows Added To DB: 440
#   Follow Link Mismatches: 1
# Successfully produced queries and made changes to table as necessary.
#
# cur followers: 2594
# now following: 6328
#
# ____________________

# %% [markdown]
# # SUCCESS!!
# # helllll yeah.
# now i'm gonna upload this to github and rerun everything and hopefully get nothing for each of the queries.
#
# # DOUBLE SUCCESS!!

# %% [markdown]
# # Query to look at how well each batch has performed, in regards to followbacks
#
# ```
# WITH cte AS (SELECT follow_date, user_id,
# CASE WHEN follows_you = TRUE THEN 1 ELSE 0 END AS followers
# FROM "bsky"."follows")
#
# SELECT follow_date, SUM(followers) as followbacks, COUNT(user_id) as total,
# ROUND( SUM(followers)::NUMERIC / COUNT(user_id) * 100, 2) AS percent
# FROM cte
# GROUP BY follow_date
# ORDER BY follow_date DESC;
# ```
